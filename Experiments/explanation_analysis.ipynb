# %%
import pandas as pd
import random
import textwrap
from IPython.display import display
from IPython.display import Markdown

# %%
def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %% [markdown]
# # GPT-4-Turbo

# %%
family = 'chatgpt'
model = 'gpt-4-turbo'

# %% [markdown]
# ## $I_2$

# %%
instance = 'question_2'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 72
# Unnamed: 0 72
# Tokens 1998
# Good A 2
# Good B 1
# Good C 1
# Good D 3
# > To allocate the goods (Good A, Good B, Good C, Good D) among Person 1, Person 2, and Person 3 in a fair way, we can evaluate different criteria such as efficiency, equity, and envy-freeness. For practical purposes, we can focus on the approach where each individual gets the maximum possible satisfaction from the allocation, given the indivisible nature of the goods. Here’s a step-by-step approach to solving this allocation problem:
# >
# > 1. **Identify Preference for Each Good**: Look at each good independently, and identify which person values it the most. This simplistic approach can help in maximizing total satisfaction.
# >
# >    - **Good A**:
# >      - Person 1 values at 5
# >      - Person 2 values at 45 (highest)
# >      - Person 3 values at 23
# >    - **Good B**:
# >      - Person 1 values at 47 (highest)
# >      - Person 2 values at 5
# >      - Person 3 values at 25
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 21
# Unnamed: 0 21
# Tokens 2082
# Good A 2
# Good B 1
# Good C 1
# Good D 3
# > To determine a fair allocation of the goods (Good A, Good B, Good C, Good D) among Person 1, Person 2, and Person 3, we can consider a variety of fairness concepts such as maximization of total utility, envy-freeness, efficiency, or equity. Let's explore an approach that aims to balance these principles, focusing on maximizing each person's valued utility without causing significant envy. Here’s one possible allocation strategy based on the given value information for each good:
# >
# > ### Step 1: Review Value Assessments
# > - **Good A:**
# >   - Person 1 values it at 5
# >   - Person 2 values it at 45 (highest value)
# >   - Person 3 values it at 23
# > - **Good B:**
# >   - Person 1 values it at 47 (highest value)
# >   - Person 2 values it at 5
# >   - Person 3 values it at 25
# > - **Good C:**
# >   - Person 1 values it at 45
# >   - Person 2 values it at 48 (highest value)
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 85
# Unnamed: 0 85
# Tokens 1921
# Good A 2
# Good B 1
# Good C 2
# Good D 3
# > Allocating goods among individuals in a way that is perceived as fair can be quite challenging due to differing valuations. Here, I will attempt to find a fair allocation based on the given data, considering the concept of maximizing the total satisfaction and aiming for equity in distribution. I will review the values placed on each good by all persons and try to allocate each good to the person who values it the most, while also taking into account balancing overall satisfaction among the individuals. Here is how I will allocate the goods
# >
# > 1. **Allocation of Good A:**
# >    - Person 1 values it at 5
# >    - Person 2 values it at 45
# >    - Person 3 values it at 23
# >    - **Allocated to Person 2** who values it the most.
# >
# > 2. **Allocation of Good B:**
# >    - Person 1 values it at 47
# >    - Person 2 values it at 5
# >    - Person 3 values it at 25
# ...

# %% [markdown]
# ## $I_3$

# %%
instance = 'question_3'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 49
# Unnamed: 0 49
# Tokens 0
# Good A 1
# Good B 3
# Good C 3
# Good D 2
# Good E 3
# > This is a classic resource allocation problem with a focus on fairness. Since there's no single "correct" answer, I'll present a few common fairness approaches and their outcomes:
# >
# > **1. Maximizing Total Value (Utilitarian Approach)**
# >
# > * **Goal:** Allocate goods to maximize the sum of everyone's value for the goods received.
# > * **Solution:**
# >     * Person 1 gets: Good A (40), Good D (25)
# >     * Person 2 gets: Good B (26), Good E (26)
# >     * Person 3 gets: Good C (26)
# > * **Total Value:** 40 + 25 + 26 + 26 + 26 = **143**
# > * **Pros:**  Efficient, potentially creates the most overall "happiness."
# > * **Cons:** Can lead to unequal distribution, where one person might get significantly more value than others.
# >
# > **2. Maximizing Minimum Value (Maximin/Rawlsian Approach)**
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 62
# Unnamed: 0 62
# Tokens 0
# Good A 1
# Good B 2
# Good C 3
# Good D 1
# Good E 3
# > This is a classic allocation problem with no single "fairest" solution, as fairness can be interpreted in different ways. Here's how we can approach this, considering a few common fairness principles:
# >
# > **1. Understanding the Values**
# >
# > First, let's visualize the values in a table:
# >
# > | Good | Person 1 | Person 2 | Person 3 |
# > |---|---|---|---|
# > | A | 40 | 14 | 10 |
# > | B | 2 | 26 | 26 |
# > | C | 3 | 8  | 26 |
# > | D | 25 | 26 | 12 |
# > | E | 30 | 26 | 26 |
# >
# > **2. Fairness Principles**
# >
# > Here are some fairness principles we can consider:
# >
# > * **Maximizing Total Value (Utilitarianism):**  Allocate goods to maximize the sum of everyone's valuations, regardless of individual satisfaction.
# > * **Prioritizing the Worst-Off (Egalitarianism):** Aim for an allocation where the person with the lowest total value receives as much value as possible.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 87
# Unnamed: 0 87
# Tokens 0
# Good A 1
# Good B 2
# Good C 3
# Good D 3
# Good E 2
# > This is a classic resource allocation problem with a focus on fairness. Since there's no single "correct" answer, I'll present a few common approaches and the resulting allocations:
# >
# > **1. Maximizing Total Value:**
# >
# > * **Goal:**  Allocate goods to maximize the sum of values across all individuals. This approach aims for the most "efficient" outcome in terms of overall satisfaction.
# >
# > * **Calculation:**
# >     * Good A: Person 1 (40)
# >     * Good B: Person 2 or 3 (both value it at 26)
# >     * Good C: Person 2 or 3 (both value it at 26)
# >     * Good D: Person 1 or 2 (both value it at 26, but Person 1 gets a higher total value)
# >     * Good E: Person 1, 2, or 3 (all value it at 26)
# >
# > * **Possible Allocation:**
# >     * Person 1: Good A, Good D
# >     * Person 2: Good B
# >     * Person 3: Good C
# >     * Good E: Not allocated (or randomly assigned)
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 3
# Unnamed: 0 3
# Tokens 0
# Good A 1
# Good B 3
# Good C 3
# Good D 2
# Good E nan
# > This is a classic fair division problem with indivisible goods! There are many ways to approach fairness, and no single "correct" answer. Here's a breakdown of a few methods and how they apply to this scenario, along with my proposed solution:
# >
# > **Methods to Consider:**
# >
# > * **Envy-Freeness:** An allocation is envy-free if no one would rather have someone else's bundle of goods over their own. This is difficult to achieve perfectly with indivisible goods.
# > * **Pareto Efficiency:** An allocation is Pareto efficient if it's impossible to make one person better off without making someone else worse off.
# > * **Maximin Share:**  This aims to guarantee each person receives a bundle they value at least as much as what they'd get if they could divide the goods into equal shares themselves and then other people chose their shares first.
# ...

# %% [markdown]
# ## $I_6$

# %%
instance = 'question_6'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 3
# Unnamed: 0 3
# Tokens 0
# Good A 3
# Good B nan
# Good C 2.0
# Good D 1
# > This is a classic resource allocation problem with a focus on fairness. Here's how I'd approach it, considering there's no single "correct" answer, and transparency is key to perceived fairness:
# >
# > **1. Define "Fairness"**
# >
# > * **Utilitarian Approach:** Maximize total value across all individuals.  We'd sum the values each person gets for the goods they receive and aim for the highest total.
# > * **Egalitarian Approach:** Make the allocation as equal as possible. This might not mean everyone gets the same number of goods, but rather that the difference in perceived value between individuals is minimized.
# > * **Envy-Freeness:**  Structure the allocation so no one envies another person's bundle of goods.
# >
# > **2. Analyze the Valuations**
# >
# > Let's represent the valuations in a table:
# >
# > | Good | Person 1 | Person 2 | Person 3 |
# > |---|---|---|---|
# > | A | 48 | 25 | 2  |
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 20
# Unnamed: 0 20
# Tokens 0
# Good A 1
# Good B 2.0
# Good C 3.0
# Good D 3
# > This is a classic example of fair division, complicated by the fact that the goods are indivisible.  Here's how I'd approach finding a "fair" allocation, with my reasoning behind it:
# >
# > **Method: Maximizing Total Value & Addressing Disparities**
# >
# > 1. **Calculate Total Value for Each Person:**  Sum the value each person places on all the goods.
# >
# >    * Person 1: 48 + 4 + 3 + 45 = 100
# >    * Person 2: 25 + 20 + 40 + 15 = 100
# >    * Person 3:  2 +  1 + 45 + 52 = 100
# >
# > 2. **Identify High-Value Allocations:** Look for allocations where a good has a significantly higher value to one person compared to others.
# >
# >    * **Good A:** Person 1 values it significantly higher.
# >    * **Good B:** No major disparity.
# >    * **Good C:** Person 3 values it significantly higher.
# >    * **Good D:** Person 3 values it significantly higher.
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 40
# Unnamed: 0 40
# Tokens 0
# Good A 1
# Good B 2.0
# Good C 3.0
# Good D 3
# > This is a classic fair division problem with indivisible goods! There are many ways to approach fairness, and here's one method with its reasoning and the resulting allocation:
# >
# > **Method: Maximizing Total Value while Considering Individual Preferences**
# >
# > * **Rationale:**  A common approach to fairness is to maximize the overall "happiness" or utility derived from the goods. This means allocating goods to the people who value them the most. However, we also want to be mindful that everyone gets something they find reasonably valuable.
# >
# > * **Procedure:**
# >
# >     1. **Rank the Valuations:** For each good, identify who values it the most, second-most, and so on.
# >
# >     2. **Allocate High-Value Goods:** Start by allocating goods where there's a clear "winner" – someone values it significantly higher than others. This helps ensure high overall satisfaction.
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 81
# Unnamed: 0 81
# Tokens 0
# Good A 1
# Good B nan
# Good C 2.0
# Good D 3
# > This is a classic fair division problem, made more complex by the indivisible nature of the goods. Here's how I'd approach finding a "fair" allocation, acknowledging that fairness is subjective and there are multiple valid approaches:
# >
# > **1. Define "Fairness"**
# >
# > * **Maximize Total Value (Utilitarian Approach):** Allocate goods to maximize the sum of everyone's value for the goods received. This might leave someone unhappy, but ensures the "most good" overall.
# > * **Prioritize Equity (Egalitarian Approach):** Aim to make everyone's received value as close as possible. This might mean not allocating something if it creates a huge disparity.
# > * **Envy-Freeness:**  Try to allocate in a way that no one envies another person's bundle of goods. This is hard to achieve perfectly with indivisible goods.
# >
# > **2. Analyze the Valuations**
# >
# > Let's visualize this in a table:
# >
# ...

# %% [markdown]
# ## $I_7$

# %%
instance = 'question_7'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 66
# Unnamed: 0 66
# Tokens 2130
# Good A 3
# Good B 2
# Good C 1
# Person 1 money 3.0
# Person 2 money 2.0
# Person 3 money 0.0
# > To determine a fair allocation of the three goods (Good A, Good B, Good C) and the available 5 units of money among Person 1, Person 2, and Person 3, we can adopt an approach that seeks to balance the total value received by each individual. Here is one possible fair allocation strategy considering the indivisibility of goods and divisibility of money:
# >
# > **Step 1: Allocate the Goods Based on Highest Value**
# >
# > - **Good A**: This good is valued highest by Person 3 (50), followed by Person 1 (45), and then Person 2 (35). Allocate Good A to Person 3.
# > - **Good B**: This good is valued highest by Person 2 (40), with the next highest value by Person 1 (30). Person 3 values it significantly less (5). Allocate Good B to Person 2.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 57
# Unnamed: 0 57
# Tokens 2232
# Good A 3
# Good B 2
# Good C 3
# Person 1 money 3.0
# Person 2 money 1.0
# Person 3 money 0.0
# > To achieve a fair allocation of the three goods and the five units of money among the three individuals, we should aim to balance the value each individual receives as closely as possible, given their valuation of the goods. Since the goods are indivisible, and the money is divisible, we can adjust money allocations to equalize the overall value received by each person. Here's a step-by-step approach to fairly allocate the goods and money:
# >
# > ### Step 1: Allocate the Goods
# > First, we aim to allocate each good to the person who values it the most:
# > - **Good A** is valued most by Person 3 (50).
# > - **Good B** is valued most by Person 2 (40).
# > - **Good C** is valued similarly by Person 3 (45) and slightly less by Persons 1 (25) and 2 (25).
# >
# > The initial choice is:
# > - Person 3 gets Good A.
# > - Person 2 gets Good B.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 81
# Unnamed: 0 81
# Tokens 2039
# Good A 3
# Good B 2
# Good C 3
# Person 1 money 3.0
# Person 2 money 1.0
# Person 3 money 1.0
# > An equitable and fair allocation of goods among the individuals involves balancing the overall utility or satisfaction each individual gains from the goods, and possibly using the money to adjust for any perceived imbalances. We need to consider the preferences of each person for each good and attempt to maximize their satisfaction while maintaining fairness.
# >
# > ### Step-by-Step Breakdown of Allocation:
# >
# > **1. Review Individual Preferences:**
# >    - **Person 1:** Values Good A at 45, Good B at 30, Good C at 25.
# >    - **Person 2:** Values Good A at 35, Good B at 40, Good C at 25.
# >    - **Person 3:** Values Good A at 50, Good B at 5, Good C at 45.
# >
# > **2. Initial Observation:**
# ...

# %% [markdown]
# # GPT-4o

# %%
family = 'chatgpt'
model = 'gpt-4o'

# %% [markdown]
# ## $I_2$

# %%
instance = 'question_2'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = 79
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        # exp = to_markdown(responses.iloc[index][col])
        responses.iloc[index][col]
        with open("options.md", "w") as file:
            # Write the text to the file
            file.write(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 96
# Unnamed: 0 96
# Tokens 1784
# Good A 2.0
# Good B 1
# Good C 3.0
# Good D 1.0

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 96
# Unnamed: 0 96
# Tokens 1784
# Good A 2.0
# Good B 1
# Good C 3.0
# Good D 1.0
# > To determine the fairest allocation of goods among Person 1, Person 2, and Person 3 given the provided values, I will consider a few fairness criteria, such as maximizing total utility and ensuring each person receives goods that provide high personal value.
# >
# > ### Step-by-Step Analysis
# >
# > #### 1. List the values for each good:
# > - **Person 1:** A = 5, B = 47, C = 45, D = 3
# > - **Person 2:** A = 45, B = 5, C = 48, D = 2
# > - **Person 3:** A = 23, B = 25, C = 32, D = 20
# >
# > #### 2. Intuitive allocation based on highest value:
# >
# > - **Good A:** Person 2 (45)
# > - **Good B:** Person 1 (47)
# > - **Good C:** Person 2 (48)
# > - **Good D:** Person 3 (20)
# >
# > *Note: This allocation seems unfair because Person 1 only gets one high-value item while Person 2 gets two high-value items.*
# >
# > #### 3. Alternative allocation considering fairness:
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 60
# Unnamed: 0 60
# Tokens 2022
# Good A 2.0
# Good B 3
# Good C 1.0
# Good D 3.0
# > In this scenario, determining the fairest allocation of goods can be quite subjective because fairness can be interpreted in various ways. One common approach to fair allocation is to ensure that each person's perceived value of the goods they receive is as close as possible to others' perceived values. This method tries to balance the overall satisfaction of all individuals involved.
# >
# > Given the values each person assigns to the goods, let's evaluate a fair allocation:
# >
# > 1. **Person 1's values:**
# >    - Good A: 5
# >    - Good B: 47
# >    - Good C: 45
# >    - Good D: 3
# >
# > 2. **Person 2's values:**
# >    - Good A: 45
# >    - Good B: 5
# >    - Good C: 48
# >    - Good D: 2
# >
# > 3. **Person 3's values:**
# >    - Good A: 23
# >    - Good B: 25
# >    - Good C: 32
# >    - Good D: 20
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 82
# Unnamed: 0 82
# Tokens 2037
# Good A 2.0
# Good B 3
# Good C 1.0
# Good D 3.0
# > To determine a fair allocation of the goods (A, B, C, D) among the three individuals while maximizing fairness, one common approach is to utilize the concept of maximizing the minimum value each person receives or ensuring an equitably efficient allocation. Given the indivisibility of goods and the personal valuations provided, let's first look at each individual's total value of the goods:
# >
# > - **Person 1:** A = 5, B = 47, C = 45, D = 3, Total = 5 + 47 + 45 + 3 = 100
# > - **Person 2:** A = 45, B = 5, C = 48, D = 2, Total = 45 + 5 + 48 + 2 = 100
# > - **Person 3:** A = 23, B = 25, C = 32, D = 20, Total = 23 + 25 + 32 + 20 = 100
# >
# > One way to approach fairness is to ensure that each person gets a high-value item that they particularly care about while balancing the overall allocation such that one person does not receive outsize value compared to the others.
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 42
# Unnamed: 0 42
# Tokens 2209
# Good A 2.0
# Good B 1
# Good C 3.0
# Good D 3.0
# > To determine a fair allocation of the 4 goods among the 3 individuals, we need to consider several fairness principles. Common fairness criteria include:
# >
# > 1. **Efficiency** (i.e., no good should be thrown away if it has value to any person).
# > 2. **Envy-freeness** (i.e., each person should feel that their allocation is at least as good as anyone else's).
# > 3. **Equitability** (i.e., the allocations should aim to give each person as equal a share of total value as possible).
# >
# > Given the values each person places on each good, we can try to allocate the goods aiming to maximize these principles.
# >
# > Here are the values again for reference:
# > - Person 1: A=5, B=47, C=45, D=3
# > - Person 2: A=45, B=5, C=48, D=2
# > - Person 3: A=23, B=25, C=32, D=20
# >
# > ### Step-by-Step Allocation
# >
# > 1. **Good B**:
# >    - Valuations: Person 1 = 47, Person 2 = 5, Person 3 = 25
# ...

# %% [markdown]
# ### Top5

# %%
variation = 'word_top5.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 35
# Unnamed: 0 35
# Tokens 2378
# Good A 2
# Good B 3.0
# Good C 1
# Good D 3
# > To determine the fairest allocation, we should consider the values each person assigns to the goods they receive in each allocation. Fairness can generally be interpreted as ensuring that the allocation is as balanced as possible in terms of the total value each person perceives they receive.
# >
# > Let's compute the total value each person receives in each allocation:
# >
# > ### Allocation-1:
# > - **Person 1:** Good B = 47
# > - **Person 2:** Good C = 48
# > - **Person 3:** Good A + Good D = 23 + 20 = 43
# >
# > Total values:
# > - Person 1: 47
# > - Person 2: 48
# > - Person 3: 43
# >
# > ### Allocation-2:
# > - **Person 1:** Good C = 45
# > - **Person 2:** Good A = 45
# > - **Person 3:** Good B + Good D = 25 + 20 = 45
# >
# > Total values:
# > - Person 1: 45
# > - Person 2: 45
# > - Person 3: 45
# >
# > ### Allocation-3:
# > - **Person 1:** Good B = 47
# > - **Person 2:** Good A = 45
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 15
# Unnamed: 0 15
# Tokens 2262
# Good A 2
# Good B 3.0
# Good C 1
# Good D 3
# > To determine the fairest allocation among the options provided, we need to evaluate each allocation based on the total value each person receives. Then we can compare the allocations to see which one provides the most balanced and fair distribution of total value.
# >
# > First, calculate the total values each person receives for each allocation:
# >
# > **Allocation-1:**
# > - Person 1: Good B (47)
# > - Person 2: Good C (48)
# > - Person 3: Good A (23) + Good D (20) = 43
# >
# > **Allocation-2:**
# > - Person 1: Good C (45)
# > - Person 2: Good A (45)
# > - Person 3: Good B (25) + Good D (20) = 45
# >
# > **Allocation-3:**
# > - Person 1: Good B (47)
# > - Person 2: Good A (45)
# > - Person 3: Good C (32) + Good D (20) = 52
# >
# > **Allocation-4:**
# > - Person 1: Good B (47)
# > - Person 2: Good A (45) + Good C (48) = 93
# > - Person 3: Good D (20)
# >
# > **Allocation-5:**
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 23
# Unnamed: 0 23
# Tokens 2167
# Good A 2
# Good B 3.0
# Good C 1
# Good D 3
# > To determine the fairest allocation of the goods among Person 1, Person 2, and Person 3, we should consider their valuations for each good to ensure that the total value received by each person is as balanced as possible. Here's a breakdown of each option:
# >
# > **Allocation-1:**
# > - Person 1 gets Good B: Value = 47
# > - Person 2 gets Good C: Value = 48
# > - Person 3 gets Goods A and D: Value = 23 + 20 = 43
# >
# > **Allocation-2:**
# > - Person 1 gets Good C: Value = 45
# > - Person 2 gets Good A: Value = 45
# > - Person 3 gets Goods B and D: Value = 25 + 20 = 45
# >
# > **Allocation-3:**
# > - Person 1 gets Good B: Value = 47
# > - Person 2 gets Good A: Value = 45
# > - Person 3 gets Goods C and D: Value = 32 + 20 = 52
# >
# > **Allocation-4:**
# > - Person 1 gets Good B: Value = 47
# > - Person 2 gets Goods A and C: Value = 45 + 48 = 93
# > - Person 3 gets Good D: Value = 20
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 64
# Unnamed: 0 64
# Tokens 2406
# Good A 2
# Good B 3.0
# Good C 1
# Good D 3
# > To determine the fairest allocation of the goods, we can consider different fairness criteria, such as maximizing the total value derived by all individuals, ensuring each person receives a relatively fair share, and preventing any individual from feeling unfairly treated with respect to others.
# >
# > Let's analyze each allocation in terms of individuals' total values:
# >
# > ### Allocation-1:
# > - **Person 1** gets Good B: Value = 47
# > - **Person 2** gets Good C: Value = 48
# > - **Person 3** gets Goods A and D: Value = 23 + 20 = 43
# > - **Total Value** = 47 + 48 + 43 = 138
# >
# > ### Allocation-2:
# > - **Person 1** gets Good C: Value = 45
# > - **Person 2** gets Good A: Value = 45
# > - **Person 3** gets Goods B and D: Value = 25 + 20 = 45
# > - **Total Value** = 45 + 45 + 45 = 135
# >
# > ### Allocation-3:
# > - **Person 1** gets Good B: Value = 47
# ...

# %% [markdown]
# ### Options (explanations)

# %%
variation = 'word_options.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 8
# Unnamed: 0 8
# Tokens 3036
# Good A 2
# Good B 3.0
# Good C 1
# Good D 3
# > In determining which option is the fairest, several fairness principles can be taken into account, such as envy-freeness, the maximin principle, Pareto-optimality, and equitability. Here's a breakdown of each option considering these principles:
# >
# > 1. **Option 1**:
# >     - **Properties**: Envy-free, Pareto-optimal.
# >     - Payoffs: Person 1: 47, Person 2: 48, Person 3: 43.
# >     - **Rationale**: Since this allocation is envy-free, no person prefers someone else's allocation over their own. Being Pareto-optimal means that no other allocation can make someone better off without making someone else worse off.
# >
# > 2. **Option 2**:
# >     - **Properties**: Equitable, satisfies the maximin principle.
# >     - Payoffs: Each person gets 45.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 93
# Unnamed: 0 93
# Tokens 3309
# Good A 2
# Good B 3.0
# Good C 1
# Good D 3
# > Selecting the fairest allocation among the given options largely depends on the fairness criterion being prioritized. Here, we have a few different criteria highlighted: envy-freeness, equity, maximin principle, and Pareto optimality. Let's consider these criteria thoroughly:
# >
# > 1. **Envy-Free and Pareto-Optimal (Option 1)**
# >     - Allocation: Person 1 gets Good B, Person 2 gets Good C, and Person 3 gets Goods A and D.
# >     - Payoffs: P1: 47, P2: 48, P3: 43.
# >     - This allocation ensures no one envies another, potentially indicating high fairness perception among participants. It also ensures there is no better allocation that would make at least one person better without making anyone worse off.
# >
# > 2. **Equitable and Maximin (Option 2)**
# >     - Allocation: Person 1 gets Good C, Person 2 gets Good A, and Person 3 gets Goods B and D.
# >     - Payoffs: Each gets 45.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 7
# Unnamed: 0 7
# Tokens 3598
# Good A 3
# Good B 1.0
# Good C 2
# Good D 3
# > Determining the fairest allocation depends on how one defines fairness, as different fairness criteria might lead to different preferred allocations. Let's analyze the given options with respect to various fairness criteria (envy-freeness, Pareto-optimality, equity, maximin principle, and total utility maximization) to determine the fairest allocation.
# >
# > ### Option 1:
# > - **Allocation**: Person 1 gets Good B, Person 2 gets Good C, and Person 3 gets Goods A and D.
# > - **Payoffs**: Person 1: 47 units, Person 2: 48 units, Person 3: 43 units.
# > - **Properties**:
# >   - **Envy-free**: No individual envies another for their allocation.
# >   - **Pareto-optimal**: No reallocation can make someone better off without making someone else worse off.
# >
# > **Pros**:
# > - Ensures no one is envious.
# > - Pareto-optimality means the allocation is efficient.
# >
# > **Cons**:
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 92
# Unnamed: 0 92
# Tokens 3005
# Good A 2
# Good B 3.0
# Good C 1
# Good D 3
# > In evaluating fairness, it's important to consider various criteria, including envy-freeness, Pareto-optimality, equity, maximization of minimum payoffs (maximin principle), and total utility. Here's a brief analysis of the given options:
# >
# > 1. **Option 1** has an envy-free and Pareto-optimal allocation. Person 1 gets 47 units of utility, Person 2 gets 48, and Person 3 gets 43. The envy-free property ensures that no one wishes to have someone else's allocation, which is a strong indicator of fairness.
# >
# > 2. **Option 2** offers an equitable allocation with each person getting the same utility, i.e., 45 units. It also satisfies the maximin principle, which means that it ensures perfect equality and maximizes the smallest utility someone gets. Equity and equality might be seen as highly fair by some because it treats everyone the same.
# >
# ...

# %% [markdown]
# ## $I_{19}$

# %%
instance = 'question_19'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 10
# Unnamed: 0 10
# Tokens 2067
# Good A 1.0
# Good B 2.0
# Good C nan
# > Determining a fair allocation of goods among individuals can be complex, particularly when goods are indivisible and individuals have different valuations for these goods. Various fairness criteria can be used to guide the allocation, such as equality, efficiency (maximizing total value), envy-freeness (no one should prefer someone else's allocation over their own), and equitability. Let's explore a few possible approaches based on these criteria:
# >
# > 1. **Maximize Total Value (Efficiency)**: The idea here is to allocate the goods in such a way that the combined value across all individuals is maximized.
# >
# >     - Person 1 values:
# >         - Good A: 45
# >         - Good B: 20
# >         - Good C: 35
# >         - Total potential value: 45 + 20 + 35 = 100
# >     - Person 2 values:
# >         - Good A: 35
# >         - Good B: 40
# >         - Good C: 25
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 26
# Unnamed: 0 26
# Tokens 1656
# Good A 1.0
# Good B 2.0
# Good C nan
# > Allocating goods fairly, especially when they are indivisible, can be challenging because it often involves balancing the total values that individuals receive. Since fairness can be subjective and context-dependent, I will try to allocate the goods in a way that maximizes the total value received by each individual while attempting to ensure that the allocation is as balanced as possible.
# >
# > Here are the values again for quick reference:
# >
# > - Person 1: Good A = 45, Good B = 20, Good C = 35
# > - Person 2: Good A = 35, Good B = 40, Good C = 25
# >
# > Let's evaluate different allocation scenarios:
# >
# > ### Allocation 1:
# > - **Person 1 receives Good A**
# > - **Person 2 receives Good B**
# > - **No allocation for Good C**
# >
# > - Person 1's total value: 45
# > - Person 2's total value: 40
# >
# > Difference in value: \( |45 - 40| = 5 \)
# >
# > ### Allocation 2:
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 50
# Unnamed: 0 50
# Tokens 2930
# Good A 1.0
# Good B 2.0
# Good C nan
# > To determine a fair allocation of the goods among Person 1 and Person 2, we need to consider the value each person places on each good. A fair allocation should ideally maximize the total utility (sum of values) and aim for equity between the individuals. Here’s how we can approach this:
# >
# > ### Allocation Based on Maximizing Total Utility
# >
# > 1. **Calculate the total values person-by-person:**
# >    - Person 1: A (45), B (20), C (35)
# >    - Person 2: A (35), B (40), C (25)
# >
# > 2. **Consider all possible allocations of the three goods:**
# >
# >    The possibilities are:
# >    - Person 1 gets A, Person 2 gets B, Person 1 gets C
# >    - Person 1 gets A, Person 2 gets B, Person 2 gets C
# >    - Person 1 gets A, Person 1 gets B, Person 2 gets C
# >    - Person 2 gets A, Person 1 gets B, Person 2 gets C
# >    - Person 2 gets A, Person 2 gets B, Person 1 gets C
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 6
# Unnamed: 0 6
# Tokens 2373
# Good A 2.0
# Good B 3
# Good C 1.0
# Good D nan
# > To determine a fair allocation of the goods among the three individuals, I will use the principle of maximizing the total value for each person. This is often known as the "utilitarian" approach, where we aim to maximize the sum of the values for each individual.
# >
# > The values each person places on each good are as follows:
# > - Person 1's values: A=5, B=47, C=45, D=3
# > - Person 2's values: A=45, B=5, C=48, D=2
# > - Person 3's values: A=23, B=25, C=32, D=20
# >
# > We need to allocate the goods such that the total value for each person is as high as possible. To begin, let's consider all possible allocations and their respective values:
# >
# > 1. **Allocation 1:**
# >     - Person 1: Good B (47)
# >     - Person 2: Good C (48)
# >     - Person 3: Good D (20)
# >     - Total value: 47 + 48 + 20 = 115
# >
# > 2. **Allocation 2:**
# >     - Person 1: Good C (45)
# ...

# %% [markdown]
# ### Top5

# %%
variation = 'word_top5.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 35
# Unnamed: 0 35
# Tokens 2378
# Good A 2
# Good B 3.0
# Good C 1
# Good D 3
# > To determine the fairest allocation, we should consider the values each person assigns to the goods they receive in each allocation. Fairness can generally be interpreted as ensuring that the allocation is as balanced as possible in terms of the total value each person perceives they receive.
# >
# > Let's compute the total value each person receives in each allocation:
# >
# > ### Allocation-1:
# > - **Person 1:** Good B = 47
# > - **Person 2:** Good C = 48
# > - **Person 3:** Good A + Good D = 23 + 20 = 43
# >
# > Total values:
# > - Person 1: 47
# > - Person 2: 48
# > - Person 3: 43
# >
# > ### Allocation-2:
# > - **Person 1:** Good C = 45
# > - **Person 2:** Good A = 45
# > - **Person 3:** Good B + Good D = 25 + 20 = 45
# >
# > Total values:
# > - Person 1: 45
# > - Person 2: 45
# > - Person 3: 45
# >
# > ### Allocation-3:
# > - **Person 1:** Good B = 47
# > - **Person 2:** Good A = 45
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 15
# Unnamed: 0 15
# Tokens 2262
# Good A 2
# Good B 3.0
# Good C 1
# Good D 3
# > To determine the fairest allocation among the options provided, we need to evaluate each allocation based on the total value each person receives. Then we can compare the allocations to see which one provides the most balanced and fair distribution of total value.
# >
# > First, calculate the total values each person receives for each allocation:
# >
# > **Allocation-1:**
# > - Person 1: Good B (47)
# > - Person 2: Good C (48)
# > - Person 3: Good A (23) + Good D (20) = 43
# >
# > **Allocation-2:**
# > - Person 1: Good C (45)
# > - Person 2: Good A (45)
# > - Person 3: Good B (25) + Good D (20) = 45
# >
# > **Allocation-3:**
# > - Person 1: Good B (47)
# > - Person 2: Good A (45)
# > - Person 3: Good C (32) + Good D (20) = 52
# >
# > **Allocation-4:**
# > - Person 1: Good B (47)
# > - Person 2: Good A (45) + Good C (48) = 93
# > - Person 3: Good D (20)
# >
# > **Allocation-5:**
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 23
# Unnamed: 0 23
# Tokens 2167
# Good A 2
# Good B 3.0
# Good C 1
# Good D 3
# > To determine the fairest allocation of the goods among Person 1, Person 2, and Person 3, we should consider their valuations for each good to ensure that the total value received by each person is as balanced as possible. Here's a breakdown of each option:
# >
# > **Allocation-1:**
# > - Person 1 gets Good B: Value = 47
# > - Person 2 gets Good C: Value = 48
# > - Person 3 gets Goods A and D: Value = 23 + 20 = 43
# >
# > **Allocation-2:**
# > - Person 1 gets Good C: Value = 45
# > - Person 2 gets Good A: Value = 45
# > - Person 3 gets Goods B and D: Value = 25 + 20 = 45
# >
# > **Allocation-3:**
# > - Person 1 gets Good B: Value = 47
# > - Person 2 gets Good A: Value = 45
# > - Person 3 gets Goods C and D: Value = 32 + 20 = 52
# >
# > **Allocation-4:**
# > - Person 1 gets Good B: Value = 47
# > - Person 2 gets Goods A and C: Value = 45 + 48 = 93
# > - Person 3 gets Good D: Value = 20
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 64
# Unnamed: 0 64
# Tokens 2406
# Good A 2
# Good B 3.0
# Good C 1
# Good D 3
# > To determine the fairest allocation of the goods, we can consider different fairness criteria, such as maximizing the total value derived by all individuals, ensuring each person receives a relatively fair share, and preventing any individual from feeling unfairly treated with respect to others.
# >
# > Let's analyze each allocation in terms of individuals' total values:
# >
# > ### Allocation-1:
# > - **Person 1** gets Good B: Value = 47
# > - **Person 2** gets Good C: Value = 48
# > - **Person 3** gets Goods A and D: Value = 23 + 20 = 43
# > - **Total Value** = 47 + 48 + 43 = 138
# >
# > ### Allocation-2:
# > - **Person 1** gets Good C: Value = 45
# > - **Person 2** gets Good A: Value = 45
# > - **Person 3** gets Goods B and D: Value = 25 + 20 = 45
# > - **Total Value** = 45 + 45 + 45 = 135
# >
# > ### Allocation-3:
# > - **Person 1** gets Good B: Value = 47
# ...

# %% [markdown]
# ### Options (explanations)

# %%
variation = 'word_options.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 8
# Unnamed: 0 8
# Tokens 3036
# Good A 2
# Good B 3.0
# Good C 1
# Good D 3
# > In determining which option is the fairest, several fairness principles can be taken into account, such as envy-freeness, the maximin principle, Pareto-optimality, and equitability. Here's a breakdown of each option considering these principles:
# >
# > 1. **Option 1**:
# >     - **Properties**: Envy-free, Pareto-optimal.
# >     - Payoffs: Person 1: 47, Person 2: 48, Person 3: 43.
# >     - **Rationale**: Since this allocation is envy-free, no person prefers someone else's allocation over their own. Being Pareto-optimal means that no other allocation can make someone better off without making someone else worse off.
# >
# > 2. **Option 2**:
# >     - **Properties**: Equitable, satisfies the maximin principle.
# >     - Payoffs: Each person gets 45.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 93
# Unnamed: 0 93
# Tokens 3309
# Good A 2
# Good B 3.0
# Good C 1
# Good D 3
# > Selecting the fairest allocation among the given options largely depends on the fairness criterion being prioritized. Here, we have a few different criteria highlighted: envy-freeness, equity, maximin principle, and Pareto optimality. Let's consider these criteria thoroughly:
# >
# > 1. **Envy-Free and Pareto-Optimal (Option 1)**
# >     - Allocation: Person 1 gets Good B, Person 2 gets Good C, and Person 3 gets Goods A and D.
# >     - Payoffs: P1: 47, P2: 48, P3: 43.
# >     - This allocation ensures no one envies another, potentially indicating high fairness perception among participants. It also ensures there is no better allocation that would make at least one person better without making anyone worse off.
# >
# > 2. **Equitable and Maximin (Option 2)**
# >     - Allocation: Person 1 gets Good C, Person 2 gets Good A, and Person 3 gets Goods B and D.
# >     - Payoffs: Each gets 45.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 7
# Unnamed: 0 7
# Tokens 3598
# Good A 3
# Good B 1.0
# Good C 2
# Good D 3
# > Determining the fairest allocation depends on how one defines fairness, as different fairness criteria might lead to different preferred allocations. Let's analyze the given options with respect to various fairness criteria (envy-freeness, Pareto-optimality, equity, maximin principle, and total utility maximization) to determine the fairest allocation.
# >
# > ### Option 1:
# > - **Allocation**: Person 1 gets Good B, Person 2 gets Good C, and Person 3 gets Goods A and D.
# > - **Payoffs**: Person 1: 47 units, Person 2: 48 units, Person 3: 43 units.
# > - **Properties**:
# >   - **Envy-free**: No individual envies another for their allocation.
# >   - **Pareto-optimal**: No reallocation can make someone better off without making someone else worse off.
# >
# > **Pros**:
# > - Ensures no one is envious.
# > - Pareto-optimality means the allocation is efficient.
# >
# > **Cons**:
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 92
# Unnamed: 0 92
# Tokens 3005
# Good A 2
# Good B 3.0
# Good C 1
# Good D 3
# > In evaluating fairness, it's important to consider various criteria, including envy-freeness, Pareto-optimality, equity, maximization of minimum payoffs (maximin principle), and total utility. Here's a brief analysis of the given options:
# >
# > 1. **Option 1** has an envy-free and Pareto-optimal allocation. Person 1 gets 47 units of utility, Person 2 gets 48, and Person 3 gets 43. The envy-free property ensures that no one wishes to have someone else's allocation, which is a strong indicator of fairness.
# >
# > 2. **Option 2** offers an equitable allocation with each person getting the same utility, i.e., 45 units. It also satisfies the maximin principle, which means that it ensures perfect equality and maximizes the smallest utility someone gets. Equity and equality might be seen as highly fair by some because it treats everyone the same.
# >
# ...

# %% [markdown]
# ## $I_3$

# %%
instance = 'question_3'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 21
# Unnamed: 0 21
# Tokens 2159
# Good A 1
# Good B 2.0
# Good C 3
# Good D 2
# Good E 3.0
# > The challenge of allocating these goods fairly among Person 1, Person 2, and Person 3 can be approached from various perspectives. One common objective is to maximize the total value each person receives, while another is to minimize envy or ensure that no one feels that someone else has a significantly better allocation.
# >
# > ### Approach: Maximin Value (Fair Distribution)
# >
# > Let's try to ensure that each person receives the highest possible minimum value (maximin value principle). We'll aim to distribute goods such that the person with the least value gets the highest possible minimum value.
# >
# > #### Step-by-Step Allocation:
# >
# > 1. **Initialization**:
# >     - List the goods and the values each person assigns to these goods.
# >
# > 2. **Sort and Assign**:
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 80
# Unnamed: 0 80
# Tokens 2504
# Good A 1
# Good B 2.0
# Good C 3
# Good D 2
# Good E 3.0
# > To determine a fair allocation of goods, we can consider several fairness criteria, such as maximizing the total value, ensuring envy-freeness (where no individual prefers another's allocation over their own), or achieving equal value distribution (i.e., minimizing the difference in total value obtained by each individual).
# >
# > Given the values assigned by each person to each good, let's explore potential allocations that strive for balance.
# >
# > **Values:**
# >
# > - Person 1
# >   - Good A: 40
# >   - Good B: 2
# >   - Good C: 3
# >   - Good D: 25
# >   - Good E: 30
# > - Person 2
# >   - Good A: 14
# >   - Good B: 26
# >   - Good C: 8
# >   - Good D: 26
# >   - Good E: 26
# > - Person 3
# >   - Good A: 10
# >   - Good B: 26
# >   - Good C: 26
# >   - Good D: 12
# >   - Good E: 26
# >
# > ### Allocation Attempt
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 59
# Unnamed: 0 59
# Tokens 2716
# Good A 1
# Good B 2.0
# Good C 3
# Good D 1
# Good E 3.0
# > To determine a fair allocation of the goods among Person 1, Person 2, and Person 3, we'll consider the valuations that each person has for each good with the goal of maximizing total satisfaction or minimizing dissatisfaction. Several fairness principles, such as envy-freeness and proportionality, could guide the allocation:
# >
# > 1. **Envy-freeness:** No person should prefer another person's allocation over their own.
# > 2. **Proportionality:** Each person should feel that they receive at least 1/n (in this case, 1/3) of the total value if it were evenly divided.
# >
# > ### Step-by-step Approach:
# > 1. **Calculate the total value each person assigns to all goods.**
# > 2. **Identify possible allocations.**
# > 3. **Evaluate the allocations based on fairness principles.**
# >
# > #### Total Value Calculations:
# > - **Person 1:** 40 (A) + 2 (B) + 3 (C) + 25 (D) + 30 (E) = 100
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 42
# Unnamed: 0 42
# Tokens 2257
# Good A 1
# Good B 2.0
# Good C 3
# Good D 2
# Good E 3.0
# > Determining a fair allocation of the goods involves considering the preferences of all three individuals and ensuring that the goods are distributed in a way that maximizes overall satisfaction or fairness. One common approach to this is to use a fairness criterion like the "Maximin share" or "Envy-free" allocation.
# >
# > Let's take a practical approach to assign each good to the person who values it most while trying to ensure a fair distribution:
# >
# > 1. **Good A:**
# >     - Person 1: 40
# >     - Person 2: 14
# >     - Person 3: 10
# >    Person 1 values Good A the most.
# >
# > 2. **Good B:**
# >     - Person 1: 2
# >     - Person 2: 26
# >     - Person 3: 26
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 76
# Unnamed: 0 76
# Tokens 2007
# Good A 1
# Good B 2.0
# Good C 3
# Good D 1
# Good E 2.0
# > In order to determine a fair allocation, we need to consider methods that balance efficiency (maximizing total value) and fairness (ensuring individuals feel they received a fair share). One popular approach is the "Maximum Nash Welfare" (MNW) method, which tries to maximize the product of the utilities (values) of the allocated goods for each individual. Here's how we can approach it step by step:
# >
# > ### Individual Valuations:
# > - **Person 1**: Good A (40), Good B (2), Good C (3), Good D (25), Good E (30)
# > - **Person 2**: Good A (14), Good B (26), Good C (8), Good D (26), Good E (26)
# > - **Person 3**: Good A (10), Good B (26), Good C (26), Good D (12), Good E (26)
# >
# > ### Step-by-Step Allocation:
# ...

# %% [markdown]
# ## $I_6$

# %%
instance = 'question_6'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 0
# Unnamed: 0 0
# Tokens 2258
# Good A 1
# Good B 2.0
# Good C 3
# Good D 1.0
# > A fair allocation of the goods in this scenario means ensuring that the distribution is equitable based on the values the individuals assign to each good. One approach to achieving fairness is to maximize total value while considering each person's preferences, although other notions of fairness could prioritize equality or envy-freeness.
# >
# > To begin, let's summarize the values each person assigns to the goods:
# > - Person 1: Good A = 48, Good B = 4, Good C = 3, Good D = 45
# > - Person 2: Good A = 25, Good B = 20, Good C = 40, Good D = 15
# > - Person 3: Good A = 2, Good B = 1, Good C = 45, Good D = 52
# >
# > **Approach: Maximizing total value:**
# > We'll start by considering a simple approach: distributing each good to the individual who values it the most.
# >
# > 1. **Good A:**
# >    - Person 1's value: 48
# >    - Person 2's value: 25
# >    - Person 3's value: 2
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 16
# Unnamed: 0 16
# Tokens 2125
# Good A 1
# Good B nan
# Good C 2
# Good D 3.0
# > To determine a fair allocation of the goods among Person 1, Person 2, and Person 3, we need to evaluate different fairness criteria. One commonly used criterion is the **maximin fairness** (maximize the minimum value received by any person), but other criteria like **envy-freeness** and **Pareto efficiency** can also be considered. For this exercise, we will use the maximin fairness criterion to ensure that each person gets as high a minimum value as possible.
# >
# > Here are the values each individual assigns to each good for reference:
# >
# > - **Person 1:**
# >   - **Good A:** 48
# >   - **Good B:** 4
# >   - **Good C:** 3
# >   - **Good D:** 45
# >
# > - **Person 2:**
# >   - **Good A:** 25
# >   - **Good B:** 20
# >   - **Good C:** 40
# >   - **Good D:** 15
# >
# > - **Person 3:**
# >   - **Good A:** 2
# >   - **Good B:** 1
# >   - **Good C:** 45
# >   - **Good D:** 52
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 69
# Unnamed: 0 69
# Tokens 1991
# Good A 1
# Good B 2.0
# Good C 2
# Good D 3.0
# > To determine a fair allocation of the four goods to Person 1, Person 2, and Person 3, we can consider various fairness criteria such as maximizing total value, ensuring envy-freeness (no person prefers another person's allocation to their own), or achieving proportional fairness (each person gets at least 1/3rd of the total value they believe the goods to have).
# >
# > Let's look at the value each person assigns to each good:
# > - **Person 1**: A = 48, B = 4, C = 3, D = 45
# > - **Person 2**: A = 25, B = 20, C = 40, D = 15
# > - **Person 3**: A = 2, B = 1, C = 45, D = 52
# >
# > First, let's sum the total values each person assigns:
# > - **Person 1's total value**: 48 + 4 + 3 + 45 = 100
# > - **Person 2's total value**: 25 + 20 + 40 + 15 = 100
# > - **Person 3's total value**: 2 + 1 + 45 + 52 = 100
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 26
# Unnamed: 0 26
# Tokens 2145
# Good A 1
# Good B nan
# Good C 2
# Good D 3.0
# > Determining a fair allocation of the four goods (A, B, C, and D) among the three individuals (Person 1, Person 2, and Person 3) based on their respective valuations requires considering different fairness criteria. One common criterion is maximizing the total perceived value for all participants (efficiency) while also trying to balance individual satisfaction (equity). Below is an analysis addressing these considerations.
# >
# > **Individuals' Valuations:**
# > - **Person 1:** A = 48, B = 4, C = 3, D = 45
# > - **Person 2:** A = 25, B = 20, C = 40, D = 15
# > - **Person 3:** A = 2, B = 1, C = 45, D = 52
# >
# > **Goals:**
# > 1. **Maximize total value.**
# > 2. **Ensure each person gets a fairly valued share.**
# >
# > ### Potential Allocation
# >
# > **Option 1:**
# >
# > - **Person 1:** Good A (48)
# > - **Person 2:** Good C (40)
# > - **Person 3:** Good D (52)
# ...

# %% [markdown]
# ## $I_7$

# %%
instance = 'question_7'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 79
# Unnamed: 0 79
# Tokens 2012
# Good A 3
# Good B 2
# Good C 1
# Person 1 money 4.0
# Person 2 money 1.0
# Person 3 money 0.0
# > Considering fair allocation principles and the values given by each individual for each good, one method to approach this problem is to maximize the total utility while striving to keep the distribution as balanced as possible. One common concept of fairness is "envy-freeness," which means trying to allocate the goods and the money such that no individual would prefer someone else's allocation over their own.
# >
# > Let's start by evaluating different ways to allocate the goods and then distribute the money to balance any perceived unfairness.
# >
# > ### Step 1: Allocate the Goods
# >
# > **Option 1: Maximize Total Utility**
# >
# > - Good A goes to Person 3 (value: 50)
# > - Good B goes to Person 2 (value: 40)
# > - Good C goes to Person 3 (value: 45)
# >
# > This allocation maximizes the total utility:
# > - Person 1: 0
# > - Person 2: 40
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 17
# Unnamed: 0 17
# Tokens 2150
# Good A 1
# Good B 2
# Good C 3
# Person 1 money 0.0
# Person 2 money 5.0
# Person 3 money 0.0
# > To determine a fair allocation of the goods and money among Person 1, Person 2, and Person 3, I'll consider a few common fairness criteria in allocation problems: maximizing total utility, envy-freeness, and proportional fairness. Given the indivisibility of goods and the divisibility of money, we will use the money as a compensatory mechanism to achieve a fair distribution.
# >
# > Here's one strategy to achieve a fair allocation:
# >
# > 1. Consider the value of each good to each person.
# > 2. Take into account the limited amount of money (5 units) that can help balance the overall fairness.
# >
# > Let's start by considering the total value of the goods to each person:
# >
# > - Person 1's values: Good A: 45, Good B: 30, Good C: 25
# > - Person 2's values: Good A: 35, Good B: 40, Good C: 25
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 30
# Unnamed: 0 30
# Tokens 2455
# Good A 3
# Good B 2
# Good C 1
# Person 1 money 3.5
# Person 2 money 1.0
# Person 3 money 0.5
# > To determine a fair allocation of the goods and money, I will consider several fairness criteria, such as maximizing the overall value and ensuring that each individual receives as fair a share as possible.
# >
# > **Step 1: Listing the valuations of each individual for the goods**
# > - Person 1's valuations: A = 45, B = 30, C = 25
# > - Person 2's valuations: A = 35, B = 40, C = 25
# > - Person 3's valuations: A = 50, B = 5, C = 45
# >
# > **Step 2: Listing each person's rank order preference for the goods**
# > - Person 1 prefers A > B > C
# > - Person 2 prefers B > A > C
# > - Person 3 prefers A > C > B
# >
# > **Step 3: Calculating the total value each person would get if they received their most preferred good**
# > - Person 1 would get: 45 (A)
# > - Person 2 would get: 40 (B)
# > - Person 3 would get: 50 (A)
# >
# ...

# %% [markdown]
# ### Top5

# %%
variation = 'word_top5.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 23
# Unnamed: 0 23
# Tokens 2638
# Good A 1
# Good B 2
# Good C 3
# Person 1 money 0
# Person 2 money 5
# Person 3 money 0
# > To determine the fairest allocation among the given options, we need to evaluate each allocation in terms of fairness criteria, which could include efficiency (such as maximizing the total value for all individuals) and equity (such as ensuring a balanced distribution of value among individuals).
# >
# > Let's calculate the total value each person gets for each allocation:
# >
# > ### Values for Each Allocation
# >
# > #### Allocation-1:
# > - Person 1: Good A (45)
# > - Person 2: Good B (40) + 5 units of money (5) = 45
# > - Person 3: Good C (45)
# >
# > Total values:
# > - Person 1: 45
# > - Person 2: 45
# > - Person 3: 45
# >
# > #### Allocation-2:
# > - Person 1: Good A (45)
# > - Person 2: Good B (40)
# > - Person 3: Good C (45) + 5 units of money (5) = 50
# >
# > Total values:
# > - Person 1: 45
# > - Person 2: 40
# > - Person 3: 50
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 7
# Unnamed: 0 7
# Tokens 2667
# Good A 1
# Good B 2
# Good C 3
# Person 1 money 0
# Person 2 money 5
# Person 3 money 0
# > To determine the fairest allocation, we need to consider both the values that each person assigns to each good (and the money) and strive to distribute the total value as evenly as possible among the three individuals. Let's calculate the total value each person receives in each of the five provided allocations and then compare these values.
# >
# > ### Values Assigned by Each Individual:
# > - **Person 1:**
# >   - Good A: 45
# >   - Good B: 30
# >   - Good C: 25
# > - **Person 2:**
# >   - Good A: 35
# >   - Good B: 40
# >   - Good C: 25
# > - **Person 3:**
# >   - Good A: 50
# >   - Good B: 5
# >   - Good C: 45
# >
# > ### Each Unit of Money is Worth (For Each Person):
# > - 1 unit of money is equivalent to 1 value point.
# >
# > ### Allocations:
# > 1. **Allocation-1:**
# >    - Person 1: Good A = 45
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 87
# Unnamed: 0 87
# Tokens 3051
# Good A 3
# Good B 2
# Good C 3
# Person 1 money 5
# Person 2 money 0
# Person 3 money 0
# > To determine the fairest allocation of goods and money, we need to evaluate each given allocation based on the values assigned by the individuals to the goods and money. We can consider fairness in terms of maximizing the total subjective value for each person.
# >
# > Let's analyze each allocation carefully:
# >
# > ### Person 1's Values:
# > - Good A: 45
# > - Good B: 30
# > - Good C: 25
# > - 1 unit of money = 1 good of the same value (so 5 units of money = 45 in value)
# >
# > ### Person 2's Values:
# > - Good A: 35
# > - Good B: 40
# > - Good C: 25
# > - 1 unit of money = 1 good of the same value (so 5 units of money = 40 in value)
# >
# > ### Person 3's Values:
# > - Good A: 50
# > - Good B: 5
# > - Good C: 45
# > - 1 unit of money = 1 good of the same value (so 5 units of money = 50 in value)
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 27
# Unnamed: 0 27
# Tokens 2713
# Good A 1
# Good B 2
# Good C 3
# Person 1 money 0
# Person 2 money 5
# Person 3 money 0
# > To determine the fairest allocation among the given options, we need to evaluate the resultant total value accrued by each individual under each allocation. Let's break down each allocation and calculate the value for each person.
# >
# > ### Allocation-1:
# > - **Person 1**: Good A (value: 45)
# > - **Person 2**: Good B (value: 40) + 5 units of money (value: 5)
# > - **Person 3**: Good C (value: 45)
# >
# > Total values:
# > - Person 1: 45
# > - Person 2: 40 + 5 = 45
# > - Person 3: 25
# >
# > ### Allocation-2:
# > - **Person 1**: Good A (value: 45)
# > - **Person 2**: Good B (value: 40)
# > - **Person 3**: Good C (value: 45) + 5 units of money (value: 5)
# >
# > Total values:
# > - Person 1: 45
# > - Person 2: 40
# > - Person 3: 45 + 5 = 50
# >
# > ### Allocation-3:
# > - **Person 1**: Good A (value: 45) + 5 units of money (value: 5)
# ...

# %% [markdown]
# # Gemini-1.5

# %%
family = 'gemini'
model = 'Gemini-1.5-Pro'

# %% [markdown]
# ## $I_2$

# %%
instance = 'question_2'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = 21
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 21
# Unnamed: 0 21
# Tokens 0
# Good A 2.0
# Good B 1
# Good C 1.0
# Good D 3.0
# > Here's my approach to determining a fair allocation, along with my reasoning:
# >
# > **Objective:** Maximize overall satisfaction while considering individual preferences and potential for envy.
# >
# > **Analysis:**
# >
# > * **Good A:** Person 2 values Good A significantly higher than anyone else (45 vs. 5 and 23). Allocating Good A to Person 2 seems like the most impactful choice.
# > * **Good B:** Person 1 has a strong preference for Good B (47 vs. 5 and 25), making them the clear choice for this good.
# > * **Good C:** This is where it gets tricky. Both Person 2 (48) and Person 1 (45) value it highly.  Person 3's valuation is significantly lower.
# > * **Good D:**  No one places exceptionally high value on Good D. Person 3 has the highest valuation (20), but it's not drastically different from others.
# >
# > **Possible Allocation Scenarios:**
# >
# > **Scenario 1: Maximize Total Value**
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 94
# Unnamed: 0 94
# Tokens 0
# Good A nan
# Good B 1
# Good C 2.0
# Good D 3.0
# > Here's how I'd approach finding a "fair" allocation, along with the allocation I'd choose based on these principles:
# >
# > **Principles of Fairness:**
# >
# > * **Maximize Total Value (Efficiency):** A fair allocation should aim to give the goods to those who value them most, thereby maximizing the overall "happiness" or utility derived from the goods.
# > * **Consider Individual Preferences:**  Fairness isn't just about the total; it's about recognizing individual desires.  Even if a person doesn't have the absolute highest value for a good, we should consider if it would be particularly meaningful to them.
# > * **Avoid Envy (Where Possible):** Ideally, no one should feel like they'd be strictly better off with another person's allocation.
# >
# > **Analyzing the Values:**
# >
# > Let's represent the values in a table:
# >
# > | Good | Person 1 | Person 2 | Person 3 |
# > |---|---|---|---|
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 48
# Unnamed: 0 48
# Tokens 0
# Good A 2.0
# Good B 1
# Good C 3.0
# Good D 3.0
# > This is a classic resource allocation problem with a fairness objective.  There are many ways to define "fairest," so I'll present a couple of common approaches and the resulting allocations:
# >
# > **1. Maximize Total Value (Utilitarian Approach)**
# >
# > * This approach aims to maximize the overall satisfaction across all individuals. We allocate each good to the person who values it most.
# >
# >     * **Good A:** Person 2 (Value 45)
# >     * **Good B:** Person 1 (Value 47)
# >     * **Good C:** Person 2 (Value 48)
# >     * **Good D:** Person 3 (Value 20)
# >
# > * **Outcome:** This allocation might seem unfair at first glance because Person 2 receives two goods while Person 3 only receives one. However, it maximizes the total value derived from the goods (45+47+48+20 = 160).
# >
# > **2.  Maximize the Minimum Value Received (Maximin Approach)**
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 4
# Unnamed: 0 4
# Tokens 0
# Good A 3.0
# Good B 1
# Good C 2.0
# Good D nan
# > This is a classic resource allocation problem with no single "fairest" solution, as fairness itself can be interpreted in many ways. Here's a breakdown of the problem and some allocation approaches with their own fairness considerations:
# >
# > **Understanding the Problem**
# >
# > * **Indivisible Goods:** You can't split the goods. Each goes entirely to one person or is discarded.
# > * **Subjective Value:** Each person has different preferences, making some goods more valuable to them than others.
# > * **Fairness:**  This is subjective and open to interpretation. Do you prioritize maximizing total happiness, ensuring everyone gets something they want, or something else entirely?
# >
# > **Possible Allocation Approaches**
# >
# > Here are a few common fairness-driven approaches and how they might apply:
# >
# > 1. **Maximizing Total Value (Utilitarian Approach):**
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 27
# Unnamed: 0 27
# Tokens 0
# Good A nan
# Good B 1
# Good C 2.0
# Good D 3.0
# > Here's how I would approach finding a "fair" allocation, along with my proposed solution:
# >
# > **Principles of Fairness**
# >
# > Since fairness is subjective, let's define some principles to guide our allocation:
# >
# > 1. **Maximize Total Value:**  A fair allocation should aim to maximize the overall satisfaction or utility derived from the goods.  We can do this by summing the individual values each person has for the goods they receive.
# > 2. **Prioritize High Value:** Goods should ideally go to the individuals who place the highest value on them.
# > 3. **Avoid Extremes:**  We should try to avoid scenarios where one person receives a disproportionately large share of the total value.
# >
# > **Analyzing the Values**
# >
# > Let's visualize the values in a table:
# >
# > | Good | Person 1 | Person 2 | Person 3 |
# > |---|---|---|---|
# > | A | 5  | **45** | 23 |
# ...

# %% [markdown]
# ## $I_3$

# %%
instance = 'question_3'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 14
# Unnamed: 0 14
# Tokens 0
# Good A 1
# Good B 3.0
# Good C 3
# Good D 2.0
# Good E nan
# > Here's how I'd approach finding a fair allocation, along with the allocation I think is fairest based on the given information:
# >
# > **Reasoning:**
# >
# > * **Maximize Total Value:** A fair allocation should aim to create the most overall happiness or utility. This means trying to give the goods to the people who value them the most.
# > * **Consider Equity:**  While maximizing total value is important, we should avoid allocations where one person gets a vastly disproportionate amount of value compared to others.
# >
# > **Analysis:**
# >
# > Let's represent the values in a table for easier comparison:
# >
# > | Good | Person 1 | Person 2 | Person 3 |
# > |---|---|---|---|
# > | A | 40 | 14 | 10 |
# > | B | 2  | 26 | 26 |
# > | C | 3  | 8  | 26 |
# > | D | 25 | 26 | 12 |
# > | E | 30 | 26 | 26 |
# >
# > * **Good A:** Person 1 clearly values Good A the most (40).
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 62
# Unnamed: 0 62
# Tokens 0
# Good A 1
# Good B 2
# Good C 3
# Good D 1
# Good E 3
# > This is a classic allocation problem with no single "fairest" solution, as fairness can be interpreted in different ways. Here's how we can approach this, considering a few common fairness principles:
# >
# > **1. Understanding the Values**
# >
# > First, let's visualize the values in a table:
# >
# > | Good | Person 1 | Person 2 | Person 3 |
# > |---|---|---|---|
# > | A | 40 | 14 | 10 |
# > | B | 2 | 26 | 26 |
# > | C | 3 | 8  | 26 |
# > | D | 25 | 26 | 12 |
# > | E | 30 | 26 | 26 |
# >
# > **2. Fairness Principles**
# >
# > Here are some fairness principles we can consider:
# >
# > * **Maximizing Total Value (Utilitarianism):**  Allocate goods to maximize the sum of everyone's valuations, regardless of individual satisfaction.
# > * **Prioritizing the Worst-Off (Egalitarianism):** Aim for an allocation where the person with the lowest total value receives as much value as possible.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 87
# Unnamed: 0 87
# Tokens 0
# Good A 1
# Good B 2
# Good C 3
# Good D 3
# Good E 2
# > This is a classic resource allocation problem with a focus on fairness. Since there's no single "correct" answer, I'll present a few common approaches and the resulting allocations:
# >
# > **1. Maximizing Total Value:**
# >
# > * **Goal:**  Allocate goods to maximize the sum of values across all individuals. This approach aims for the most "efficient" outcome in terms of overall satisfaction.
# >
# > * **Calculation:**
# >     * Good A: Person 1 (40)
# >     * Good B: Person 2 or 3 (both value it at 26)
# >     * Good C: Person 2 or 3 (both value it at 26)
# >     * Good D: Person 1 or 2 (both value it at 26, but Person 1 gets a higher total value)
# >     * Good E: Person 1, 2, or 3 (all value it at 26)
# >
# > * **Possible Allocation:**
# >     * Person 1: Good A, Good D
# >     * Person 2: Good B
# >     * Person 3: Good C
# >     * Good E: Not allocated (or randomly assigned)
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 3
# Unnamed: 0 3
# Tokens 0
# Good A 1
# Good B 3
# Good C 3
# Good D 2
# Good E nan
# > This is a classic fair division problem with indivisible goods! There are many ways to approach fairness, and no single "correct" answer. Here's a breakdown of a few methods and how they apply to this scenario, along with my proposed solution:
# >
# > **Methods to Consider:**
# >
# > * **Envy-Freeness:** An allocation is envy-free if no one would rather have someone else's bundle of goods over their own. This is difficult to achieve perfectly with indivisible goods.
# > * **Pareto Efficiency:** An allocation is Pareto efficient if it's impossible to make one person better off without making someone else worse off.
# > * **Maximin Share:**  This aims to guarantee each person receives a bundle they value at least as much as what they'd get if they could divide the goods into equal shares themselves and then other people chose their shares first.
# ...

# %% [markdown]
# ## $I_4$

# %%
instance = 'question_4'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 11
# Unnamed: 0 11
# Tokens 0
# Good A 2
# Good B 1
# Good C 3
# Good D nan
# > This is a classic problem in economics and social choice theory, highlighting the difficulties in defining and achieving "fairness".  Here's my approach to allocating the goods, along with my reasoning:
# >
# > **Proposed Allocation:**
# >
# > * **Person 1:** Good B
# > * **Person 2:** Good A
# > * **Person 3:** Good C
# > * **Good D:** Unallocated
# >
# > **Reasoning:**
# >
# > 1. **Maximize Total Value:**  A fair allocation should aim to create the highest total value across all individuals. This suggests allocating each good to the person who values it most.
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 62
# Unnamed: 0 62
# Tokens 0
# Good A 2
# Good B 1
# Good C 3
# Good D 1
# > This is a classic resource allocation problem with a fairness constraint! There are many ways to approach this, and each reflects a different idea of "fairness". Here are a few approaches and how I'd apply them:
# >
# > **1. Maximize Total Value (Utilitarian Approach)**
# >
# > * **Idea:**  Allocate goods to maximize the sum of everyone's value, aiming for the most overall "happiness" or "utility."
# > * **Process:**
# >     * Good A: Person 2 values it most (33)
# >     * Good B: Person 3 values it most (32)
# >     * Good C: Person 1 values it most (32)
# >     * Good D: All value it equally (7).  We could allocate randomly, or perhaps discard it since no one has a strong preference.
# > * **Allocation:**
# >     * Person 1: Good C
# >     * Person 2: Good A
# >     * Person 3: Good B
# >     * Good D: Not allocated
# > * **Pros:** Maximizes overall satisfaction.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 29
# Unnamed: 0 29
# Tokens 0
# Good A 2
# Good B 3
# Good C 1
# Good D nan
# > This is a classic resource allocation problem with a fairness constraint. Here's how I'd approach finding a "fair" allocation, along with my reasoning:
# >
# > **1. Define "Fairness"**
# >
# > There are many ways to define fairness. Some common ones include:
# >
# > * **Utilitarian:** Maximize the total value across all people.
# > * **Egalitarian:**  Make sure everyone gets as close to equal value as possible.
# > * **Envy-Free:**  Ensure no one would rather have someone else's allocation.
# >
# > For this problem, I'll prioritize a combination of **utilitarian** and **envy-free**, as I want to maximize overall happiness while minimizing potential jealousy or feelings of unfairness.
# >
# > **2. Analyze the Valuations**
# >
# > Let's visualize the valuations in a table:
# >
# > | Good | Person 1 | Person 2 | Person 3 |
# > |---|---|---|---|
# > | A | 30 | **33** | 31 |
# > | B | 31 | 29 | **32** |
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 52
# Unnamed: 0 52
# Tokens 0
# Good A 2
# Good B 3
# Good C 1
# Good D nan
# > This is a classic resource allocation problem where fairness is key! Here's how I'd approach it and my reasoning:
# >
# > **Understanding Fairness**
# >
# > There are many ways to define fairness. Here are a few common principles:
# >
# > * **Envy-freeness:** No person would want to swap their allocation with anyone else's.
# > * **Pareto efficiency:**  No one can be made better off without making someone else worse off.
# > * **Maximizing total social welfare:** The allocation that results in the highest total value across all people.
# >
# > **Analyzing the Values**
# >
# > Let's look at the valuations in a table to make it clearer:
# >
# > | Person | Good A | Good B | Good C | Good D |
# > |-------|--------|--------|--------|--------|
# > | Person 1 | 30    | 31    | 32    | 7     |
# > | Person 2 | 33    | 29    | 31    | 7     |
# > | Person 3 | 31    | 32    | 30    | 7     |
# >
# ...

# %% [markdown]
# ## $I_9$

# %%
instance = 'question_9'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 80
# Unnamed: 0 80
# Tokens 0
# Good A 3
# Good B You
# Good C nan
# Good D 2
# > Here's my proposed allocation and my reasoning:
# >
# > **Proposed Allocation:**
# >
# > * **You:** Good B
# > * **Person 2:** Good D
# > * **Person 3:** Good A
# > * **Not Allocated:** Good C
# >
# > **Reasoning:**
# >
# > This allocation prioritizes maximizing the overall "happiness" or utility derived from the goods. Here's why I believe it's fair:
# >
# > * **High Value Match:** Each person receives the good they value most highly:
# >     * You value Good B the most (40).
# >     * Person 2 values Good D the most (54).
# >     * Person 3 values Good A the most (49).
# > * **Minimizing Waste:** Good C has relatively low values for everyone compared to the other goods. By not allocating it, we avoid giving it to someone who wouldn't gain much from it.
# >
# > **Why I think it's acceptable to others:**
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 85
# Unnamed: 0 85
# Tokens 0
# Good A 3
# Good B You
# Good C nan
# Good D 2
# > Here's my proposed allocation and my reasoning:
# >
# > **Proposed Allocation:**
# >
# > * **You:** Good B
# > * **Person 2:** Good D
# > * **Person 3:** Good A
# > * **Not Allocated:** Good C
# >
# > **Reasoning:**
# >
# > This allocation prioritizes giving each person the item they value most, maximizing overall happiness:
# >
# > * **You:**  You value Good B the highest (40).
# > * **Person 2:** They value Good D significantly more (54) than any other item.
# > * **Person 3:** Good A is their most desired item (49).
# >
# > **Why not allocate Good C?**
# >
# > Good C has relatively low values for everyone. Rather than assigning it randomly and potentially causing envy, it might be best to not allocate it.  This prevents anyone from feeling like they got "stuck" with something undesirable.
# >
# > **Why I believe this is fair:**
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 12
# Unnamed: 0 12
# Tokens 0
# Good A 3
# Good B You
# Good C nan
# Good D 2
# > Here's my proposed allocation and my reasoning:
# >
# > **Proposed Allocation:**
# >
# > * **You:** Good B
# > * **Person 2:** Good D
# > * **Person 3:** Good A
# > * **Not Allocated:** Good C
# >
# > **Reasoning:**
# >
# > This allocation focuses on maximizing the overall happiness or "utility" derived from the goods, even if it means I don't get the most items:
# >
# > * **Prioritize High Values:**  Each person receives the good they value most highly:
# >     * I value Good B at 40.
# >     * Person 2 values Good D at 54.
# >     * Person 3 values Good A at 49.
# > * **Minimize Waste:**  Good C has relatively low values for everyone. To avoid giving it to someone who wouldn't appreciate it much, it's better to not allocate it. This could represent discarding it, donating it elsewhere, or saving it for a future allocation.
# >
# > **Why I think this is fair and acceptable:**
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 48
# Unnamed: 0 48
# Tokens 0
# Good A 3
# Good B You
# Good C nan
# Good D 2
# > Here's my proposed allocation and why I think it's fair:
# >
# > * **You receive: Good B**
# > * **Person 2 receives: Good D**
# > * **Person 3 receives: Good A**
# > * **Good C is not allocated.**
# >
# > **Reasoning:**
# >
# > * **Maximizing Overall Happiness:**  This allocation prioritizes giving each person the item they value most, maximizing the overall "happiness" or utility derived from the goods.
# >     * You value Good B the most (40).
# >     * Person 2 values Good D the most (54).
# >     * Person 3 values Good A the most (49).
# >
# > * **Addressing Large Value Discrepancies:** Notice that Person 2 places significantly higher value on Good D (54) compared to anyone else.  Similarly, Person 3 values Good A much higher (49) than the others. This allocation recognizes these significant differences in preference.
# >
# ...

# %% [markdown]
# ## $I_7$

# %%
instance = 'question_7'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 60
# Unnamed: 0 60
# Tokens 0
# Good A 3
# Good B 1
# Good C 2.0
# Person 1 money 5.0
# Person 2 money 0.0
# Person 3 money 0.0
# > This is a classic resource allocation problem with elements of fairness thrown in. Here's how I'd approach it, outlining my reasoning and the potential issues:
# >
# > **My Proposed Allocation:**
# >
# > * **Person 1:**  Good B + 5 units of money
# > * **Person 2:**  Good C
# > * **Person 3:**  Good A
# >
# > **Reasoning:**
# >
# > 1. **Maximize Total Value:**  My primary goal is to allocate the goods in a way that generates the highest total value across all individuals.
# >     * Person 3 values Good A the most (50).
# >     * Person 2 values Good C the most (45).
# >     * This leaves Person 1 with Good B (value 30), but I compensate with the full 5 units of money, making their total perceived value 35.
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 57
# Unnamed: 0 57
# Tokens 2232
# Good A 3
# Good B 2
# Good C 3
# Person 1 money 3.0
# Person 2 money 1.0
# Person 3 money 0.0
# > To achieve a fair allocation of the three goods and the five units of money among the three individuals, we should aim to balance the value each individual receives as closely as possible, given their valuation of the goods. Since the goods are indivisible, and the money is divisible, we can adjust money allocations to equalize the overall value received by each person. Here's a step-by-step approach to fairly allocate the goods and money:
# >
# > ### Step 1: Allocate the Goods
# > First, we aim to allocate each good to the person who values it the most:
# > - **Good A** is valued most by Person 3 (50).
# > - **Good B** is valued most by Person 2 (40).
# > - **Good C** is valued similarly by Person 3 (45) and slightly less by Persons 1 (25) and 2 (25).
# >
# > The initial choice is:
# > - Person 3 gets Good A.
# > - Person 2 gets Good B.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 31
# Unnamed: 0 31
# Tokens 0
# Good A 3
# Good B 1
# Good C 2.0
# Person 1 money 5.0
# Person 2 money 0.0
# Person 3 money 0.0
# > This is a classic resource allocation problem with elements of fairness to consider. Here's one approach to a "fair" allocation, along with the reasoning:
# >
# > **Proposed Allocation:**
# >
# > * **Person 1:** Good B + 5 units of money
# > * **Person 2:** Good C
# > * **Person 3:** Good A
# >
# > **Reasoning:**
# >
# > 1. **Maximize Total Value (Efficiency):**  The goal is to allocate goods in a way that maximizes the overall satisfaction or "utility" represented by the assigned values.
# >     * Person 3 values Good A the most (50).
# >     * Person 2 values Good C the most (45).
# >     * While Person 1 doesn't have the highest value for Good B, allocating it this way leads to the highest total value across all goods.
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 58
# Unnamed: 0 58
# Tokens 0
# Good A 2
# Good B 1
# Good C 3.0
# Person 1 money 5.0
# Person 2 money 0.0
# Person 3 money 0.0
# > This is a classic resource allocation problem with elements of fairness to consider. Here's one approach to a "fair" allocation and the reasoning behind it:
# >
# > **Proposed Allocation:**
# >
# > * **Person 1:** Good B + 5 units of money
# > * **Person 2:** Good A
# > * **Person 3:** Good C
# >
# > **Reasoning:**
# >
# > 1. **Maximize Total Value (Efficiency):**
# >    * Our goal is to allocate the goods in a way that maximizes the overall satisfaction or "utility" derived by the group.
# >    * This allocation achieves that:
# >       * Person 1 values Good B the most at 30, plus gets the full value of the money (equivalent to another 5 value).
# >       * Person 2 values Good A the most at 35.
# >       * Person 3 values Good C the most at 45.
# >
# > 2. **Addressing Envy-Freeness (Fairness):**
# ...

# %% [markdown]
# # LLaMA 3 70b

# %%
family = 'llama'
model = 'llama3-70b-8192'

# %% [markdown]
# ## $I_2$

# %%
instance = 'question_2'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 91
# Unnamed: 0 91
# Tokens 0
# Good A 2
# Good B 1
# Good C 2
# Good D 3.0
# > What a fascinating problem!
# >
# > To determine a fair allocation, I'll consider various approaches and principles of fairness. Here's my thought process:
# >
# > **1. Efficiency**: I want to allocate the goods in a way that maximizes the total value created. This means I should try to give each good to the person who values it the most.
# >
# > **2. Envy-freeness**: I strive for an allocation where no person envies another person's bundle of goods. In other words, each person should prefer their own allocation to anyone else's.
# >
# > **3. Equity**: I aim for an allocation that is fair in terms of the total value each person receives.
# >
# > Here's the allocation I propose:
# >
# > * Good A: Allocate to Person 2 (value: 45) as they value it the most.
# > * Good B: Allocate to Person 1 (value: 47) as they value it the most.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 64
# Unnamed: 0 64
# Tokens 0
# Good A 3
# Good B 1
# Good C 2
# Good D 3.0
# > What a fascinating problem!
# >
# > To determine a fair allocation, I'll use a combination of intuition and simple economic principles. Since there's no one "right" answer, I'll provide my reasoning and justification for the allocation I propose.
# >
# > **Step 1: Identify the most valuable goods for each person**
# >
# > For Person 1, the most valuable goods are Good B (47) and Good C (45).
# > For Person 2, the most valuable goods are Good C (48) and Good A (45).
# > For Person 3, the most valuable goods are Good C (32) and Good B (25).
# >
# > **Step 2: Allocate the most valuable goods to each person**
# >
# > Based on the values, I allocate:
# >
# > * Good C to Person 2 (value: 48) - This is the highest value among all persons for Good C.
# > * Good B to Person 1 (value: 47) - This is the highest value among all persons for Good B, and Person 1 also values Good C highly.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 11
# Unnamed: 0 11
# Tokens 0
# Good A 2
# Good B 1
# Good C 2
# Good D 3.0
# > A classic problem of fair allocation!
# >
# > Before I propose an allocation, let me summarize the values each person has for each good:
# >
# > | Good | Person 1 | Person 2 | Person 3 |
# > | --- | --- | --- | --- |
# > | A    | 5      | 45     | 23     |
# > | B    | 47     | 5      | 25     |
# > | C    | 45     | 48     | 32     |
# > | D    | 3      | 2      | 20     |
# >
# > To determine a fair allocation, I'll consider the following principles:
# >
# > 1. **Efficiency**: Allocate goods to maximize the total value.
# > 2. **Fairness**: Ensure that each person receives a reasonable share of the total value.
# > 3. **Individual Rationality**: No person should be worse off than if they had not participated in the allocation.
# >
# > With these principles in mind, here's my proposed allocation:
# >
# > * Good A: Allocate to Person 2 (value: 45)
# > * Good B: Allocate to Person 1 (value: 47)
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 97
# Unnamed: 0 97
# Tokens 0
# Good A 2
# Good B 1
# Good C 2
# Good D 3.0
# > What a fascinating problem! After analyzing the values assigned by each person to each good, I will propose an allocation that I consider to be the fairest. Here's my thought process:
# >
# > **Observations:**
# >
# > 1. Person 1 values Good B the most (47), followed closely by Good C (45). They don't value Good A or Good D as much.
# > 2. Person 2 values Good C the most (48), followed closely by Good A (45). They don't value Good B or Good D as much.
# > 3. Person 3 values Good C the most (32), followed by Good B (25). They don't value Good A or Good D as much.
# >
# > **Fair Allocation:**
# >
# > To ensure a fair allocation, I'll aim to maximize the total value assigned to each good while considering the individual values and making sure no good is allocated to more than one person.
# >
# > Here's my proposed allocation:
# >
# ...

# %% [markdown]
# ### Top5

# %%
variation = 'word_top5.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 66
# Unnamed: 0 66
# Tokens 0
# Good A 3
# Good B 1
# Good C 2
# Good D 3.0
# > What a fascinating problem! After careful analysis, I would recommend Allocation-1: Person 1 gets Good B, Person 2 gets Good C, and Person 3 gets Goods A and D as the fairest allocation. Here's why:
# >
# > **Efficiency**: In Allocation-1, each good is allocated to the person who values it the most. Person 1 values Good B the most (47), Person 2 values Good C the most (48), and Person 3 values Good A the most among the remaining goods (23). This allocation ensures that the total value created is maximized.
# >
# > **Fairness**: Allocation-1 also ensures a certain level of fairness. Each person receives at least one good that they value highly. Person 1 gets their second-highest valued good (Good B), Person 2 gets their highest valued good (Good C), and Person 3 gets two goods that they value relatively highly (Goods A and D).
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 42
# Unnamed: 0 42
# Tokens 0
# Good A 2
# Good B 1
# Good C 3
# Good D 3.0
# > What a great problem! After careful consideration, I believe the fairest allocation is Allocation-3: Person 1 gets Good B, Person 2 gets Good A, and Person 3 gets Goods C and D.
# >
# > Here's why:
# >
# > 1. **Efficiency**: In this allocation, all goods are allocated to someone, which means we aren't wasting any goods. This is important because the goods are indivisible, so we can't divide them among multiple people.
# > 2. **Maximum total value**: Let's calculate the total value of each allocation:
# >
# > Allocation-3: Person 1 (47) + Person 2 (45) + Person 3 (52) = 144
# >
# > This allocation has the highest total value among all options. It ensures that the goods are allocated to the people who value them the most.
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 60
# Unnamed: 0 60
# Tokens 0
# Good A 2
# Good B 1
# Good C 3
# Good D 3.0
# > What a fascinating problem!
# >
# > After analyzing the values assigned by each person to each good, I have decided that Allocation-3 is the fairest:
# >
# > **Allocation-3: Person 1 gets Good B, Person 2 gets Good A, and Person 3 gets Goods C and D.**
# >
# > Here's why I chose this allocation:
# >
# > **Efficiency**: This allocation ensures that each good is allocated to the person who values it the most. Person 1 values Good B the most (47), Person 2 values Good A the most (45), and Person 3 values Good C (32) and Good D (20) more than the others.
# >
# > **Fairness**: This allocation is fair because it tries to maximize the total value received by each person. By allocating Good B to Person 1 (47), Good A to Person 2 (45), and both Good C and Good D to Person 3 (32 + 20 = 52), we ensure that each person receives a significant value from the allocation.
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 98
# Unnamed: 0 98
# Tokens 0
# Good A 2
# Good B 1
# Good C 3
# Good D 3.0
# > After analyzing the values of each person for each good, I believe that Allocation-3: Person 1 gets Good B, Person 2 gets Good A, and Person 3 gets Goods C and D is the fairest allocation. Here's why:
# >
# > 1. **Efficiency**: This allocation ensures that each good is allocated to the person who values it the most. Person 1 values Good B the most (47), Person 2 values Good A the most (45), and Person 3 values Good C and Good D more than the others (32 and 20, respectively). This allocation maximizes the total value obtained by all individuals.
# > 2. **Fairness**: This allocation is fair because it gives each person a bundle of goods that is closest to their top preferences. Person 1 gets their top choice (Good B), Person 2 gets their second choice (Good A), and Person 3 gets their top two choices (Goods C and D).
# ...

# %% [markdown]
# ### Options (explanations)

# %%
variation = 'word_options.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 98
# Unnamed: 0 98
# Tokens 0
# Good A 2
# Good B 3
# Good C 1
# Good D 3
# > What a delightful problem!
# >
# > After careful consideration, I believe the fairest allocation is Option 2:
# >
# > {
# >     Allocation: Person 1 gets Good C, Person 2 gets Good A, and Person 3 gets Goods B and D.
# >     Payoffs: Each Person gets 45 units of utility.
# >     Properties: This allocation is equitable and satisfies the maximin principle, i.e., it ensures perfect equality and maximizes the minimum payoff.
# > }
# >
# > Here's why I think Option 2 is the fairest:
# >
# > 1. **Equality**: The allocation ensures perfect equality among all three individuals, with each receiving 45 units of utility. This is a fundamental principle of fairness, as it treats each person equally and doesn't favor one over the others.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 7
# Unnamed: 0 7
# Tokens 0
# Good A 2
# Good B 3
# Good C 1
# Good D 3
# > What a delightful problem in fair division!
# >
# > After carefully analyzing each option, I believe the fairest allocation is **Option 2**.
# >
# > Here's why:
# >
# > 1. **Equitability**: Option 2 is the only allocation that ensures perfect equality among the individuals, with each person receiving 45 units of utility. This property is essential in fair division, as it prevents any individual from being significantly disadvantaged compared to others.
# > 2. **No Envy**: While Option 1 is envy-free, Option 2 takes it a step further by ensuring that each person receives the same payoff, eliminating any possibility of envy.
# > 3. **Simple and Intuitive**: The allocation in Option 2 is straightforward and easy to understand, which can contribute to its perceived fairness.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 90
# Unnamed: 0 90
# Tokens 0
# Good A 2
# Good B 3
# Good C 1
# Good D 3
# > After careful consideration, I think Option 2 is the fairest allocation. Here's why:
# >
# > Option 2 is the only option that achieves perfect equality among the individuals, with each person receiving 45 units of utility. This is a key principle of fairness, as it ensures that each person has an equal share of the total utility.
# >
# > Additionally, Option 2 satisfies the maximin principle, which means that it maximizes the minimum payoff among the individuals. This principle is often considered a fairness criterion, as it prioritizes the well-being of the worst-off individual.
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 14
# Unnamed: 0 14
# Tokens 0
# Good A 2
# Good B 1
# Good C 3
# Good D 3
# > What a delightful problem!
# >
# > After careful consideration, I believe Option 2 is the fairest allocation. Here's why:
# >
# > **Equitability**: Option 2 is the only allocation that ensures perfect equality among the three individuals, with each person receiving 45 units of utility. This is a fundamental principle of fairness, as it treats everyone equally and does not prioritize one person's welfare over another.
# >
# > **Maximin principle**: Option 2 satisfies the maximin principle, which means that it maximizes the minimum payoff among the three individuals. This principle ensures that the worst-off person is as well-off as possible, which is a critical aspect of fairness.
# >
# ...

# %% [markdown]
# ## $I_3$

# %%
instance = 'question_3'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 76
# Unnamed: 0 76
# Tokens 0
# Good A 1
# Good B 2.0
# Good C 3
# Good D 1.0
# Good E 1.0
# > What a fascinating problem! There are many ways to approach this, and I'll present one possible solution that I consider fair.
# >
# > Before I start, let's set some ground rules:
# >
# > 1. Each good can only be allocated to one person or not allocated at all.
# > 2. The goal is to find a fair allocation, considering the values each person assigns to each good.
# >
# > My approach will be to consider the following principles:
# >
# > 1. **Efficiency**: Try to allocate goods to the person who values them the most.
# > 2. **Equity**: Ensure that each person receives a fair share of the total value.
# >
# > Here's the allocation I propose:
# >
# > **Good A**: Person 1 values it the most (40), so I'll allocate Good A to Person 1.
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 97
# Unnamed: 0 97
# Tokens 0
# Good A 1
# Good B 2.0
# Good C 3
# Good D 2.0
# Good E 1.0
# > A classic problem of fair allocation!
# >
# > To determine a fair allocation, I'll use a combination of methods to ensure that each person receives a reasonable share of goods, considering their individual values. Here's my approach:
# >
# > **Step 1: Normalize the values**
# >
# > To compare the values across individuals, I'll normalize them by dividing each person's values by the sum of their values. This will give me a sense of the relative importance of each good to each person.
# >
# > Person 1: [40, 2, 3, 25, 30] => [0.44, 0.02, 0.03, 0.28, 0.33]
# > Person 2: [14, 26, 8, 26, 26] => [0.17, 0.32, 0.10, 0.32, 0.32]
# > Person 3: [10, 26, 26, 12, 26] => [0.11, 0.32, 0.32, 0.15, 0.32]
# >
# > **Step 2: Identify the most valuable good for each person**
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 70
# Unnamed: 0 70
# Tokens 0
# Good A 1
# Good B 2.0
# Good C 3
# Good D 1.0
# Good E 2.0
# > What a fascinating problem!
# >
# > To determine a fair allocation, I'll consider a few principles:
# >
# > 1. **Efficiency**: Allocate goods to individuals who value them the most.
# > 2. **Equity**: Distribute goods in a way that balances the overall value each person receives.
# > 3. **Non-wastefulness**: Avoid throwing away goods whenever possible.
# >
# > Here's my proposed allocation:
# >
# > **Good A**: Allocate to Person 1 (value: 40) - They value it the most.
# >
# > **Good B**: Allocate to Person 2 (value: 26) or Person 3 (value: 26) - Both value it equally, so I'll allocate it to Person 2 randomly (could have gone either way).
# >
# > **Good C**: Allocate to Person 3 (value: 26) - They value it the most among the remaining individuals.
# >
# > **Good D**: Allocate to Person 1 (value: 25) - They value it more than Person 2 and Person 3.
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 3
# Unnamed: 0 3
# Tokens 0
# Good A 1
# Good B 2.0
# Good C 3
# Good D 1.0
# Good E 2.0
# > A classic problem of fair division! I'll do my best to allocate the goods in a way that seems fairest to me.
# >
# > To start, I'll calculate the total value of each good across all individuals:
# >
# > * Good A: 40 + 14 + 10 = 64
# > * Good B: 2 + 26 + 26 = 54
# > * Good C: 3 + 8 + 26 = 37
# > * Good D: 25 + 26 + 12 = 63
# > * Good E: 30 + 26 + 26 = 82
# >
# > Now, I'll allocate the goods based on a combination of fairness and efficiency considerations. Here's my proposed allocation:
# >
# > * Good A: Allocate to Person 1, as they value it the most (40).
# > * Good B: Allocate to Person 2, as they value it equally to Good A (26) and higher than Person 3.
# > * Good C: Allocate to Person 3, as they value it the most (26).
# > * Good D: Allocate to Person 1, as they value it highly (25) and it's the next best option after Good A.
# ...

# %% [markdown]
# ## $I_4$

# %%
instance = 'question_4'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 31
# Unnamed: 0 31
# Tokens 0
# Good A 2
# Good B 3
# Good C 1
# Good D nan
# > What a fascinating problem! After analyzing the values each person has for each good, I'll propose an allocation that I consider to be fair. Here's my reasoning:
# >
# > **Observations:**
# >
# > 1. Good D is valued equally by all three individuals, at 7. This good seems to be of relatively low value to everyone, so I'll focus on allocating the other three goods first.
# > 2. Each person has a unique ranking of the top three goods (A, B, and C). This suggests that each person has different preferences, which will help guide my allocation decision.
# >
# > **Proposed Allocation:**
# >
# > 1. Good A: Allocate to Person 2 (value 33). This is the highest value anyone has for Good A.
# > 2. Good B: Allocate to Person 3 (value 32). This is the highest value anyone has for Good B.
# > 3. Good C: Allocate to Person 1 (value 32). This is the highest value anyone has for Good C.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 12
# Unnamed: 0 12
# Tokens 0
# Good A 2
# Good B 3
# Good C 1
# Good D nan
# > What a fascinating problem!
# >
# > After analyzing the values each person assigns to each good, I'll try to determine a fair allocation. Before I do, let me highlight a few observations:
# >
# > 1. All three individuals value Good D equally, at 7. This good doesn't seem to be a priority for anyone.
# > 2. Person 1 values Good C the most, Person 2 values Good A the most, and Person 3 values Good B the most.
# > 3. There are no extreme differences in values between individuals for a particular good, which makes the allocation decision more nuanced.
# >
# > With these observations in mind, here's the allocation I consider to be the fairest:
# >
# > **Allocation:**
# >
# > * Good A: Person 2 (value: 33)
# > * Good B: Person 3 (value: 32)
# > * Good C: Person 1 (value: 32)
# > * Good D: Not allocated (throw it away, as no one values it highly)
# >
# > **Rationale:**
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 29
# Unnamed: 0 29
# Tokens 0
# Good A 2
# Good B 3
# Good C 1.0
# Good D 1.0
# > A classic problem of fair division!
# >
# > After analyzing the values each person has for each good, I'll propose a fair allocation. I'll consider various factors, such as efficiency, envy-freeness, and fairness.
# >
# > Here's my proposed allocation:
# >
# > 1. Good A: Allocate to Person 2, who values it the most (33).
# > 2. Good B: Allocate to Person 3, who values it the most (32).
# > 3. Good C: Allocate to Person 1, who values it the most (32).
# > 4. Good D: Unfortunately, no one values it particularly highly (all values are 7), so I'll randomly allocate it to Person 1 to avoid throwing it away.
# >
# > Rationale:
# >
# > * Each person receives a good that they value highly, maximizing overall efficiency.
# > * The allocation is envy-free, meaning no person would prefer another person's allocation to their own.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 34
# Unnamed: 0 34
# Tokens 0
# Good A 2
# Good B 3
# Good C 1.0
# Good D 1.0
# > A classic problem of fair allocation!
# >
# > After analyzing the values provided, I'll propose an allocation that I consider fair. Here's my reasoning:
# >
# > **Observations:**
# >
# > 1. Each person has a different highest-value good.
# > 2. Person 1 values Good C the most, Person 2 values Good A the most, and Person 3 values Good B the most.
# > 3. Good D has the same, relatively low, value for all three persons.
# >
# > **Proposed Allocation:**
# >
# > To ensure a fair allocation, I'll aim to give each person their highest-value good, while also considering the overall efficiency of the allocation.
# >
# > 1. **Good A:** Allocate to Person 2, who values it the most (33).
# > 2. **Good B:** Allocate to Person 3, who values it the most (32).
# > 3. **Good C:** Allocate to Person 1, who values it the most (32).
# ...

# %% [markdown]
# # Claude 3.5 Sonnet

# %%
family = 'claude'
model = 'claude-3-5-sonnet-20240620'

# %% [markdown]
# ## $I_2$

# %%
instance = 'question_2'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 0
# Unnamed: 0 0
# Tokens 0
# Good A 3
# Good B 1
# Good C 2
# Good D 3.0
# > To determine the fairest allocation of these indivisible goods, I'll consider a few principles:
# >
# > 1. Maximizing overall value: Trying to allocate goods to those who value them most.
# > 2. Ensuring each person gets at least one good.
# > 3. Minimizing the difference in total value received by each person.
# >
# > Based on these principles, here's an allocation I consider fair:
# >
# > Person 1: Good B (value 47)
# > Person 2: Good C (value 48)
# > Person 3: Good A and Good D (total value 43)
# >
# > Reasoning:
# >
# > 1. Person 1 gets Good B, which they value highly (47).
# > 2. Person 2 gets Good C, which they value the most (48).
# > 3. Person 3 gets both Good A and Good D, which together (23 + 20 = 43) gives them a value close to what the others receive.
# >
# > This allocation ensures that:
# > - Each person receives at least one good.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 71
# Unnamed: 0 71
# Tokens 0
# Good A 3
# Good B 1
# Good C 2
# Good D 3.0
# > To determine the fairest allocation, we need to consider several factors such as maximizing overall utility, ensuring each person receives something of value, and minimizing envy between individuals. Here's my approach to a fair allocation:
# >
# > 1. Person 1 gets Good B (value 47)
# > 2. Person 2 gets Good C (value 48)
# > 3. Person 3 gets Good A and Good D (total value 43)
# >
# > Reasoning:
# >
# > 1. This allocation gives each person at least one item, ensuring no one is left out.
# >
# > 2. It maximizes the value for Person 1 and Person 2, giving them their highest-valued items.
# >
# > 3. Person 3 receives two items, which compensates for the fact that they're getting lower-valued items compared to the others. The total value (43) is close to what the others are receiving.
# >
# > 4. This allocation utilizes all items, leaving nothing unallocated.
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 49
# Unnamed: 0 49
# Tokens 0
# Good A 2
# Good B 1
# Good C 2
# Good D 3.0
# > To determine the fairest allocation, I'll consider a few principles:
# >
# > 1. Maximizing overall value: Try to allocate goods to those who value them most.
# > 2. Ensuring each person gets something of value.
# > 3. Minimizing the disparity between individuals' total values.
# >
# > Let's analyze:
# >
# > 1. Good A: Person 2 values it most (45)
# > 2. Good B: Person 1 values it most (47)
# > 3. Good C: Person 2 values it most (48), but Person 1 is close (45)
# > 4. Good D: Person 3 values it most (20), but it's relatively low-value overall
# >
# > Proposed allocation:
# >
# > - Person 1: Good B (47)
# > - Person 2: Good A and Good C (45 + 48 = 93)
# > - Person 3: Good D (20)
# >
# > Reasoning:
# > 1. This allocation maximizes overall value for Goods A, B, and C.
# > 2. Each person receives at least one item.
# > 3. Person 2 gets two items because they have the highest valuation for two goods.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 91
# Unnamed: 0 91
# Tokens 0
# Good A 3
# Good B 1
# Good C 2
# Good D 3.0
# > To determine the fairest allocation of these indivisible goods, we need to consider several factors such as maximizing overall utility, ensuring each person gets a fair share, and minimizing envy between individuals. Here's my approach to allocating these goods:
# >
# > 1. Person 1 gets Good B (value 47)
# > 2. Person 2 gets Good C (value 48)
# > 3. Person 3 gets Good A and Good D (total value 43)
# >
# > Reasoning:
# >
# > 1. This allocation maximizes overall utility. Each person gets the good (or goods) they value most highly, with the exception of Person 2 not getting Good A.
# >
# > 2. It ensures that each person receives a significant value:
# >    Person 1: 47
# >    Person 2: 48
# >    Person 3: 43
# >
# > 3. The values received are relatively close to each other, with only a 5-point difference between the highest and lowest.
# >
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 57
# Unnamed: 0 57
# Tokens 0
# Good A 3
# Good B 1
# Good C 2
# Good D 3.0
# > To determine the fairest allocation, we need to consider several principles of fairness, such as maximizing overall utility, ensuring each person receives something of value, and minimizing envy between individuals. Let's analyze the situation and propose an allocation:
# >
# > 1. First, let's look at the highest values for each good:
# >    Good A: Person 2 values it most at 45
# >    Good B: Person 1 values it most at 47
# >    Good C: Person 2 values it most at 48
# >    Good D: Person 3 values it most at 20
# >
# > 2. Considering this, a fair allocation might be:
# >    Person 1: Good B (47)
# >    Person 2: Good C (48)
# >    Person 3: Good A (23) and Good D (20)
# >
# > Reasoning:
# > 1. This allocation maximizes overall utility, as the two highest-valued goods (B and C) are given to the people who value them most.
# ...

# %% [markdown]
# ## $I_3$

# %%
instance = 'question_3'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 11
# Unnamed: 0 11
# Tokens 0
# Good A 1
# Good B 2.0
# Good C 3
# Good D nan
# Good E nan
# > Here's how I'd approach finding a "fair" allocation, along with the allocation I'd choose and why:
# >
# > **Understanding Fairness:**
# >
# > * **Utilitarian Approach:** Maximize the total value across all people. This might mean some people get more goods if they value them highly.
# > * **Egalitarian Approach:**  Try to distribute value as equally as possible, even if it means a lower total value overall.
# > * **Envy-Freeness:**  Allocate in a way that no person would prefer another person's bundle of goods over their own.
# >
# > **Analyzing the Valuations:**
# >
# > | Good  | Person 1 | Person 2 | Person 3 |
# > |-------|----------|----------|----------|
# > |   A   |    40    |    14    |    10    |
# > |   B   |     2    |    26    |    26    |
# > |   C   |     3    |     8    |    26    |
# > |   D   |    25    |    26    |    12    |
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 34
# Unnamed: 0 34
# Tokens 0
# Good A 1
# Good B 3.0
# Good C 3
# Good D 2.0
# Good E 3.0
# > Here's how I'd approach finding a "fair" allocation, along with the allocation I'd propose:
# >
# > **Reasoning**
# >
# > * **Maximize Total Value:**  A fair allocation should aim to create the highest total happiness or utility.  This means giving each good to the person who values it most.
# > * **Consider Equity:** While maximizing total value is important, we should also try to avoid situations where one person gets a vastly disproportionate amount of value.
# >
# > **Analyzing the Values**
# >
# > Let's visualize the values to make decisions easier:
# >
# > | Good | Person 1 | Person 2 | Person 3 |
# > |---|---|---|---|
# > | A | **40** | 14 | 10 |
# > | B | 2  | 26 | **26** |
# > | C | 3  | 8  | **26** |
# > | D | 25 | **26** | 12 |
# > | E | 30 | 26 | **26** |
# >
# > **Proposed Allocation**
# >
# > * **Person 1:** Receives Good A (Value 40)
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 62
# Unnamed: 0 62
# Tokens 0
# Good A 1
# Good B 2
# Good C 3
# Good D 1
# Good E 2
# > To determine the fairest allocation, I'll consider a few key principles:
# >
# > 1. Maximizing overall utility: Trying to allocate goods to those who value them most.
# > 2. Fairness in distribution: Aiming for a relatively even distribution of value among the three people.
# > 3. Avoiding waste: Not throwing away any goods if possible.
# >
# > Given these considerations, here's an allocation I believe to be fair:
# >
# > Person 1:
# > - Good A (value 40)
# > - Good D (value 25)
# >
# > Total value for Person 1: 65
# >
# > Person 2:
# > - Good B (value 26)
# > - Good E (value 26)
# >
# > Total value for Person 2: 52
# >
# > Person 3:
# > - Good C (value 26)
# >
# > Total value for Person 3: 26
# >
# > Rationale:
# > 1. Person 1 gets Good A, which they value significantly higher than the others.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 42
# Unnamed: 0 42
# Tokens 0
# Good A 1
# Good B 2
# Good C 3
# Good D 2
# Good E 1
# > To determine the fairest allocation, I'll consider a few key principles:
# >
# > 1. Maximizing overall value/utility
# > 2. Ensuring each person receives at least one good
# > 3. Trying to balance the total value each person receives
# > 4. Avoiding wasting goods by not allocating them
# >
# > Based on these principles, here's an allocation I consider fair:
# >
# > Person 1: Good A (40) and Good E (30)
# > Total value: 70
# >
# > Person 2: Good B (26) and Good D (26)
# > Total value: 52
# >
# > Person 3: Good C (26)
# > Total value: 26
# >
# > Reasoning:
# >
# > 1. This allocation maximizes overall utility, as each good goes to the person who values it most highly, except for Good D (which goes to Person 2 instead of Person 1 for balance).
# >
# > 2. Each person receives at least one good.
# >
# ...

# %% [markdown]
# ## $I_7$

# %%
instance = 'question_7'

# %% [markdown]
# ### WP

# %%
variation = 'word.csv'

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 10
# Unnamed: 0 10
# Tokens 0
# Good A 3
# Good B 2
# Good C 1
# Person 1 money 2.0
# Person 2 money 0.0
# Person 3 money 3.0
# > To determine a fair allocation, I'll consider a few key principles:
# >
# > 1. Maximize overall utility/value
# > 2. Ensure each person receives a fair share
# > 3. Minimize envy between individuals
# >
# > Let's analyze the situation:
# >
# > Person 1: A(45), B(30), C(25)
# > Person 2: A(35), B(40), C(25)
# > Person 3: A(50), B(5), C(45)
# >
# > Allocation:
# >
# > 1. Good A to Person 3 (50)
# > 2. Good B to Person 2 (40)
# > 3. Good C to Person 1 (25)
# >
# > This allocation maximizes the overall value. Now, let's distribute the money to balance things out:
# >
# > Person 1 receives: Good C (25) + 2 units of money = 27
# > Person 2 receives: Good B (40) + 0 units of money = 40
# > Person 3 receives: Good A (50) + 3 units of money = 53
# >
# > Rationale:
# >
# > 1. This allocation maximizes overall utility (135 from goods + 5 from money = 140).
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 23
# Unnamed: 0 23
# Tokens 0
# Good A 3
# Good B 1
# Good C 2
# Person 1 money 1.0
# Person 2 money 2.0
# Person 3 money 2.0
# > To determine the fairest allocation, I'll consider a few key principles:
# >
# > 1. Maximizing overall value
# > 2. Ensuring each person receives something of value
# > 3. Balancing the value received by each person as much as possible
# >
# > Given these considerations, here's an allocation I believe to be fair:
# >
# > 1. Person 1: Good B (value 30) + 1 unit of money
# > 2. Person 2: Good C (value 25) + 2 units of money
# > 3. Person 3: Good A (value 50) + 2 units of money
# >
# > Reasoning:
# >
# > 1. This allocation maximizes overall value. Good A goes to the person who values it most (Person 3), and the other goods are allocated efficiently.
# >
# > 2. Each person receives a good and some money, ensuring everyone gets something of value.
# >
# > 3. The total value received by each person is:
# >    - Person 1: 30 + 1 = 31
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 29
# Unnamed: 0 29
# Tokens 0
# Good A 2
# Good B 3
# Good C 1.0
# Good D 1.0
# > A classic problem of fair division!
# >
# > After analyzing the values each person has for each good, I'll propose a fair allocation. I'll consider various factors, such as efficiency, envy-freeness, and fairness.
# >
# > Here's my proposed allocation:
# >
# > 1. Good A: Allocate to Person 2, who values it the most (33).
# > 2. Good B: Allocate to Person 3, who values it the most (32).
# > 3. Good C: Allocate to Person 1, who values it the most (32).
# > 4. Good D: Unfortunately, no one values it particularly highly (all values are 7), so I'll randomly allocate it to Person 1 to avoid throwing it away.
# >
# > Rationale:
# >
# > * Each person receives a good that they value highly, maximizing overall efficiency.
# > * The allocation is envy-free, meaning no person would prefer another person's allocation to their own.
# ...

# %%
responses = pd.read_csv(f'results/{family}/{model}/{instance}/{variation}')
index = random.randrange(0,100,1)
print(f'Index {index}')
exp = None
for col in responses.columns:
    if col == 'Text':
        exp = to_markdown(responses.iloc[index][col])
    else:
        print(col, responses.iloc[index][col])

exp
# Out:
# Index 34
# Unnamed: 0 34
# Tokens 0
# Good A 2
# Good B 3
# Good C 1.0
# Good D 1.0
# > A classic problem of fair allocation!
# >
# > After analyzing the values provided, I'll propose an allocation that I consider fair. Here's my reasoning:
# >
# > **Observations:**
# >
# > 1. Each person has a different highest-value good.
# > 2. Person 1 values Good C the most, Person 2 values Good A the most, and Person 3 values Good B the most.
# > 3. Good D has the same, relatively low, value for all three persons.
# >
# > **Proposed Allocation:**
# >
# > To ensure a fair allocation, I'll aim to give each person their highest-value good, while also considering the overall efficiency of the allocation.
# >
# > 1. **Good A:** Allocate to Person 2, who values it the most (33).
# > 2. **Good B:** Allocate to Person 3, who values it the most (32).
# > 3. **Good C:** Allocate to Person 1, who values it the most (32).
# ...

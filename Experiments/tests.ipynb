# %%
import json
import requests
API_URL = "https://api-inference.huggingface.co/models/meta-llama/Llama-2-7b-chat"
headers = {"Authorization": "Bearer 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",
        "Content-Type": "application/json"}

def query(payload):
    json_body = {
        "inputs": f"[INST] <<SYS>> Your job is to talk like a pirate. Every reponse must sound like a pirate. <<SYS>> {payload} [/INST] ",
                "parameters": {"max_new_tokens":256, "top_p":0.9, "temperature":0.7}
        }
    data = json.dumps(json_body)
    response = requests.request("POST", API_URL, headers=headers, data=data)
    try:
        return json.loads(response.content.decode("utf-8"))
    except:
        return response

data = query("Just say hi!")
# print(data[0]['generated_text'].split('[/INST] ')[1])

# %%
data = query("Can you please let us know more details about your ")
print(data)
# Out:
# {'error': "We couldn't connect to 'https://huggingface.co' to load this file, couldn't find it in the cached files and it looks like meta-llama/Llama-2-7b-chat is not the path to a directory containing a file named config.json.\nCheckout your internet connection or see how to run the library in offline mode at 'https://huggingface.co/docs/transformers/installation#offline-mode'."}

# %%
from llamaapi import LlamaAPI

# %%
with open('../Auth_keys/llama_auth_key.txt', 'r') as f:
    AUTHKEY = f.read()

api_request_json = {
    "model": 'llama-13b-chat',
    "messages": [
        {
            "role": "user",
            "content": "What is fair?"
        }
    ]
}

llama = LlamaAPI(AUTHKEY)

response = llama.run(api_request_json).json()
print(response['choices'][0]['message']['content'])
# Out:
# Fairness is a concept that can be interpreted in many ways, but at its core, it refers to the idea of justice, equality, and impartiality. Fairness is about treating individuals with respect and dignity, and ensuring that they have equal access to opportunities and resources. It also involves being honest, transparent, and accountable in all dealings, and avoiding any actions or behaviors that could be perceived as unfair or biased. Ultimately, what is fair is subjective and can vary depending on the context and perspectives of those involved. However, some common principles of fairness include:
#
# * Treating others with respect and dignity
# * Providing equal access to opportunities and resources
# * Being honest, transparent, and accountable
# * Avoiding any actions or behaviors that could be perceived as unfair or biased
#
# I hope this helps! Is there anything else you would like to know?

# %%
API_URL = 'https://api.mistral.ai/v1/chat/completions'

{
  "model": "mistral-small-latest",
  "messages": [
    {
      "role": "user",
      "content": "Who is the best French painter? Answer in one short sentence."
    }
  ],
}

response = requests.request("POST", API_URL, headers=headers, data=data)
print(response.json())
# Out:
# {'message': 'Unauthorized', 'request_id': 'da5aaf784b505371c06bc52efcdb3e26'}

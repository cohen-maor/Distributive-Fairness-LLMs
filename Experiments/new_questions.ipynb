# %%
import pandas as pd
import os
import pathlib
import textwrap
from IPython.display import display
from IPython.display import Markdown
from components import PromptGenerator, LLM, OutputAnalyzer
import time
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
oa = OutputAnalyzer(
    model_paths=[
        # ('gemini/gemini-1.0-pro-latest', 'word'),
        ('chatgpt/gpt-4o', 'word'),
        ('claude/claude-3-5-sonnet-20240620', 'word'),
        ('llama/llama3-70b-8192', 'word'), 
        ('gemini/gemini-1.5-pro', 'word')
    ],
    index=[
        # 'Gemini-1.0',
        'GPT',
        'Claude',
        'LLaMA',
        'Gemini',
        # "Gemini",
        # "ChatGPT"
    ]
)
oa.plot_tweak_comparison(
    [6,9], 
    title=r"Skin in the game", 
    figsize=(25,8), 
    title_fontsize=36,
    xlabels_fontsize=32,
    ylabels_fontsize=28,
    ticks_fontsize=28,
    graph_labels_fontsize=20,
    legend_fontsize=28,
    legend_pos=(0.95, 0.9),
    common_legend=False,
    yticks=(6,20),
    humans=True        
)
# Out:
# None
# None

# %%
oa = OutputAnalyzer(
    model_paths=[
        # ('gemini/gemini-1.0-pro-latest', 'word'),
        ('chatgpt/gpt-4o', 'word_top5'),
        ('claude/claude-3-5-sonnet-20240620', 'word_top5'),
        ('llama/llama3-70b-8192', 'word_top5'), 
        ('gemini/gemini-1.5-pro', 'word_top5')
    ],
    index=[
        'GPT',
        'Claude',
        'LLaMA',
        'Gemini',
    ]
)
oa.plot_options(
    [19,2,6,5,7], 
    title=r"Fairest within fair", 
    figsize=(22,4), 
    title_fontsize=16,
    ylabels_fontsize=16,
    xlabels_fontsize=20,
    ticks_fontsize=16,
    graph_labels_fontsize=16,
)
# Out:
# None
# None
# None
# None
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:3507: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([t*20 for t in range(6)], fontsize=ticks_fontsize)
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:3507: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([t*20 for t in range(6)], fontsize=ticks_fontsize)
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:3507: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# ...

# %%
oa = OutputAnalyzer(
    model_paths=[
        # ('gemini/gemini-1.0-pro-latest', 'word'),
        ('chatgpt/gpt-4o', 'word_bad5'),
        ('claude/claude-3-5-sonnet-20240620', 'word_bad5'),
        ('llama/llama3-70b-8192', 'word_bad5'), 
        ('gemini/gemini-1.5-pro', 'word_bad5')
    ],
    index=[
        'GPT',
        'Claude',
        'LLaMA',
        'Gemini',
    ]
)
oa.plot_options(
    [2,7], 
    title=r"Fairest within unfair", 
    figsize=(9,4), 
    title_fontsize=16,
    ylabels_fontsize=16,
    xlabels_fontsize=20,
    ticks_fontsize=16,
    graph_labels_fontsize=16,
    option_type='unfair',
    questions_colors={
        2: ['limegreen', 'palegreen', 'yellow', 'gold', 'salmon', 'orangered'],
        7: ['limegreen', 'palegreen', 'yellow', 'gold', 'salmon', 'orangered'],
    }
)
# Out:
# None
# 2 GPT 89
# 2 Claude 73
# 2 LLaMA 4
# 2 Gemini 0
# 2 GPT 11
# 2 Claude 3
# 2 LLaMA 1
# 2 Gemini 0
# 2 GPT 0
# 2 Claude 4
# 2 LLaMA 11
# 2 Gemini 0
# 2 GPT 0
# 2 Claude 6
# 2 LLaMA 11
# 2 Gemini 7
# 2 GPT 0
# 2 Claude 14
# 2 LLaMA 73
# 2 Gemini 93
# 2 GPT 0
# 2 Claude 0
# 2 LLaMA 0
# 2 Gemini 0
# None
# 7 GPT 53
# 7 Claude 43
# 7 LLaMA 14
# 7 Gemini 0
# 7 GPT 1
# 7 Claude 0
# 7 LLaMA 0
# 7 Gemini 0
# 7 GPT 46
# 7 Claude 23
# 7 LLaMA 31
# 7 Gemini 64
# 7 GPT 0
# 7 Claude 29
# 7 LLaMA 8
# 7 Gemini 8
# 7 GPT 0
# 7 Claude 5
# 7 LLaMA 46
# 7 Gemini 28
# 7 GPT 0
# 7 Claude 0
# 7 LLaMA 1
# 7 Gemini 0
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:3528: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([t*20 for t in range(6)], fontsize=ticks_fontsize)
# ...

# %%
oa = OutputAnalyzer(
    model_paths=[
        # ('gemini/gemini-1.0-pro-latest', 'word'),
        ('chatgpt/gpt-4o', 'word'),
        ('claude/claude-3-5-sonnet-20240620', 'word'),
        ('llama/llama3-70b-8192', 'word'), 
        ('gemini/gemini-1.5-pro', 'word'),
    ],
    index=[
        # 'Gemini-1.0',
        'GPT',
        'Claude',
        'Llama',
        'Gemini',
        # "Gemini",
        # "ChatGPT"
    ]
)
oa.plot_stacked_graph(
    [1,2,3,4,5,6], 
    title=r"Human Vs. LLM Responses", 
    figsize=(48,8), 
    title_fontsize=36,
    labels_fontsize=32,
    ticks_fontsize=28,
    graph_labels_fontsize=24,
    legend_fontsize=28,
    legend_pos=(0.96, 0.9)
)
# Out:
# None
# None
# None
# None
# None
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:3144: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([t*20 for t in range(6)], fontsize=ticks_fontsize)
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:3144: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([t*20 for t in range(6)], fontsize=ticks_fontsize)
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:3144: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# ...

# %%
oa = OutputAnalyzer(
    model_paths=[
        # ('gemini/gemini-1.0-pro-latest', 'word'),
        ('chatgpt/gpt-4o', 'word'),
        ('claude/claude-3-5-sonnet-20240620', 'word'),
        ('llama/llama3-70b-8192', 'word'), 
        ('gemini/gemini-1.5-pro', 'word'),
    ],
    index=[
        # 'Gemini-1.0',
        'GPT',
        'Claude',
        'Llama',
        'Gemini',
        # "Gemini",
        # "ChatGPT"
    ]
)
oa.plot_stacked_graph(
    [6,9], 
    title=r"Human Vs. LLM Responses", 
    figsize=(16,8), 
    title_fontsize=36,
    labels_fontsize=32,
    ticks_fontsize=28,
    graph_labels_fontsize=24,
    legend_fontsize=28,
    question_ordering={
        6: [0,1,2,3,4],
        9: [0,1,2,3,4],
    },
    common_legend = False
)
# Out:
# None
# None
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:3179: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([t*20 for t in range(6)], fontsize=ticks_fontsize)
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:3179: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([t*20 for t in range(6)], fontsize=ticks_fontsize)

# %%
fig, axn = plt.subplots(1, 4, sharex=True, sharey=True, figsize=(7,5))
cbar_ax = fig.add_axes([2.02, 0.08, 0.03, .60])

none = [
    [92,96,26,24],
    [98,77,62,26],
    [100,73,92,90],
    [93,39,50,50],
]

desirable = [
    [97,93,26,23],
    [99,88,56,25],
    [79,70,46,95],
    [94,44,56,45],
]

acceptable = [
    [89,57,12,8],
    [98,60,43,16],
    [20,18,41,68],
    [72,38,33,24],
]

fairest = [
    [34,36,13,14],
    [90,62,16,8],
    [84,5,27,6],
    [32,5,9,16],
]

matrices = [fairest, acceptable, none, desirable]
titles = ['Fairest', 'Acceptable by all', 'An allocation', 'Most desirable']

for i, ax in enumerate(axn.flat):
    s = sns.heatmap(matrices[i], ax=ax,
                cbar=i == 0,
                vmin=0, vmax=100,
                cbar_ax=None if i else cbar_ax, 
                annot=True,
                cmap='Blues',
                fmt='g',
                annot_kws={'size': 14}
            )
    s.set_yticklabels(['Gemini', 'Llama', 'Claude', 'GPT'], rotation=0, fontsize=14)
    s.set_xticklabels([r'$I_{0}$', r'$I_{2}$', r'$I_{3}$', r'$I_{7}$'], fontsize=14)
    # s.set_xlabel(r"Instance, $\phi_w$")
    s.set_title(titles[i], fontsize=16)
    # if not i: s.set_ylabel(r"Dispersion parameter, $\phi_m$")

fig.tight_layout(rect=[0.0, 0, 2, 0.75])
# fig.suptitle("Fraction of Instances with Non-empty Intersection\nbetween Different Optimal Matchings", y=0.82, x=0.6)
fig.savefig("../Graphs/changed_objective.pdf", bbox_inches="tight")
# Out:
# /var/folders/76/q6l8fqjj31n_72p5b5xz4vg40000gn/T/ipykernel_22158/462968282.py:51: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(rect=[0.0, 0, 2, 0.75])

# %%
best_support = {
    'Gemini': {
        1: {
            'v': {
                'val': 50,
                'notion': 'EF\nIA',
                'color': 'gold'
            },
            't': {
                'val': 95,
                'notion': 'EF\nIA',
                'color': 'limegreen'
            }
        },
        2: {
            'v': {
                'val': 36,
                'notion': 'USW',
                'color': 'gold'
            },
            't': {
                'val': 98,
                'notion': 'USW',
                'color': 'limegreen'
            }
        },
        3: {
            'v': {
                'val': 22,
                'notion': 'EF\nRMM\nPO',
                'color': 'gold'
            },
            't': {
                'val': 38,
                'notion': 'NA',
                'color': 'orangered'
            }
        },
        4: {
            'v': {
                'val': 55,
                'notion': 'EF\nRMM',
                'color': 'gold'
            },
            't': {
                'val': 83,
                'notion': 'EF\nRMM',
                'color': 'limegreen'
            }
        },
        5: {
            'v': {
                'val': 41,
                'notion': 'EF\nRMM\nUSW',
                'color': 'gold'
            },
            't': {
                'val': 99,
                'notion': 'EF\nRMM\nUSW',
                'color': 'limegreen'
            }
        },
        6: {
            'v': {
                'val': 29,
                'notion': 'EF',
                'color': 'gold'
            },
            't': {
                'val': 98,
                'notion': 'USW',
                'color': 'orangered'
            }
        },
        9: {
            'v': {
                'val': 100,
                'notion': 'EF',
                'color': 'gold'
            },
            't': {
                'val': 95,
                'notion': 'USW',
                'color': 'orangered'
            }
        }
    },
    'Llama': {
        1: {
            'v': {
                'val': 63,
                'notion': 'EF\nIA',
                'color': 'gold'
            },
            't': {
                'val': 100,
                'notion': 'EF\nIA',
                'color': 'limegreen'
            }
        },
        2: {
            'v': {
                'val': 62,
                'notion': 'USW',
                'color': 'gold'
            },
            't': {
                'val': 96,
                'notion': 'USW',
                'color': 'limegreen'
            }
        },
        3: {
            'v': {
                'val': 34,
                'notion': 'NA',
                'color': 'gold'
            },
            't': {
                'val': 42,
                'notion': 'NA',
                'color': 'orangered'
            }
        },
        4: {
            'v': {
                'val': 72,
                'notion': 'EF\nRMM',
                'color': 'gold'
            },
            't': {
                'val': 89,
                'notion': 'EF\nRMM',
                'color': 'limegreen'
            }
        },
        5: {
            'v': {
                'val': 40,
                'notion': 'NA',
                'color': 'gold'
            },
            't': {
                'val': 72,
                'notion': 'NA',
                'color': 'limegreen'
            }
        },
        6: {
            'v': {
                'val': 69,
                'notion': 'USW',
                'color': 'gold'
            },
            't': {
                'val': 69,
                'notion': 'USW',
                'color': 'gold'
            }
        },
        9: {
            'v': {
                'val': 98,
                'notion': 'USW',
                'color': 'gold'
            },
            't': {
                'val': 78,
                'notion': 'NA',
                'color': 'orangered'
            }
        }
    },
    'GPT': {
        1: {
            'v': {
                'val': 61,
                'notion': 'EF\nIA',
                'color': 'gold'
            },
            't': {
                'val': 71,
                'notion': 'EF\nIA',
                'color': 'gold'
            }
        },
        2: {
            'v': {
                'val': 29,
                'notion': 'EF\nPO',
                'color': 'gold'
            },
            't': {
                'val': 39,
                'notion': 'USW',
                'color': 'orangered'
            }
        },
        3: {
            'v': {
                'val': 36,
                'notion': 'EF\nRMM\nPO',
                'color': 'gold'
            },
            't': {
                'val': 21,
                'notion': 'EF\nRMM\nPO',
                'color': 'tan'
            }
        },
        4: {
            'v': {
                'val': 43,
                'notion': 'EF\nRMM',
                'color': 'gold'
            },
            't': {
                'val': 78,
                'notion': 'EF\nRMM',
                'color': 'limegreen'
            }
        },
        5: {
            'v': {
                'val': 79,
                'notion': 'EF\nRMM\nUSW',
                'color': 'gold'
            },
            't': {
                'val': 89,
                'notion': 'EF\nRMM\nUSW',
                'color': 'gold'
            }
        },
        6: {
            'v': {
                'val': 43,
                'notion': 'EF\nRMM\nPO',
                'color': 'gold'
            },
            't': {
                'val': 53,
                'notion': 'USW',
                'color': 'orangered'
            }
        },
        9: {
            'v': {
                'val': 35,
                'notion': 'USW',
                'color': 'gold'
            },
            't': {
                'val': 68,
                'notion': 'USW',
                'color': 'limegreen'
            }
        }
    },
    'Claude': {
        1: {
            'v': {
                'val': 75,
                'notion': 'EF\nIA',
                'color': 'gold'
            },
            't': {
                'val': 85,
                'notion': 'EF\nIA',
                'color': 'gold'
            }
        },
        2: {
            'v': {
                'val': 77,
                'notion': 'EF\nPO',
                'color': 'gold'
            },
            't': {
                'val': 56,
                'notion': 'RMM\nPO',
                'color': 'orangered'
            }
        },
        3: {
            'v': {
                'val': 66,
                'notion': 'NA',
                'color': 'gold'
            },
            't': {
                'val': 69,
                'notion': 'NA',
                'color': 'orangered'
            }
        },
        4: {
            'v': {
                'val': 77,
                'notion': 'EF\nRMM',
                'color': 'gold'
            },
            't': {
                'val': 67,
                'notion': 'EF\nRMM',
                'color': 'gold'
            }
        },
        5: {
            'v': {
                'val': 45,
                'notion': 'EF\nRMM\nUSW',
                'color': 'gold'
            },
            't': {
                'val': 100,
                'notion': 'EF\nRMM\nUSW',
                'color': 'limegreen'
            }
        },
        6: {
            'v': {
                'val': 57,
                'notion': 'EF\nRMM\nPO',
                'color': 'gold'
            },
            't': {
                'val': 68,
                'notion': 'USW',
                'color': 'orangered'
            }
        },
        9: {
            'v': {
                'val': 88,
                'notion': 'EF',
                'color': 'gold'
            },
            't': {
                'val': 100,
                'notion': 'EF\nRMM\nPO',
                'color': 'orangered'
            }
        }
    }
}

fig, axes = plt.subplots(4, 7, sharex=True, sharey=True, figsize=(10,5))

for i, model in enumerate(list(best_support.keys())):
    fig.text(0.05, 0.778 - (i * 0.2), model, ha='center', fontsize=11)
    for j, ques in enumerate(list(best_support[model].keys())):
        axes[i,j].bar(x=['OP'], height=[best_support[model][ques]['v']['val']], label=best_support[model][ques]['v']['notion'], color=best_support[model][ques]['v']['color'])
        axes[i,j].bar(x=['TP'], height=[best_support[model][ques]['t']['val']], label=best_support[model][ques]['t']['notion'], color=best_support[model][ques]['t']['color'])
        ticks = ['v', 't']
        for k, c in enumerate(axes[i,j].containers):
            if best_support[model][ques][ticks[k]]['notion'].count('\n') > 1 and best_support[model][ques][ticks[k]]['val'] < 50:
                print('Yes')
                axes[i,j].bar_label(c, labels=[best_support[model][ques][ticks[k]]['notion']])
            elif best_support[model][ques][ticks[k]]['notion'].count('\n') > 0 and best_support[model][ques][ticks[k]]['val'] < 30:
                print('Yes')
                axes[i,j].bar_label(c, labels=[best_support[model][ques][ticks[k]]['notion']])
            else:
                axes[i,j].bar_label(c, labels=[best_support[model][ques][ticks[k]]['notion']], label_type='center')
        qtext = '{'+str(ques)+'}'
        if not i: axes[i,j].set_title(fr'$I_{qtext}$')



# questions = [1,2,3,4,5,6,9]
# fig = plt.figure(constrained_layout=True, figsize=(12,6))
# fig.tight_layout()
# subfigs = fig.subfigures(nrows=4, ncols=1)
# for i, subfig in enumerate(subfigs):
#     subfig.suptitle(f'Subfigure title {i}')

#     # create 1x3 subplots per subfig
#     axs = subfig.subplots(nrows=1, ncols=7)
#     for j, ax in enumerate(axs):
#         ax.bar(x=['V'], height=[best_support[models[i]][questions[j]]['v']['val']], label=best_support[models[i]][questions[j]]['v']['notion'], color=best_support[models[i]][questions[j]]['v']['color'])
#         ax.bar(x=['T'], height=[best_support[models[i]][questions[j]]['t']['val']], label=best_support[models[i]][questions[j]]['t']['notion'], color=best_support[models[i]][questions[j]]['t']['color'])
#         ticks = ['v', 't']
#         for k, c in enumerate(ax.containers):
#             if best_support[models[i]][questions[j]][ticks[k]]['notion'].count('\n') > 1 and best_support[models[i]][questions[j]][ticks[k]]['val'] < 38:
#                 print('Yes')
#                 ax.bar_label(c, labels=[best_support[models[i]][questions[j]][ticks[k]]['notion']], label_type='center')
#             else:
#                 ax.bar_label(c, labels=[best_support[models[i]][questions[j]][ticks[k]]['notion']], label_type='center')
#         qtext = '{'+str(questions[j])+'}'
#         if not i: ax.set_title(fr'$I_{qtext}$')
fig.savefig("../Graphs/template_effects.pdf", bbox_inches="tight")
# Out:
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes

# %%
fig, axn = plt.subplots(1, 4, sharex=True, sharey=True)
cbar_ax = fig.add_axes([2.02, 0.08, 0.03, .60])

best = [
    [9,0,7,3],
    [0,0,11,0],
    [10,11,9,13],
    [43,52,56,66],
]

second = [
    [9,2,15,16],
    [0,2,17,3],
    [10,12,12,14],
    [43,54,58,69],
]

third = [
    [66,50,23,16],
    [38,44,24,3],
    [64,62,44,14],
    [62,81,67,69],
]

fourth = [
    [33,14,13,32],
    [60,57,53,78],
    [63,70,74,87],
    [89,91,89,95],
]

matrices = [best, second, third, fourth]
titles = ['RMM + EQ + EF + USW', 'EQ + EF', 'EF', 'USW']

for i, ax in enumerate(axn.flat):
    s = sns.heatmap(matrices[i], ax=ax,
                cbar=i == 0,
                vmin=0, vmax=100,
                cbar_ax=None if i else cbar_ax, 
                annot=True,
                cmap='Greens',
                fmt='g',
                annot_kws={'size': 14}
            )
    s.set_yticklabels(['Gemini', 'Llama', 'Claude', 'GPT'], rotation=0, fontsize=14)
    s.set_xticklabels([r'$I_{1.4}$', r'$I_{1.5}$', r'$I_{1.6}$', r'$I_{1.7}$'], fontsize=14)
    # s.set_xlabel(r"Instance, $\phi_w$")
    s.set_title(titles[i], fontsize=16)
    # if not i: s.set_ylabel(r"Dispersion parameter, $\phi_m$")

fig.tight_layout(rect=[0.0, 0, 2, 0.75])
# fig.suptitle("Fraction of Instances with Non-empty Intersection\nbetween Different Optimal Matchings", y=0.82, x=0.6)
fig.savefig("../Graphs/money_instances_new.pdf", bbox_inches="tight")
# Out:
# /var/folders/76/q6l8fqjj31n_72p5b5xz4vg40000gn/T/ipykernel_22158/1389830995.py:51: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(rect=[0.0, 0, 2, 0.75])

# %%
oa = OutputAnalyzer(
    model_paths=[
        # ('gemini/gemini-1.0-pro-latest', 'word'),
        ('chatgpt/gpt-4o', 'word'),
        ('chatgpt/gpt-4o', 'word_cot'),
        ('claude/claude-3-5-sonnet-20240620', 'word'),
        ('claude/claude-3-5-sonnet-20240620', 'word_cot'),
        ('llama/llama3-70b-8192', 'word'), 
        ('llama/llama3-70b-8192', 'word_cot'),
        ('gemini/gemini-1.5-pro', 'word'), 
        ('gemini/gemini-1.5-pro', 'word_cot'),
    ],
    index=[
        # 'Gemini-1.0',
        'GPT (0)',
        'GPT (1)',
        'Claude (0)',
        'Claude (1)',
        'LLaMA (0)',
        'LLaMA (1)',
        'Gemini (0)',
        'Gemini (1)',
        # "Gemini",
        # "ChatGPT"
    ]
)
oa.plot_stacked_graph(
    [2,7], 
    title=r"Effect of Multi-shot Prompting", 
    figsize=(24,7), 
    title_fontsize=36,
    labels_fontsize=26,
    ticks_fontsize=22,
    graph_labels_fontsize=23,
    legend_fontsize=22,
    question_ordering={
        2: [0,1,2,3,4,5,6,7,8],
        7: [0,1,2,3,4,5,6,7,8],
    },
    legend_pos=(1.03, 0.9)
)
# Out:
# None
# new_order = {'1st': [26.2, 9, 28, 1, 44, 0, 0, 0, 2], '2nd': [26.2, 29, 40, 77, 33, 15, 18, 11, 11], '3rd': [12.7, 19, 9, 13, 22, 3, 0, 3, 1], '4th': [9, 5, 4, 5, 1, 62, 28, 36, 22], '5th': [7.9, 8, 6, 1, 0, 0, 0, 3, 3], 'Other': [18, 30, 13, 3, 0, 20, 54, 47, 61]}
# index=['Humans', 'GPT (0)', 'GPT (1)', 'Claude (0)', 'Claude (1)', 'LLaMA (0)', 'LLaMA (1)', 'Gemini (0)', 'Gemini (1)']
# labels = ['IA\nRMM', 'EF\nPO', 'RMM\nPO', 'USW', '-', '-']
# None
# new_order = {'1st': [55, 8, 22, 0, 0, 0, 0, 2, 0], '2nd': [12.7, 0, 7, 0, 1, 0, 2, 4, 4], '3rd': [16.8, 15, 47, 0, 1, 1, 9, 12, 37], '4th': [15, 52, 7, 43, 0, 87, 56, 23, 15], '5th': [0, 17, 1, 6, 0, 9, 14, 15, 0], 'Other': [0.5, 8, 16, 51, 98, 3, 19, 44, 44]}
# index=['Humans', 'GPT (0)', 'GPT (1)', 'Claude (0)', 'Claude (1)', 'LLaMA (0)', 'LLaMA (1)', 'Gemini (0)', 'Gemini (1)']
# labels = ['IA', 'EF', '-', '-', 'USW', '-']
# ...

# %%
oa = OutputAnalyzer(
    model_paths=[
        # ('gemini/gemini-1.0-pro-latest', 'word'),
        ('gemini/gemini-1.0-pro-latest', 'word_best_goods_centric'), 
        # ('chatgpt/gpt-35-turbo-1106', 'word'),
        # ('chatgpt/gpt-35-turbo-1106', 'word_goods_centric')
        # ('chatgpt/gpt-4-1106-preview', 'word')
    ],
    index=[
        # 'Gemini-1.0\n(Vanilla)',
        'Gemini-1.0\n(Template)',
        # 'GPT-3.5\n(Vanilla)',
        # 'GPT-3.5\n(Instruction)',
        # 'GPT-4'
        # "Gemini",
        # "ChatGPT"
    ]
)
oa.plot_tweak_comparison(
    [5,51,2,21,6,61,62], 
    title="Gemini's Choices with Template-based Prompting", 
    figsize=(14,6), 
    title_fontsize=22, 
    common_legend=False,
    xticks=False,
    graph_labels_fontsize=14,
    labels_fontsize=20,
    yticks=[10,10],
    ticks_fontsize=14,
    bar_width=1,
    colorlist={
        2: ['limegreen', 'palegreen', 'plum', 'yellow', 'gold', 'lightsalmon', 'coral', 'lightgrey', 'silver', 'lightsteelblue', 'silver', 'lightsteelblue'],
        5: ['limegreen', 'palegreen', 'yellow', 'gold', 'gold', 'lightsalmon', 'coral', 'sandybrown', 'sandybrown', 'chocolate', 'chocolate'],
        6: ['limegreen', 'yellow', 'plum', 'gold', 'lightsalmon', 'coral', 'tomato', 'lightgrey', 'silver', 'lightsteelblue', 'sandybrown', 'chocolate', 'chocolate'],
    },
    marks='fixed',
)
# Out:
# None
# None
# None
# None
# None
# None
# None

# %%
oa = OutputAnalyzer(
    model_paths=[
        # ('gemini/gemini-1.0-pro-latest', 'word'),
        ('chatgpt/gpt-35-turbo-1106', 'word'),
    ],
    index=[
        # 'Gemini-1.0',
        'GPT-3.5',
    ]
)

oa.plot_tweak_comparison(
    [2,23,24,6,9,91], 
    title="Influence of Decision-maker Bias on GPT's Responses", 
    figsize=(12,5), 
    title_fontsize=20, 
    common_legend=False,
    xticks=False,
    graph_labels_fontsize=14,
    labels_fontsize=18,
    yticks=[8,10],
    ticks_fontsize=14,
    # marks='fixed',
    # legend_fontsize=14,
    # legend_pos=(1.05, 0.8),
    bar_width=1,
    marks='fixed',
    colorlist={
        2: ['limegreen', 'palegreen', 'plum', 'yellow', 'gold', 'lightsalmon', 'coral', 'lightgrey', 'silver', 'lightsteelblue', 'dimgrey'],
        6: ['limegreen', 'yellow', 'plum', 'gold', 'lightsalmon', 'coral', 'tomato', 'lightgrey', 'silver', 'lightsteelblue', 'sandybrown', 'chocolate'],
        9: ['limegreen', 'yellow', 'plum', 'gold', 'lightsalmon', 'coral', 'tomato', 'lightgrey', 'silver', 'lightsteelblue', 'sandybrown', 'chocolate'],
    }
)
# Out:
# None
# None
# None
# None
# None
# None

# %%
oa = OutputAnalyzer(
    model_paths=[
        ('gemini/gemini-1.5-pro', 'word'),
        ('chatgpt/gpt-4-turbo', 'word'),
    ],
    index=[
        'Gemini',
        'GPT',
    ]
)

oa.plot_tweak_comparison(
    [4,43,2,21,6,62], 
    title="Influence of Ordering on Choice Distributions", 
    figsize=(18,7), 
    title_fontsize=28, 
    common_legend=False,
    # xticks=False,
    graph_labels_fontsize=14,
    labels_fontsize=26,
    yticks=[11,10],
    ticks_fontsize=22,
    # marks='fixed',
    # legend_fontsize=14,
    # legend_pos=(1.05, 0.8),
    bar_width=0.8,
    colorlist={
        2: ['limegreen', 'palegreen', 'plum', 'yellow', 'gold', 'goldenrod', 'lightsalmon', 'coral', 'lightgrey', 'silver', 'lightsteelblue', 'dimgrey'],
        3: ['limegreen', 'palegreen', 'yellow', 'plum', 'plum', 'sandybrown', 'chocolate',],
        4: ['limegreen', 'skyblue', 'pink', 'orchid', 'plum', 'lightgrey', 'silver', 'lightsteelblue'],
        5: ['limegreen', 'palegreen', 'yellow', 'lightsalmon', 'coral', 'tomato', 'orangered', 'lightgrey', 'silver', 'lightsteelblue', 'dimgrey'],
        6: ['limegreen', 'yellow', 'plum', 'gold', 'lightsalmon', 'coral', 'tomato', 'lightgrey', 'silver', 'lightsteelblue',],
    },
    marks='fixed'
)
# Out:
# None
# None
# None
# None
# None
# None

# %%
oa = OutputAnalyzer(
    model_paths=[
        ('llama/llama3-70b-8192', 'word'),
        ('chatgpt/gpt-4o', 'word'),
    ],
    index=[
        'LLaMA3',
        'GPT-4o',
    ]
)

oa.plot_tweak_comparison(
    [14,15,16,17], 
    title="Can LLMs Utilize Money to Compensate Envy and/or Inequality?", 
    figsize=(12,6), 
    title_fontsize=18, 
    common_legend=True,
    graph_labels_fontsize=18,
    labels_fontsize=18,
    yticks=[11,10],
    ticks_fontsize=16,
    marks='fixed',
    legend_fontsize=14,
    legend_pos=(1.05, 0.8),
    colorlist={
        1: ['darkgreen', 'green', 'limegreen', 'lightgreen', 'paleturquoise', 'khaki', 'yellow', 'gold', 'lightsalmon', 'coral', 'orangered', 'red', 'darkred']
    }
)
# Out:
# None
# 14 98 ('llama/llama3-70b-8192', 'word')
# 14 90 ('chatgpt/gpt-4o', 'word')
# None
# 15 97 ('llama/llama3-70b-8192', 'word')
# 15 96 ('chatgpt/gpt-4o', 'word')
# None
# 16 95 ('llama/llama3-70b-8192', 'word')
# 16 90 ('chatgpt/gpt-4o', 'word')
# None
# 17 88 ('llama/llama3-70b-8192', 'word')
# 17 96 ('chatgpt/gpt-4o', 'word')
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:1742: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_alloc['Person 1 money'] = pd.to_numeric(data_alloc['Person 1 money'], errors='coerce')
# ...

# %%
oa = OutputAnalyzer(
    model_paths=[
        ('gemini/gemini-1.0-pro-latest', 'word'),
        ('gemini/gemini-1.5-pro-latest', 'word'), 
        # ('chatgpt/gpt-35-turbo-1106', 'word'),
        # ('chatgpt/gpt-4-1106-preview', 'word')
    ],
    index=[
        'Gemini-1.0',
        'Gemini-1.5',
        # 'GPT-3.5',
        # 'GPT-4'
        # "Gemini",
        # "ChatGPT"
    ]
)
oa.plot_stacked_graph(
    [1,2,3,4,5,6,7,9], 
    title=r"Model Version Comparison - Gemini", 
    figsize=(47,9), 
    title_fontsize=36,
    labels_fontsize=32,
    ticks_fontsize=24,
    graph_labels_fontsize=24,
    legend_fontsize=28)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:2398: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([t*20 for t in range(6)], fontsize=ticks_fontsize)
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:2398: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([t*20 for t in range(6)], fontsize=ticks_fontsize)
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:2398: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# ...

# %%
oa = OutputAnalyzer(
    model_paths=[
        ('gemini/gemini-1.0-pro-latest', 'word_best_goods_centric'),
        # ('gemini/gemini-1.5-pro-latest', 'word'), 
        ('chatgpt/gpt-35-turbo-1106', 'word_goods_centric'),
        # ('chatgpt/gpt-4-1106-preview', 'word')
    ],
    index=[
        'Gemini-1.0',
        # 'Gemini-1.5',
        'GPT-3.5',
        # 'GPT-4'
        # "Gemini",
        # "ChatGPT"
    ]
)
oa.plot_stacked_graph(    
    [1,2,3,4,5,6,7,9], 
    title=r"Human Vs. LLM Responses with Template-based Prompting", 
    figsize=(47,9), 
    title_fontsize=36,
    labels_fontsize=32,
    ticks_fontsize=24,
    graph_labels_fontsize=24,
    legend_fontsize=28
)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:2398: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([t*20 for t in range(6)], fontsize=ticks_fontsize)
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:2398: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([t*20 for t in range(6)], fontsize=ticks_fontsize)
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:2398: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# ...

# %%
oa = OutputAnalyzer(
    model_paths=[
        ('gemini/gemini-1.0-pro-latest', 'word'),
        ('gemini/gemini-1.0-pro-latest', 'word_best_goods_centric'), 
        # ('chatgpt/gpt-35-turbo-1106', 'word'),
        # ('chatgpt/gpt-35-turbo-1106', 'word_mandatory'),
        # ('chatgpt/gpt-4-1106-preview', 'word')
    ],
    index=[
        'Gemini-1.0\n(WP)',
        'Gemini-1.0\n(WP+SB+GC)',
        # 'GPT-3.5',
        # 'GPT-3.5\n(WP+MJ)',
        # 'GPT-4'
        # "Gemini",
        # "ChatGPT"
    ]
)
oa.plot_tweak_comparison(
    questions=[5,51,2,21,6,61,62], 
    title=r"Impact of Ordering Changes with Goods Centric Template (Gemini)", 
    figsize=(24,6), 
    title_fontsize=25, 
    labels_fontsize=20,
    ticks_fontsize=16,
    graph_labels_fontsize=12,
    yticks=(9,10),
    common_legend=False
)
# Out:
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:2439: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([t*yticks[1] for t in range(yticks[0])], fontsize=ticks_fontsize)
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:2439: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([t*yticks[1] for t in range(yticks[0])], fontsize=ticks_fontsize)
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:2439: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# ...

# %%
oa.plot_stacked_graph([1,4], title="Fairness vs. Efficiency")
# Out:
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:2179: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([t*20 for t in range(6)], fontsize=20)
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:2179: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([t*20 for t in range(6)], fontsize=20)

# %%
oa = OutputAnalyzer(
    model_paths=[
        ('gemini/gemini-1.0-pro-latest', 'word'),
        # ('gemini/gemini-1.0-pro-latest', 'word_best_goods_centric'), 
        ('chatgpt/gpt-35-turbo-1106', 'word'),
        # ('chatgpt/gpt-35-turbo-1106', 'word_mandatory')
    ],
    index=[
        'Gemini-1.0',
        # 'Gemini-1.0\n(WP+SB+GC)',
        'GPT-3.5',
        # 'GPT-3.5\n(WP+MJ)'
        # "Gemini",
        # "ChatGPT"
    ]
)
oa.plot_tweak_comparison(
    [1, 11,12,13], 
    common_legend=True, 
    figsize=(16,6), 
    title='Do LLMs select an allocation satisfying ALL notions?', 
    title_fontsize=26,
    graph_labels_fontsize=15,
    labels_fontsize=22,
    legend_fontsize=16,
    ticks_fontsize=18,
    marks='fixed',
    colorlist=['powderblue', 'pink', 'palegreen', 'tomato'],
    yticks=(6,20),
    legend_pos=(1.01, 0.65)
)
# Out:
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:2518: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([t*yticks[1] for t in range(yticks[0])], fontsize=ticks_fontsize)
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:2518: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([t*yticks[1] for t in range(yticks[0])], fontsize=ticks_fontsize)
# /Users/samarthkhanna/Library/CloudStorage/OneDrive-ThePennsylvaniaStateUniversity/LLM project/Experiments/components.py:2518: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# ...

# %%
oa = OutputAnalyzer(
    model_paths=[
        ('gemini/gemini-1.0-pro-latest', 'word'),
        # ('gemini/gemini-1.0-pro-latest', 'word_best_goods_centric'), 
        ('chatgpt/gpt-35-turbo-1106', 'word'),
        # ('chatgpt/gpt-35-turbo-1106', 'word_mandatory')
    ],
    index=[
        'Gemini-1.0',
        # 'Gemini-1.0\n(WP+SB+GC)',
        'GPT-3.5',
        # 'GPT-3.5\n(WP+MJ)'
        # "Gemini",
        # "ChatGPT"
    ]
)
oa.plot_tweak_comparison([4,41,42], common_legend=False, figsize=(8,5), title=r'Magnitude changes to $I_4$', title_fontsize=15)
# Out:
# 4
# 41
# 42

# %%
oa.plot_stacked_graph([2,6], title='EQ vs. EF vs. RMM vs. USW')
# Out:
# [26.2, 26.2, 12.7, 9, 7.9, 18] [4, 9, 0, 11, 3, 73]
# 2 humans ('gemini/gemini-1.0-pro-latest', 'word') [26.2, 26.2, 12.7, 9, 7.9, 18] [4, 9, 0, 11, 3, 73] Power_divergenceResult(statistic=214.34153058266497, pvalue=2.420307477011387e-44)
# [26.2, 26.2, 12.7, 9, 7.9, 18] [0, 11, 2, 16, 19, 52]
# 2 humans ('chatgpt/gpt-35-turbo-1106', 'word') [26.2, 26.2, 12.7, 9, 7.9, 18] [0, 11, 2, 16, 19, 52] Power_divergenceResult(statistic=129.2961504389205, pvalue=3.356850990033185e-26)
# [4, 9, 0, 11, 3, 73] [0, 11, 2, 16, 19, 52]
# 2 ('gemini/gemini-1.0-pro-latest', 'word') ('chatgpt/gpt-35-turbo-1106', 'word') [4, 9, 0, 11, 3, 73] [0, 11, 2, 16, 19, 52] Power_divergenceResult(statistic=inf, pvalue=0.0)
# [32.6, 28.1, 18.4, 7.9, 13] [0, 12, 6, 12, 70]
# 6 humans ('gemini/gemini-1.0-pro-latest', 'word') [32.6, 28.1, 18.4, 7.9, 13] [0, 12, 6, 12, 70] Power_divergenceResult(statistic=302.23200192361554, pvalue=3.575440494563443e-64)
# [32.6, 28.1, 18.4, 7.9, 13] [0, 4, 27, 37, 32]
# ...

# %%
oa.plot_tweak_comparison([2,21,22], title=r"Effect of Ordering and Magnitude Changes on $I_2$", figsize=(8,5), title_fontsize=15, common_legend=False)
# Out:
# 2
# 21
# 22

# %%
oa.plot_tweak_comparison([6,61], title=r"Effect of Ordering Changes on $I_6$")

# %%
oa.plot_stacked_graph([3,5], title='Instances with more than 4 goods')
# Out:
# [27.8, 12.5, 9.7, 7.9, 7, 35.1] [17, 2, 4, 0, 8, 69]
# 3 humans ('gemini/gemini-1.0-pro-latest', 'word') [27.8, 12.5, 9.7, 7.9, 7, 35.1] [17, 2, 4, 0, 8, 69] Power_divergenceResult(statistic=57.14905077320266, pvalue=4.711573287118555e-11)
# [27.8, 12.5, 9.7, 7.9, 7, 35.1] [11, 0, 1, 0, 9, 79]
# 3 humans ('chatgpt/gpt-35-turbo-1106', 'word') [27.8, 12.5, 9.7, 7.9, 7, 35.1] [11, 0, 1, 0, 9, 79] Power_divergenceResult(statistic=93.83330714681304, pvalue=1.0508003611665647e-18)
# [17, 2, 4, 0, 8, 69] [11, 0, 1, 0, 9, 79]
# 3 ('gemini/gemini-1.0-pro-latest', 'word') ('chatgpt/gpt-35-turbo-1106', 'word') [17, 2, 4, 0, 8, 69] [11, 0, 1, 0, 9, 79] Power_divergenceResult(statistic=nan, pvalue=nan)
# [50, 12.5, 9.3, 6.9, 21.3] [15, 0, 1, 1, 83]
# 5 humans ('gemini/gemini-1.0-pro-latest', 'word') [50, 12.5, 9.3, 6.9, 21.3] [15, 0, 1, 1, 83] Power_divergenceResult(statistic=228.17968446490067, pvalue=3.2542287077070356e-48)
# [50, 12.5, 9.3, 6.9, 21.3] [13, 0, 0, 5, 82]
# ...

# %%
oa.plot_tweak_comparison([5,51], title=r'Effect of ordering change in $I_5$')

# %%
oa.plot_stacked_graph([7,8], title="Addition of money to the resources bein allocated")

# %%
oa.plot_tweak_comparison([2,23,24], title=r"The effect of decision maker bias in $I_2$")

# %%
oa.plot_tweak_comparison([9,91], title=r"The effect of ordering changes in $I_9$")

# %%
oa = OutputAnalyzer(
    model_paths=[
        ('gemini/gemini-1.0-pro-latest', 'word'),
        ('gemini/gemini-1.5-pro-latest', 'word'), 
        ('chatgpt/gpt-35-turbo-1106', 'word'),
        ('chatgpt/gpt-4-1106-preview', 'word')
    ],
    index=[
        'Gemini-1.0',
        'Gemini-1.5',
        'GPT-3.5',
        'GPT-4'
        # "Gemini",
        # "ChatGPT"
    ]
)
oa.plot_stacked_graph([1,2,3,4,5,6], title="Comparison of model versions")
# Out:
# [70.4, 23.2, 6.4] [41, 10, 49]
# 1 humans ('gemini/gemini-1.0-pro-latest', 'word') [70.4, 23.2, 6.4] [41, 10, 49] Power_divergenceResult(statistic=303.34443573667716, pvalue=1.3476984278758098e-66)
# [70.4, 23.2, 6.4] [45, 6, 49]
# 1 humans ('gemini/gemini-1.5-pro-latest', 'word') [70.4, 23.2, 6.4] [45, 6, 49] Power_divergenceResult(statistic=305.4721786833856, pvalue=4.65113785147981e-67)
# [41, 10, 49] [45, 6, 49]
# 1 ('gemini/gemini-1.0-pro-latest', 'word') ('gemini/gemini-1.5-pro-latest', 'word') [41, 10, 49] [45, 6, 49] Power_divergenceResult(statistic=1.9902439024390244, pvalue=0.3696783590682848)
# [70.4, 23.2, 6.4] [86, 1, 13]
# 1 humans ('chatgpt/gpt-35-turbo-1106', 'word') [70.4, 23.2, 6.4] [86, 1, 13] Power_divergenceResult(statistic=31.506171630094038, pvalue=1.4405281769869109e-07)
# [41, 10, 49] [86, 1, 13]
# ...

# %%
oa = OutputAnalyzer(
    model_paths=[
        ('gemini/gemini-1.0-pro-latest', 'word_best_goods_centric'),
        ('gemini/gemini-1.0-pro-latest', 'word_best_goods_centric_2'),
        ('gemini/gemini-1.0-pro-latest', 'word_best_goods_centric_3'),
        ('gemini/gemini-1.0-pro-latest', 'word_best_goods_centric_4'),
        ('gemini/gemini-1.0-pro-latest', 'word_best_goods_centric_5'),
    ],
    index=[
        'Gemini-1.0',
        'Gemini-1.0',
        'Gemini-1.0',
        'Gemini-1.0',
        'Gemini-1.0',
    ]
)
oa.plot_stacked_graph([1,2,3,4,5,6], title="Comparison of model versions", figsize=(30,6))
# Out:
# [70.4, 23.2, 6.4] [65, 0, 35]
# 1 humans ('gemini/gemini-1.0-pro-latest', 'word_best_goods_centric') [70.4, 23.2, 6.4] [65, 0, 35] Power_divergenceResult(statistic=151.42045454545456, pvalue=1.3166370496776643e-33)
# [70.4, 23.2, 6.4] [60, 0, 40]
# 1 humans ('gemini/gemini-1.0-pro-latest', 'word_best_goods_centric_2') [70.4, 23.2, 6.4] [60, 0, 40] Power_divergenceResult(statistic=201.13636363636365, pvalue=2.1076261643370393e-44)
# [65, 0, 35] [60, 0, 40]
# 1 ('gemini/gemini-1.0-pro-latest', 'word_best_goods_centric') ('gemini/gemini-1.0-pro-latest', 'word_best_goods_centric_2') [65, 0, 35] [60, 0, 40] Power_divergenceResult(statistic=nan, pvalue=nan)
# [70.4, 23.2, 6.4] [58, 0, 42]
# 1 humans ('gemini/gemini-1.0-pro-latest', 'word_best_goods_centric_3') [70.4, 23.2, 6.4] [58, 0, 42] Power_divergenceResult(statistic=223.40909090909093, pvalue=3.0713711856526715e-49)
# [65, 0, 35] [58, 0, 42]
# ...

# %% [markdown]
# # Qualitative Analysis

# %%
def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
def get_single_response(auth_file, family, model, question, valuation, restriction='vanilla', template='vanilla', instruction='fairest'):
    llm = LLM(auth_file=auth_file, family=family, model=model)
    pg = PromptGenerator(question=question,valuation_type=valuation,restriction=restriction, template=template,llm_type=family,instruction=instruction)
    num_agents, num_goods = pg.set_text_values()
    prompt1 = pg.generate_prompt1()

    print(prompt1)

    df_dict = {
        'Text': [],
    }

    for g in range(num_goods):
        df_dict[f'Good {chr(65+g)}'] = []

    df_dict['Text'] = llm.makeLLMRequest(prompt1)
    prompt2 = pg.generate_prompt2(df_dict['Text'])
    # print(prompt2)

    try:
        alloc = llm.makeLLMRequest(prompt2)
    except:
        print('LLM request failed.')
        time.sleep(5)

    bopen = alloc.find('{')
    bclose = alloc.find('}')

    json_obj = json.loads(alloc[bopen:bclose+1])
    
    for g in range(num_goods):
        df_dict[f'Good {chr(65+g)}'].append(json_obj[f'Good {chr(65+g)}'].split()[-1])
    if 'money' in pg.valuations:
        for a in list(pg.valuations['valuation'].keys()):
            df_dict[f'{pg.person_names[a]} money'] = json_obj[f'{pg.person_names[a]} money']

    return df_dict

# %% [markdown]
# # Gemini

# %% [markdown]
# ## SC-1.1

# %%
df_dict = get_single_response('../Auth_keys/gemini_auth_key.txt', 'gemini', 'gemini-1.5-pro-latest', 11, 'word', 'vanilla', 'vanilla')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > ## Analyzing the Fair Allocation of Goods
# >
# > Given the values each person places on the goods, let's explore potential allocations and their fairness implications:
# >
# > **Allocation 1: Person 1 gets Goods A and C, Person 2 gets Good B.**
# >
# > * **Person 1 Value:** 80 (A) + 20 (C) = 100
# > * **Person 2 Value:** 60 (B)
# >
# > This allocation maximizes the total value (160) as each person receives the goods they value most. However, Person 1 receives significantly more value than Person 2.
# >
# > **Allocation 2: Person 1 gets Good A, Person 2 gets Goods B and C.**
# >
# > * **Person 1 Value:** 80 (A)
# > * **Person 2 Value:** 60 (B) + 20 (C) = 80
# >
# > This allocation equalizes the value received by each person. However, it might be seen as unfair to Person 1 who values Good A considerably more than Person 2.
# >
# > **Allocation 3: Person 1 gets Goods B and C, Person 2 gets Good A.**
# >
# ...

# %%
df_dict = get_single_response('../Auth_keys/gemini_auth_key.txt', 'gemini', 'gemini-1.5-pro-latest', 11, 'word', 'vanilla', 'vanilla')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > ## Analyzing the Fair Allocation of Goods
# >
# > Given the values each person places on the goods, let's explore some allocation options and their fairness implications:
# >
# > **Option 1: Maximize Total Value**
# >
# > *   **Allocation:** Give Good A to Person 1 (value 80), Good B to Person 2 (value 60), and Good C to either person (value 20).
# > *   **Total Value:** 160
# > *   **Fairness Concerns:** While this allocation maximizes the total value across both individuals, it might not be perceived as fair since Person 1 receives significantly more value (80) compared to Person 2 (60).
# >
# > **Option 2: Equal Total Value**
# >
# > *   **Allocation:** Give Good A and Good C to Person 1 (total value 100) and Good B to Person 2 (value 60). Alternatively, give Good B and Good C to Person 2 (total value 80) and Good A to Person 1 (value 80).
# > *   **Total Value:** 160 (either way)
# ...

# %%
df_dict = get_single_response('../Auth_keys/gemini_auth_key.txt', 'gemini', 'gemini-1.5-pro-latest', 11, 'word', 'vanilla', 'vanilla')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > ## Analyzing the Fair Allocation of Goods
# >
# > Given the values each person places on the goods, let's explore potential allocations and their fairness implications:
# >
# > **Option 1: Maximize Total Value**
# >
# > * **Allocation:** Give Good A to Person 1 (value 80), Good B to Person 2 (value 60), and Good C to either Person 1 or 2 (value 20).
# > * **Total Value:** 160
# > * **Fairness Concerns:** This allocation maximizes the total value derived from the goods. However, it might be perceived as unfair as Person 1 receives significantly more value (80) compared to Person 2 (60).
# >
# > **Option 2: Equal Value Distribution**
# >
# > * **Allocation:** Give Good A to Person 1 (value 80) and Good B to Person 2 (value 60). Leave Good C unallocated as giving it to either person would create an imbalance.
# > * **Total Value:** 140
# ...

# %%
df_dict = get_single_response('../Auth_keys/gemini_auth_key.txt', 'gemini', 'gemini-1.5-pro-latest', 11, 'word', 'vanilla', 'vanilla')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > ## Analyzing the Fair Allocation of Goods
# >
# > Given the preferences of Person 1 and Person 2, let's evaluate potential allocations for fairness:
# >
# > **Option 1: Allocate Good A to Person 1, Good B to Person 2, and Good C to either Person 1 or 2 (or discard it).**
# >
# > * This allocation seems fair as both individuals receive the good they value the most (Person 1 gets Good A with value 80, Person 2 gets Good B with value 60).
# > * Good C could be allocated based on a coin flip or discarded as neither person values it highly.
# >
# > **Option 2: Allocate Good A and Good C to Person 1 and Good B to Person 2.**
# >
# > * This allocation favors Person 1 significantly (total value of 100) compared to Person 2 (value of 60).
# > * While Person 1 gets both goods they value, the disparity in total value makes this option less fair.
# >
# ...

# %%
df_dict = get_single_response('../Auth_keys/gemini_auth_key.txt', 'gemini', 'gemini-1.5-pro-latest', 11, 'word', 'vanilla', 'vanilla')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['2']
# > ## Analyzing Fairness in Goods Allocation
# >
# > Given the values each person places on the goods, let's explore potential allocations and their fairness implications:
# >
# > **Allocation 1: Maximize Total Value**
# >
# > * **Person 1:** Good A (Value 80)
# > * **Person 2:** Good B (Value 60)
# > * **Good C:** Not allocated
# >
# > This allocation maximizes the total value derived from the goods (80 + 60 = 140). However, it leaves Person 2 without Good C, which they value.
# >
# > **Allocation 2: Prioritize Person 1's Preferences**
# >
# > * **Person 1:** Good A & Good C (Value 100)
# > * **Person 2:** Good B (Value 60)
# >
# > This allocation prioritizes Person 1, giving them both goods they value. While Person 2 receives their most valued good (B), they miss out on Good C, which they also value.
# >
# > **Allocation 3: Equal Distribution of Value**
# >
# > * **Person 1:** Good A (Value 80)
# ...

# %% [markdown]
# ## SC-1.2

# %%
df_dict = get_single_response('../Auth_keys/gemini_auth_key_2.txt', 'gemini', 'gemini-1.5-pro-latest', 12, 'word', 'vanilla', 'vanilla')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['1']
# > ## Analyzing the Fair Allocation of Goods
# >
# > Given the values each person places on the goods, let's explore potential allocations and their fairness implications:
# >
# > **Allocation 1: Maximize Total Value**
# >
# > * **Person 1:** Good A (value 80)
# > * **Person 2:** Good B (value 60) and Good C (value 20)
# >
# > This allocation maximizes the total value across both individuals (80 + 60 + 20 = 160). However, it might not be entirely fair as Person 1 receives only one good while Person 2 receives two.
# >
# > **Allocation 2: Prioritize High-Value Goods**
# >
# > * **Person 1:** Good A (value 80) and Good C (value 15)
# > * **Person 2:** Good B (value 60)
# >
# > This allocation ensures both individuals receive their highest-valued good. Person 1 gets a combined value of 95, and Person 2 gets a value of 60. This seems fairer in terms of addressing individual preferences.
# >
# > **Allocation 3: Equal Distribution of Goods**
# ...

# %%
df_dict = get_single_response('../Auth_keys/gemini_auth_key.txt', 'gemini', 'gemini-1.5-pro-latest', 12, 'word', 'vanilla', 'vanilla')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['1']
# > ## Analyzing the Fair Allocation of Goods
# >
# > Given the values each person places on the goods, here's an analysis of possible allocations and their fairness considerations:
# >
# > **Allocation 1: Maximize Total Value**
# >
# > * **Person 1 gets:** Good A (value 80)
# > * **Person 2 gets:** Good B (value 60)
# > * **Good C is not allocated**
# >
# > This allocation maximizes the total value derived from the goods (80 + 60 = 140).  However, it might not be perceived as fair since Person 2 doesn't receive Good C, which they value at 20.
# >
# > **Allocation 2: Prioritize High-Value Goods**
# >
# > * **Person 1 gets:** Good A (value 80) and Good C (value 15)
# > * **Person 2 gets:** Good B (value 60)
# >
# ...

# %%
df_dict = get_single_response('../Auth_keys/gemini_auth_key.txt', 'gemini', 'gemini-1.5-pro-latest', 12, 'word', 'vanilla', 'vanilla')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['1']
# > ## Analyzing the Fair Allocation of Goods
# >
# > Given the individual valuations of Person 1 and Person 2 for goods A, B, and C, let's explore potential allocations and their fairness implications:
# >
# > **Possible Allocations:**
# >
# > 1. **Maximize Total Value:**
# >     * Allocate Good A to Person 1 (value 80) and Good B to Person 2 (value 60).
# >     * Good C can be allocated to either person or discarded as it has equal value to both.
# >     * This allocation achieves the highest total value (140) but might seem unfair as Person 1 receives significantly more value.
# >
# > 2. **Equal Total Value:**
# >     * Allocate Good A to Person 1 (value 80) and Good B and C to Person 2 (total value 80).
# >     * This allocation ensures both individuals receive the same total value, promoting equality.
# >     * However, Person 1 might feel unfairly treated as they only receive one good while Person 2 receives two.
# >
# ...

# %%
df_dict = get_single_response('../Auth_keys/gemini_auth_key.txt', 'gemini', 'gemini-1.5-pro-latest', 12, 'word', 'vanilla', 'vanilla')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > ## Analyzing the Fair Allocation of Goods
# >
# > Given the individual valuations of Person 1 and Person 2 for goods A, B, and C, let's explore potential allocations and their fairness implications:
# >
# > **Allocation 1: Maximize Total Value**
# >
# > *   **Person 1:** Good A (Value: 80)
# > *   **Person 2:** Good B (Value: 60) and Good C (Value: 20)
# >
# > This allocation maximizes the total value derived from the goods (80 + 60 + 20 = 160). However, it might not be perceived as fair as Person 1 receives only one good while Person 2 receives two.
# >
# > **Allocation 2: Equal Number of Goods**
# >
# > *   **Person 1:** Good A (Value: 80) and Good C (Value: 15)
# > *   **Person 2:** Good B (Value: 60)
# >
# > This allocation ensures both individuals receive an equal number of goods. However, the values derived are not equal (Person 1: 95, Person 2: 60).
# >
# > **Allocation 3: Equal Value**
# >
# ...

# %%
df_dict = get_single_response('../Auth_keys/gemini_auth_key.txt', 'gemini', 'gemini-1.5-pro-latest', 12, 'word', 'vanilla', 'vanilla')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > ## Analyzing the Fair Allocation of Goods
# >
# > Given the information about Person 1 and Person 2's values for the goods, let's explore possible allocations and their fairness implications:
# >
# > **Option 1: Allocate based on maximum value:**
# >
# > * **Good A to Person 1:** This makes sense as Person 1 values it significantly more (80) than Person 2 (20).
# > * **Good B to Person 2:** Similarly, Person 2 values Good B much more (60) than Person 1 (5).
# > * **Good C to Person 2:** Again, Person 2 values Good C more (20) than Person 1 (15).
# >
# > This allocation maximizes the total value derived from the goods. However, it might seem unfair as Person 2 receives two goods while Person 1 receives only one.
# >
# > **Option 2: Allocate one good to each person based on highest individual value:**
# >
# > * **Good A to Person 1:** As before, Person 1 values it the most.
# ...

# %% [markdown]
# ## SC-1.1 + EQ instruct

# %%
df_dict = get_single_response('../Auth_keys/gemini_auth_key.txt', 'gemini', 'gemini-1.5-pro-latest', 11, 'word', instruction='EQ')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that ensures each individuals has the same total value for the good(s) they respectively receive..

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > ## Fair Allocation of Goods:
# >
# > Given the values each person assigns to the goods, achieving a perfectly equal total value for both individuals isn't possible without discarding one good. Here's the breakdown:
# >
# > * **Total value across all goods:** 80 (A) + 60 (B) + 20 (C) = 160
# > * **Equal value target for each person:** 160 / 2 = 80
# >
# > **Allocation Options:**
# >
# > 1. **Person 1 gets Good A, Person 2 gets Good B:** This achieves the equal target value of 80 for both individuals. Good C would be discarded as neither person values it highly and including it for either person would create an imbalance.
# >
# > 2. **Discard Good B, allocate Good A and C:**  In this scenario, both individuals receive a total value of 40, which is less than the optimal 80 but ensures fairness.
# >
# > **Recommendation:**
# >
# ...

# %%
df_dict = get_single_response('../Auth_keys/gemini_auth_key_2.txt', 'gemini', 'gemini-1.5-pro-latest', 11, 'word', instruction='EQ')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that ensures each individuals has the same total value for the good(s) they respectively receive..

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['2']
# > The total value of the goods is 80 + 0 + 20 + 20 + 60 + 20 = 200. To ensure each individual has the same total value, each should receive goods worth 100.
# >
# > One possible allocation that satisfies this condition is to give Good A to Person 1, and Good B to Person 2. This gives Person 1 a total value of 80, and Person 2 a total value of 60. To make the total value for each person 100, Person 2 can receive Good C as well.
# >
# > Therefore, the fair allocation is:
# >
# > * Person 1 receives Good A
# > * Person 2 receives Goods B and C
# >
# > This allocation ensures that both individuals have the same total value of 100.

# %%
df_dict = get_single_response('../Auth_keys/gemini_auth_key.txt', 'gemini', 'gemini-1.5-pro-latest', 11, 'word', instruction='EQ')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that ensures each individuals has the same total value for the good(s) they respectively receive.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > ## Fair Allocation of Goods:
# >
# > Given the individual preferences, here's an allocation that ensures both Person 1 and Person 2 receive the same total value:
# >
# > * **Person 1 receives Good A.**
# > * **Person 2 receives Good B.**
# > * **Good C is not allocated (or discarded).**
# >
# > **Explanation:**
# >
# > * With this allocation, Person 1 receives a value of 80 (from Good A).
# > * Person 2 receives a value of 60 (from Good B).
# > *  Since Good C has equal value to both individuals and allocating it would create an imbalance, it's best left unallocated.
# >
# > This scenario satisfies the condition of equal total value for both individuals.

# %%
df_dict = get_single_response('../Auth_keys/gemini_auth_key_2.txt', 'gemini', 'gemini-1.5-pro-latest', 11, 'word', instruction='EQ')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that ensures each individuals has the same total value for the good(s) they respectively receive.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['1']
# > ## Finding a Fair Allocation
# >
# > To ensure both Person 1 and Person 2 have the same total value for the goods they receive, we need to consider their preferences and the value they assign to each good.
# >
# > **Here's how we can approach this:**
# >
# > 1. **Calculate the total value available:**
# >     - Add the value each person assigns to each good.
# >     - Total Value = (80 + 0 + 20) + (20 + 60 + 20) = 200
# >
# > 2. **Determine the target value for each person:**
# >     - Since we want an equal allocation, each person should get a total value of half the total value available.
# >     - Target Value per person = 200 / 2 = 100
# >
# > 3. **Analyze individual preferences and possible allocations:**
# >     - **Person 1:** Values Good A the most (80) and Good C (20).
# >     - **Person 2:** Values Good B the most (60) and equally values Good A and C (20 each).
# >
# > 4. **Allocate goods to achieve the target value:**
# ...

# %%
df_dict = get_single_response('../Auth_keys/gemini_auth_key_2.txt', 'gemini', 'gemini-1.5-pro-latest', 11, 'word', instruction='EQ')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that ensures each individuals has the same total value for the good(s) they respectively receive.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['2']
# > ## Fair Allocation of Goods:
# >
# > To ensure both Person 1 and Person 2 have the same total value for the goods they receive, we need to analyze their preferences and the value they associate with each good.
# >
# > **Analysis:**
# >
# > * **Person 1:** Values Good A the most (80), followed by Good C (20), and has no value for Good B (0).
# > * **Person 2:** Values Good B the most (60), followed by both Good A and Good C equally (20 each).
# >
# > **Allocation for Equal Value:**
# >
# > To achieve equal total value for both individuals, we can allocate the goods as follows:
# >
# > * **Person 1 receives Good A:** This gives Person 1 a total value of 80.
# > * **Person 2 receives Good B and Good C:** This gives Person 2 a total value of 60 (from Good B) + 20 (from Good C) = 80.
# >
# > This allocation ensures both individuals have the same total value (80) for the goods they receive, achieving fairness in the distribution.

# %% [markdown]
# ## SC 13

# %% [markdown]
# ## SC 14

# %% [markdown]
# ## SC 15

# %% [markdown]
# ## SC 21

# %% [markdown]
# ## SC 22

# %% [markdown]
# # ChatGPT - 3.5

# %% [markdown]
# ## SC-1.1

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 11, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['1']
# > One potential way to approach this problem is to use the concept of "maximizing the social welfare," which means trying to allocate the goods in a way that maximizes the total value received by both individuals combined.
# >
# > In this case, if we try to maximize the total value received by both Person 1 and Person 2, we could allocate Good A to Person 1 (with a value of 80), Good B to Person 2 (with a value of 60), and Good C to Person 1 (with a value of 20).
# >
# > This allocation would result in a total value of 80 (from Person 1) + 60 (from Person 2) + 20 (from Person 1) = 160.
# >
# > Alternatively, we could also allocate Good A to Person 1 (with a value of 80), Good B to Person 1 (with a value of 0), and Good C to Person 2 (with a value of 20).
# >
# > This allocation would result in a total value of 80 (from Person 1) + 0 (from Person 1) + 20 (from Person 2) = 100.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 11, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > There are various methods to determine a fair allocation, such as maximizing total value, fair division algorithms, or considering each person's preferences. One possible fair allocation in this scenario could be:
# >
# > - Give Good A to Person 1, as it has the highest value for them (80).
# > - Give Good B to Person 2, as it has the highest value for them (60).
# > - Do not allocate Good C to either person, as neither of them values it significantly higher than the other.
# >
# > This allocation ensures that each person receives a good that is of high value to them, and the unallocated Good C is not wasted. However, there are several other possible fair allocations based on different criteria or fairness principles.

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 11, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > To determine the fairest allocation, we can consider different approaches such as maximizing total value, maximizing minimum value for each person, or using a fair division algorithm.
# >
# > One potential fair allocation could be to give Good A to Person 1 (since their value for it is higher), Good B to Person 2, and not allocate Good C to anyone. This way, both individuals receive a good that they highly value, and the unallocated good does not go to waste.
# >
# > Another approach could be to use a fair division algorithm such as the "divide and choose" method, where one person divides the goods into what they perceive to be equal shares, and the other person gets to choose their preferred share. This method ensures that both individuals feel they are receiving a fair share of the goods.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 11, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > There are several ways to approach this problem, and different people may have different ideas of what is "fair". One possible approach is to allocate the goods in a way that maximizes the total value that can be obtained from them.
# >
# > In this case, one possible allocation could be:
# > - Person 1 receives Good A (value 80)
# > - Person 2 receives Good B (value 60)
# > - Good C is not allocated to either person
# >
# > This allocation maximizes the total value obtained, as it gives each person the good that they value the most. It also ensures that the goods are not wasted by being allocated to someone who does not value them highly.
# >
# > Another approach could be to try to equalize the value obtained by each person, in which case an allocation such as:
# > - Person 1 receives Good A (value 80)
# > - Person 2 receives Good C (value 20)
# > - Good B is not allocated to either person
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 11, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > One way to approach this problem is to use the concept of efficiency and fairness in allocation. One possible solution could be to allocate Good A to Person 1, Good B to Person 2, and not allocate Good C to either person, as it would not increase the total value. This would result in Person 1 receiving a total value of 80, Person 2 receiving a total value of 60, and a total value of 140 being achieved.
# >
# > Another approach could be to use a method such as the "max-min fair division" where each person receives their highest value good, and the remaining good is allocated such that the lowest value for each person is maximized. In this case, Good A would go to Person 1, Good B to Person 2, and Good C to Person 1, resulting in Person 1 receiving a total value of 100, and Person 2 receiving a total value of 60.
# >
# ...

# %% [markdown]
# ## SC-1.2

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 12, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > There are several ways to approach this problem. One potential solution could be to allocate the goods based on the total value that each person places on the goods. In this case, the allocation could be as follows:
# >
# > Person 1 receives Good A (valued at 80) and Person 2 receives Good B (valued at 60). Since Person 1's value for Good B is lower than Person 2's, and Person 2's value for Good A is lower than Person 1's, the remaining good, Good C, could be thrown away as neither person values it highly.
# >
# > Another approach could be to allocate the goods based on the overall impact it would have on each person's total value. In this case, the allocation could be as follows:
# >
# > Person 1 receives Good A (valued at 80) and Person 2 receives Good B (valued at 60). This allocation ensures that each person receives the good with the highest impact on their total value.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 12, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > One way to approach this problem is to use the concept of maximum total value. This means allocating the goods in a way that maximizes the total value obtained by both individuals.
# >
# > In this case, since the goods are indivisible, we need to consider all possible allocations and choose the one that maximizes the total value.
# >
# > - Option 1: Allocate Good A to Person 1, Good B to Person 2, and discard Good C.
# >     - Total value: 80 (Person 1) + 60 (Person 2) = 140
# >
# > - Option 2: Allocate Good A to Person 1, Good C to Person 2, and discard Good B.
# >     - Total value: 80 (Person 1) + 20 (Person 2) = 100
# >
# > - Option 3: Allocate Good B to Person 1, Good A to Person 2, and discard Good C.
# >     - Total value: 20 (Person 1) + 60 (Person 2) = 80
# >
# > - Option 4: Allocate Good B to Person 1, Good C to Person 2, and discard Good A.
# >     - Total value: 5 (Person 1) + 20 (Person 2) = 25
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 12, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['1']
# > There are several approaches that can be used to determine a fair allocation of the goods. One possible approach is to use the concept of maximum total value, which involves allocating each good to the person who values it the most.
# >
# > In this case, you could allocate Good A to Person 1, as they have a higher value for it compared to Person 2. Then you could allocate Good B to Person 2, and Good C to Person 2 as well. This allocation ensures that each good is given to the person who values it the most, maximizing the total value generated from the allocation.
# >
# > Another approach could be to use the concept of envy-free allocations, where no individual prefers the allocation of another individual. In this case, you could allocate Good A to Person 1, Good B to Person 2, and Good C to Person 1. This allocation ensures that neither person envies the other's allocation, making it fair from an envy-free perspective.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 12, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > There are several ways to approach this problem, and fairness is subjective. One way to determine a fair allocation is to maximize the total value obtained by both individuals.
# >
# > In this case, if we allocate Good A to Person 1, Good B to Person 2, and Good C to Person 2, the total value obtained is 80 (Person 1) + 60 (Person 2) + 20 (Person 2) = 160.
# >
# > If we allocate Good A to Person 1, Good B to Person 1, and Good C to Person 2, the total value obtained is 80 (Person 1) + 5 (Person 1) + 20 (Person 2) = 105.
# >
# > If we allocate Good A to Person 1, Good B to Person 2, and do not allocate Good C, the total value obtained is 80 (Person 1) + 60 (Person 2) = 140.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 12, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > There are various ways to approach the fair allocation of the goods. One method is to allocate the goods in a way that maximizes the total value obtained by both individuals. Another method is to ensure that each individual receives a fair share of the goods based on their values.
# >
# > One possible fair allocation could be to allocate Good A to Person 1, Good B to Person 2, and not allocate Good C to either person. This allocation maximizes the total value obtained as Person 1 values Good A the most and Person 2 values Good B the most.
# >
# > Another possible fair allocation could be to allocate Good A to Person 1, Good B to Person 2, and allocate Good C to Person 1. This allocation ensures that both individuals receive a good that they value highly.
# >
# ...

# %% [markdown]
# ## SC-1.1 + EQ instruct

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 12, 'word', instruction='EQ')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that ensures each individuals has the same total value for the good(s) they respectively receive.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['None']
# Good B: ['None']
# Good C: ['None']
# > To determine a fair allocation, we can use the concept of envy-free allocation, where each person values the good they receive at least as much as the good the other person receives.
# >
# > To start, let's consider all possible allocations:
# >
# > 1. Person 1 gets Good A (value 80), Person 2 gets Good B and C (total value 80)
# > 2. Person 1 gets Good B (value 5), Person 2 gets Good A and C (total value 100)
# > 3. Person 1 gets Good C (value 15), Person 2 gets Good A and B (total value 100)
# > 4. Person 1 gets Good A and B (total value 85), Person 2 gets Good C
# > 5. Person 1 gets Good A and C (total value 95), Person 2 gets Good B
# > 6. Person 1 gets Good B and C (total value 65), Person 2 gets Good A
# > 7. Both goods are thrown away (total value 0 for each person)
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 12, 'word', instruction='EQ')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that ensures each individuals has the same total value for the good(s) they respectively receive.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['1']
# > To determine a fair allocation of the goods, we can use the concept of the maximum value division, also known as the max-min allocation.
# >
# > First, we calculate the total value that each person places on all the goods:
# > Person 1's total value = 80 + 5 + 15 = 100
# > Person 2's total value = 20 + 60 + 20 = 100
# >
# > Since both individuals have the same total value, we can use the following allocation to ensure each person has the same total value for the goods:
# > - Allocate Good A to Person 1, as it has the highest value for them.
# > - Allocate Good B to Person 2, as it has the highest value for them.
# > - Allocate Good C to Person 1, as it has the second highest value for them after Good A.
# >
# > This allocation ensures that each person receives goods with a total value of 80, which is fair and maximizes the minimum value received by each person.

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 12, 'word', instruction='EQ')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that ensures each individuals has the same total value for the good(s) they respectively receive.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['1']
# > To determine a fair allocation that ensures each individual has the same total value for the goods they receive, we can use the following approach.
# >
# > We will assign each good to the person who values it the most. If there is a tie in value, we will randomly allocate the good to one of the individuals.
# >
# > First, let's compare the values for each good:
# > - Person 1's total value for Good A, B, and C is 80 + 5 + 15 = 100.
# > - Person 2's total value for Good A, B, and C is 20 + 60 + 20 = 100.
# >
# > Since both individuals have the same total value, we can allocate the goods as follows:
# > - Good A will be allocated to Person 1 since they value it the most.
# > - Good B will be allocated to Person 2 since they value it the most.
# > - Good C will be allocated to Person 1 since they value it the most.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 12, 'word', instruction='EQ')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that ensures each individuals has the same total value for the good(s) they respectively receive.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > In order to determine a fair allocation of the goods, we can use the concept of maximum value division, where the goods are allocated to maximize the total value received by each individual.
# >
# > First, let's consider Person 1's values for the goods:
# > - Good A: 80
# > - Good B: 5
# > - Good C: 15
# >
# > Now, let's consider Person 2's values for the goods:
# > - Good A: 20
# > - Good B: 60
# > - Good C: 20
# >
# > To determine the fair allocation, we should allocate the goods in a way that maximizes the total value received by each individual. In this case, we can give Good A to Person 1 and Good B to Person 2, as these are their highest valued goods.
# >
# > So, the fair allocation would be:
# > - Person 1 receives Good A with a value of 80
# > - Person 2 receives Good B with a value of 60
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 12, 'word', instruction='EQ')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that ensures each individuals has the same total value for the good(s) they respectively receive.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > To determine a fair allocation of the goods, we can use the concept of envy-free allocation. In this case, an allocation is envy-free if each person values their allocated goods at least as much as the goods allocated to the other person.
# >
# > We can start by finding the total value of the goods for each person:
# > - Person 1's total value = 80 (Good A) + 5 (Good B) + 15 (Good C) = 100
# > - Person 2's total value = 20 (Good A) + 60 (Good B) + 20 (Good C) = 100
# >
# > Now, let's try different allocations to see what would be fair for both individuals.
# >
# > Allocation 1: Person 1 gets Good A, Person 2 gets Good B and Good C are thrown away.
# > - Person 1's total value = 80
# > - Person 2's total value = 80 (Good B) + 20 (Good C) = 100
# >
# > This allocation is not envy-free because Person 1 values their good less than Person 2.
# >
# > Allocation 2: Person 1 gets Good A and Good C, Person 2 gets Good B.
# ...

# %% [markdown]
# ## SC 13

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 13, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 2 goods, namely , Good A, and Good B. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 90, and for Good B is 10.
# Person 2's value for Good A is 60, and for Good B is 40.
# A total of 50 units of money are also available for allocation. This amount of money is worth exactly as much as a good of the same value, for each individual. Since this is a divisible resource, parts of it can be allocated to different agents, although the total money allocated cannot exceed 50 units.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['2']
# Good B: ['1']
# Person 1 money: 20
# Person 2 money: 30
# > One possible approach to determining a fair allocation of the goods and money would be to use the concept of the "fair division" method. One common method is the 'divide and choose' method, which involves one person dividing the goods and the other person choosing their preferred portion.
# >
# > In this case, since there are only two individuals involved, we can use the following approach to allocate the goods and money:
# >
# > 1. Person 1 divides the goods and money into two portions that they consider to be of equal value.
# > 2. Person 2 then chooses which portion they prefer.
# >
# > Applying this method to the problem at hand:
# >
# > Person 1 can divide the goods and money in the following manner:
# > - Portion 1: Good A (value 90) and 20 units of money
# > - Portion 2: Good B (value 10) and 30 units of money
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 13, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 2 goods, namely , Good A, and Good B. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 90, and for Good B is 10.
# Person 2's value for Good A is 60, and for Good B is 40.
# A total of 50 units of money are also available for allocation. This amount of money is worth exactly as much as a good of the same value, for each individual. Since this is a divisible resource, parts of it can be allocated to different agents, although the total money allocated cannot exceed 50 units.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Person 1 money: 0
# Person 2 money: 30
# > One way to approach this problem is to use the concept of Pareto efficiency, which aims to maximize the total value of the goods allocated.
# >
# > One possible fair allocation could be to allocate Good A to Person 1 and Good B to Person 2. This allocation would result in a total value of 100 (90 for Person 1 and 40 for Person 2) which is the highest possible total value.
# >
# > Another possible fair allocation could be to allocate Good A to Person 1 and allocate 30 units of money to Person 2. This allocation would result in a total value of 120 (90 for Person 1 and 60 for Person 2), which is the highest possible total value.
# >
# > It's important to note that fairness is subjective and different allocation methods could be considered fair depending on the perspective. But in this case, both of these allocations result in a Pareto efficient outcome where the total value is maximized.

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 13, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 2 goods, namely , Good A, and Good B. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 90, and for Good B is 10.
# Person 2's value for Good A is 60, and for Good B is 40.
# A total of 50 units of money are also available for allocation. This amount of money is worth exactly as much as a good of the same value, for each individual. Since this is a divisible resource, parts of it can be allocated to different agents, although the total money allocated cannot exceed 50 units.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Person 1 money: 0
# Person 2 money: 30
# > One possible fair allocation could be to allocate Good A to Person 1 and Good B to Person 2, as this maximizes the total value generated from the allocation. This would result in Person 1 receiving a value of 90 and Person 2 receiving a value of 40, which maximizes the total value generated from the allocation.
# >
# > Alternatively, you could allocate Good A to Person 1 and allocate 30 units of money to Person 2, as Person 1 values Good A more than Person 2, and Person 2 values the money more than Good B. This would result in Person 1 receiving a value of 90 and Person 2 receiving a value of 90, which seems fair as both individuals receive the same value.
# >
# > Ultimately, the fairest allocation depends on the criteria used for fairness, and there may be multiple potential solutions.

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 13, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 2 goods, namely , Good A, and Good B. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 90, and for Good B is 10.
# Person 2's value for Good A is 60, and for Good B is 40.
# A total of 50 units of money are also available for allocation. This amount of money is worth exactly as much as a good of the same value, for each individual. Since this is a divisible resource, parts of it can be allocated to different agents, although the total money allocated cannot exceed 50 units.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Person 1 money: 25
# Person 2 money: 25
# > There are different approaches to determine fair allocations, but one commonly used method is the proportional allocation, where each person receives a share of the goods and money that is proportional to their value.
# >
# > In this case, we can calculate the total value each person places on the goods:
# > Person 1: 90 (Good A) + 10 (Good B) = 100
# > Person 2: 60 (Good A) + 40 (Good B) = 100
# >
# > Then we can calculate the proportion of the total value each person contributes:
# > Person 1: 100/200 = 0.5
# > Person 2: 100/200 = 0.5
# >
# > This means that each person contributes 50% of the total value.
# >
# > Using this proportional approach, we can allocate the goods and money accordingly:
# > - Person 1 receives 25 units of money (50 * 0.5) and 1 unit of Good A.
# > - Person 2 receives 25 units of money (50 * 0.5) and 1 unit of Good B.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 13, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 2 goods, namely , Good A, and Good B. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 90, and for Good B is 10.
# Person 2's value for Good A is 60, and for Good B is 40.
# A total of 50 units of money are also available for allocation. This amount of money is worth exactly as much as a good of the same value, for each individual. Since this is a divisible resource, parts of it can be allocated to different agents, although the total money allocated cannot exceed 50 units.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Person 1 money: 10
# Person 2 money: 40
# > One possible approach to determining a fair allocation of the goods and money could be to use the concept of "fair division". One method of fair division is the "max-min" or "divide and choose" method. In this method, one person (let's say Person 1) is designated as the divider, and the other person (Person 2) is designated as the chooser.
# >
# > Person 1 can divide the goods and money into two portions that they consider to be fair, and then Person 2 gets to choose which portion they prefer. This ensures that Person 1 will strive to make the division as fair as possible to avoid Person 2 choosing the portion that is less favorable.
# >
# > In this specific scenario, one possible fair allocation could be as follows:
# > - Person 1 could allocate Good A and 10 units of money to themselves, and give Good B and 40 units of money to Person 2.
# ...

# %% [markdown]
# ## SC 14

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 14, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 2 goods, namely , Good A, and Good B. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, and for Good B is 20.
# Person 2's value for Good A is 60, and for Good B is 40.
# A total of 50 units of money are also available for allocation. This amount of money is worth exactly as much as a good of the same value, for each individual. Since this is a divisible resource, parts of it can be allocated to different agents, although the total money allocated cannot exceed 50 units.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Person 1 money: 20
# Person 2 money: 30
# > There are different ways to approach this problem. One way to determine a fair allocation is to use the concept of efficiency, where you try to allocate the goods in a way that maximizes the total value that the goods provide to the individuals.
# >
# > One possible allocation that you could consider is to allocate Good A to Person 1, as Person 1 values it higher than Person 2, and allocate Good B to Person 2, as Person 2 values it higher than Person 1. This allocation would maximize the total value obtained from the goods.
# >
# > As for the money, you could allocate it in a way that equalizes the marginal utility of the last unit of money for both individuals. This means that you could allocate the money in a way that makes both individuals equally better off.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 14, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 2 goods, namely , Good A, and Good B. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, and for Good B is 20.
# Person 2's value for Good A is 60, and for Good B is 40.
# A total of 50 units of money are also available for allocation. This amount of money is worth exactly as much as a good of the same value, for each individual. Since this is a divisible resource, parts of it can be allocated to different agents, although the total money allocated cannot exceed 50 units.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Person 1 money: 10
# Person 2 money: 10
# > There are several ways to approach this problem. One method is to use the concept of maximin fairness, where the goal is to maximize the minimum value that each person receives.
# >
# > One possible allocation could be to give Person 1 Good A and Person 2 Good B, as this maximizes the minimum value each person receives. In this allocation, both Person 1 and Person 2 would receive a good with a value of 80, which is their highest value for any good.
# >
# > Another approach could be to consider the total value of each good for each person and allocate based on that. In this case, allocating Good A to Person 1 and Good B to Person 2 would result in a total value of 100 for Person 1 and 100 for Person 2. This allocation maximizes the total value received by both individuals.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 14, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 2 goods, namely , Good A, and Good B. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, and for Good B is 20.
# Person 2's value for Good A is 60, and for Good B is 40.
# A total of 50 units of money are also available for allocation. This amount of money is worth exactly as much as a good of the same value, for each individual. Since this is a divisible resource, parts of it can be allocated to different agents, although the total money allocated cannot exceed 50 units.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Person 1 money: 40
# Person 2 money: 10
# > There are different ways to approach the problem of fair allocation in this scenario. One way to determine a fair allocation is to use the concept of maximum total value. In this approach, you could allocate the goods and money in a way that maximizes the total value that the individuals receive from the allocation.
# >
# > In this case, you could allocate Good A to Person 1, as their value for Good A is higher than Person 2's value. Then, you could allocate Good B to Person 2, as their value for Good B is higher than Person 1's value. This allocation would maximize the total value obtained from the allocation of goods.
# >
# > As for the money, you could allocate 30 units to Person 1 and 20 units to Person 2. This way, the total value obtained from the allocation of money is also maximized.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 14, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 2 goods, namely , Good A, and Good B. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, and for Good B is 20.
# Person 2's value for Good A is 60, and for Good B is 40.
# A total of 50 units of money are also available for allocation. This amount of money is worth exactly as much as a good of the same value, for each individual. Since this is a divisible resource, parts of it can be allocated to different agents, although the total money allocated cannot exceed 50 units.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Person 1 money: 30
# Person 2 money: 20
# > One way to approach this problem is to use the concept of the maximin value, which identifies the maximum value that each individual can obtain, and then compare these values to determine the fairest allocation.
# >
# > For Person 1, the maximum value they can obtain is 80 for Good A. For Person 2, the maximum value they can obtain is 60 for Good A.
# >
# > Considering the maximum value for each person, it would be fair to allocate Good A to Person 1, as it provides the highest value to them. This means that Person 2 would not receive Good A.
# >
# > For Good B, the values are 20 for Person 1 and 40 for Person 2. In this case, it would be fair to allocate Good B to Person 2, as it provides the highest value to them. This means that Person 1 would not receive Good B.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 14, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 2 goods, namely , Good A, and Good B. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, and for Good B is 20.
# Person 2's value for Good A is 60, and for Good B is 40.
# A total of 50 units of money are also available for allocation. This amount of money is worth exactly as much as a good of the same value, for each individual. Since this is a divisible resource, parts of it can be allocated to different agents, although the total money allocated cannot exceed 50 units.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Person 1 money: 40
# Person 2 money: 10
# > One way to approach this problem is to use the concept of "maximin fairness," which means maximizing the minimum value that each person receives. In this case, we can calculate the maximum value each person can receive for the goods and the money.
# >
# > For Person 1:
# > - Maximum value for Good A = 80
# > - Maximum value for Good B = 20
# > - Maximum value for money = 50
# >
# > For Person 2:
# > - Maximum value for Good A = 60
# > - Maximum value for Good B = 40
# > - Maximum value for money = 50
# >
# > Now let's consider the following allocations:
# >
# > Allocation 1:
# > - Person 1 receives Good A, worth 80, and 20 units of money
# > - Person 2 receives Good B, worth 40, and 30 units of money
# >
# > In this allocation, Person 1 receives a total value of 100, and Person 2 receives a total value of 70.
# >
# > Allocation 2:
# > - Person 1 receives Good A, worth 80, and 20 units of money
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 14, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 2 goods, namely , Good A, and Good B. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, and for Good B is 20.
# Person 2's value for Good A is 60, and for Good B is 40.
# A total of 50 units of money are also available for allocation. This amount of money is worth exactly as much as a good of the same value, for each individual. Since this is a divisible resource, parts of it can be allocated to different agents, although the total money allocated cannot exceed 50 units.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Person 1 money: 10
# Person 2 money: 40
# > There are multiple ways to determine a fair allocation in this scenario. One possible approach is to use the concept of Maximin share, where you try to maximize the minimum value that each individual receives.
# >
# > One way to allocate the goods and money is as follows:
# > - Give Person 1 Good A, as their value for it is higher at 80, and Person 2 Good B, as their value for it is higher at 40.
# > - Allocate 20 units of money to Person 1, as they have a lower value for Good B at 20, and allocate 30 units of money to Person 2, as their value for Good A is lower at 60.
# >
# > This allocation ensures that each person gets a good that they highly value and also receives a fair amount of money to compensate for the value of the good they did not receive.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 14, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 2 goods, namely , Good A, and Good B. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, and for Good B is 20.
# Person 2's value for Good A is 60, and for Good B is 40.
# A total of 50 units of money are also available for allocation. This amount of money is worth exactly as much as a good of the same value, for each individual. Since this is a divisible resource, parts of it can be allocated to different agents, although the total money allocated cannot exceed 50 units.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Person 1 money: 40
# Person 2 money: 10
# > There are a few ways to approach this problem, but one way to determine the fairest allocation is to use the concept of the competitive equilibrium. In a competitive equilibrium, goods and money are allocated in such a way that no individual can be made better off without making someone else worse off.
# >
# > One possible allocation could be to give Good A to Person 1 and Good B to Person 2, and allocate the remaining money in such a way that both individuals are indifferent between the amount of money they receive and the goods they did not receive.
# >
# > In this case, Person 1's total value would be 80 (for Good A) + 0 (for Good B) + x (the amount of money) and Person 2's total value would be 0 (for Good A) + 40 (for Good B) + (50-x) (the amount of money), where x is the amount of money allocated to Person 1.
# >
# ...

# %% [markdown]
# ## SC 15

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 15, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 2 goods, namely , Good A, and Good B. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 66, and for Good B is 34.
# Person 2's value for Good A is 60, and for Good B is 40.
# A total of 50 units of money are also available for allocation. This amount of money is worth exactly as much as a good of the same value, for each individual. Since this is a divisible resource, parts of it can be allocated to different agents, although the total money allocated cannot exceed 50 units.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Person 1 money: 0
# Person 2 money: 50
# > There are different ways to determine a fair allocation in this scenario. One approach could be to use the concept of the competitive equilibrium from equal incomes (CEEI), where the goods and money are allocated in a way that maximizes the total value obtained by the two individuals.
# >
# > To do this, we can calculate the total value each individual would get if they were allocated both goods, and then compare it to the total value they would get if they were given the 50 units of money instead.
# >
# > For Person 1:
# > Total value of Goods A and B = 66 + 34 = 100
# > Total value of 50 units of money = 50
# >
# > For Person 2:
# > Total value of Goods A and B = 60 + 40 = 100
# > Total value of 50 units of money = 50
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 15, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 2 goods, namely , Good A, and Good B. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 66, and for Good B is 34.
# Person 2's value for Good A is 60, and for Good B is 40.
# A total of 50 units of money are also available for allocation. This amount of money is worth exactly as much as a good of the same value, for each individual. Since this is a divisible resource, parts of it can be allocated to different agents, although the total money allocated cannot exceed 50 units.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Person 1 money: 25
# Person 2 money: 25
# > One way to approach this problem is to try to maximize the total value obtained by both individuals.
# >
# > If we allocate Good A to Person 1 and Good B to Person 2, the total value obtained is 66 + 40 = 106. However, in this case, Person 2 does not receive any value for Good A, even though they value it at 60.
# >
# > If we allocate Good A to Person 2 and Good B to Person 1, the total value obtained is 60 + 34 = 94. Again, in this case, Person 1 does not receive any value for Good B, even though they value it at 34.
# >
# > Another approach could be to allocate Goods A and B to the individuals based on the value they place on the goods. Person 1 values Good A higher than Person 2, and Person 2 values Good B higher than Person 1.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 15, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 2 goods, namely , Good A, and Good B. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 66, and for Good B is 34.
# Person 2's value for Good A is 60, and for Good B is 40.
# A total of 50 units of money are also available for allocation. This amount of money is worth exactly as much as a good of the same value, for each individual. Since this is a divisible resource, parts of it can be allocated to different agents, although the total money allocated cannot exceed 50 units.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Person 1 money: 33
# Person 2 money: 20
# > There are various methods to determine a fair allocation in this scenario. One possible approach is to use the concept of maximizing the sum of the minimum values each person receives (also known as the max-min fairness criterion).
# >
# > First, let's calculate the total value for each person:
# > Person 1's total value = 66 (Good A) + 34 (Good B) = 100
# > Person 2's total value = 60 (Good A) + 40 (Good B) = 100
# >
# > Now, we need to distribute the 50 units of money in a way that maximizes the minimum value each person receives. This could be done by obtaining a value ratio for each good for each person:
# > - For Person 1, the value ratio for Good A is 66/100 = 0.66, and for Good B is 34/100 = 0.34
# > - For Person 2, the value ratio for Good A is 60/100 = 0.60, and for Good B is 40/100 = 0.40
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 15, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 2 goods, namely , Good A, and Good B. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 66, and for Good B is 34.
# Person 2's value for Good A is 60, and for Good B is 40.
# A total of 50 units of money are also available for allocation. This amount of money is worth exactly as much as a good of the same value, for each individual. Since this is a divisible resource, parts of it can be allocated to different agents, although the total money allocated cannot exceed 50 units.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Person 1 money: 40
# Person 2 money: 10
# > There are different ways to determine a fair allocation in this scenario. One approach could be to allocate the goods and money in a way that maximizes the total value created.
# >
# > One possible allocation could be to give Good A to Person 1 and Good B to Person 2. This way, the total value created is 66 + 40 = 106. In terms of money, Person 1 could receive 40 units and Person 2 could receive 10 units, totaling 50 units.
# >
# > Another possible allocation could be to give Good A to Person 2 and Good B to Person 1. This way, the total value created is 60 + 34 = 94. In terms of money, Person 2 could receive 36 units and Person 1 could receive 14 units, totaling 50 units.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 15, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 2 goods, namely , Good A, and Good B. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 66, and for Good B is 34.
# Person 2's value for Good A is 60, and for Good B is 40.
# A total of 50 units of money are also available for allocation. This amount of money is worth exactly as much as a good of the same value, for each individual. Since this is a divisible resource, parts of it can be allocated to different agents, although the total money allocated cannot exceed 50 units.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Person 1 money: 0
# Person 2 money: 50
# > There are various ways to approach this allocation problem, and different fairness criteria that could be used. One approach could be to use the concept of maximin fairness, where the goal is to maximize the minimum value that each person receives.
# >
# > In this case, we could consider giving Person 1 Good A and Person 2 Good B, as this would result in Person 1 receiving a value of 66 and Person 2 receiving a value of 40. This allocation ensures that both individuals receive a relatively high value, with Person 1 receiving the higher value.
# >
# ...

# %% [markdown]
# ## SC 21

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 21, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, Person 2, and Person 3, approach you and ask you to determine a fair allocation of 4 goods, namely Good A, Good B, Good C, and Good D. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 45, for Good B is 5, for Good C is 47, and for Good D is 3.
# Person 2's value for Good A is 48, for Good B is 45, for Good C is 5, and for Good D is 2.
# Person 3's value for Good A is 32, for Good B is 23, for Good C is 25, and for Good D is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['2']
# Good B: ['3']
# Good C: ['1']
# Good D: ['None']
# > There are different approaches to determine a fair allocation of the goods. One way to do it is by using the concept of maximum total value. In this approach, the goods would be allocated in a way that maximizes the total value generated from the allocation.
# >
# > Using this approach, we can calculate the total value each person would get from each possible allocation. Then, we can select the allocation that generates the maximum total value.
# >
# > Here are the total values for each possible allocation:
# > - If Person 1 gets Good A: 45
# > - If Person 1 gets Good B: 5
# > - If Person 1 gets Good C: 47
# > - If Person 1 gets Good D: 3
# > - If Person 2 gets Good A: 48
# > - If Person 2 gets Good B: 45
# > - If Person 2 gets Good C: 5
# > - If Person 2 gets Good D: 2
# > - If Person 3 gets Good A: 32
# > - If Person 3 gets Good B: 23
# > - If Person 3 gets Good C: 25
# > - If Person 3 gets Good D: 20
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 21, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, Person 2, and Person 3, approach you and ask you to determine a fair allocation of 4 goods, namely Good A, Good B, Good C, and Good D. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 45, for Good B is 5, for Good C is 47, and for Good D is 3.
# Person 2's value for Good A is 48, for Good B is 45, for Good C is 5, and for Good D is 2.
# Person 3's value for Good A is 32, for Good B is 23, for Good C is 25, and for Good D is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['2']
# Good B: ['1']
# Good C: ['1']
# Good D: ['3']
# > One way to approach this problem is to use the concept of maximum value allocation. This means allocating each good to the person who values it the most.
# >
# > Using this approach, we can allocate Good A to Person 2, as they value it the most (48), then allocate Good B to Person 1 (45), allocate Good C to Person 1 (47), and finally allocate Good D to Person 3 (20).
# >
# > This allocation ensures that each good goes to the person who values it the most. However, it's important to note that there are other ways to allocate the goods that could also be considered fair, as fairness is a subjective concept. This approach is just one way to approach the problem.

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 21, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, Person 2, and Person 3, approach you and ask you to determine a fair allocation of 4 goods, namely Good A, Good B, Good C, and Good D. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 45, for Good B is 5, for Good C is 47, and for Good D is 3.
# Person 2's value for Good A is 48, for Good B is 45, for Good C is 5, and for Good D is 2.
# Person 3's value for Good A is 32, for Good B is 23, for Good C is 25, and for Good D is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['1']
# Good D: ['3']
# > There are different ways to determine a fair allocation of goods among the individuals. One approach is to maximize the total value generated by the allocation. Another approach is to ensure that each individual receives a fair share based on their preferences.
# >
# > One potential fair allocation could be as follows:
# >
# > Person 1 receives Good A (valued at 45) and Good C (valued at 47), with a total value of 92.
# > Person 2 receives Good B (valued at 45) and Good D (valued at 2), with a total value of 47.
# > Person 3 does not receive any goods.
# >
# > This allocation maximizes the total value generated, as all goods are allocated and the total value is 92 + 47 = 139.
# >
# > Another potential fair allocation could be:
# >
# > Person 1 receives Good A (valued at 45) and Good C (valued at 47), with a total value of 92.
# > Person 2 receives Good B (valued at 45).
# > Person 3 receives Good D (valued at 20).
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-35-turbo-1106', 21, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, Person 2, and Person 3, approach you and ask you to determine a fair allocation of 4 goods, namely Good A, Good B, Good C, and Good D. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 45, for Good B is 5, for Good C is 47, and for Good D is 3.
# Person 2's value for Good A is 48, for Good B is 45, for Good C is 5, and for Good D is 2.
# Person 3's value for Good A is 32, for Good B is 23, for Good C is 25, and for Good D is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['3']
# Good D: ['3']
# > There are multiple ways to approach the allocation of goods to individuals. One approach could be to allocate the goods in a way that maximizes the total value across all individuals. Another approach could be to allocate the goods in a way that ensures each individual receives a fair share based on their value for the goods.
# >
# > Using the first approach, we could allocate the goods to maximize the total value across all individuals. In this case, a possible allocation could be as follows:
# >
# > - Person 1 receives Good A and Good C
# > - Person 2 receives Good B
# > - Person 3 receives Good D
# >
# > This allocation would result in a total value of 45 (Good A) + 47 (Good C) + 45 (Good B) + 20 (Good D) = 157.
# >
# ...

# %% [markdown]
# ## SC 22

# %% [markdown]
# # ChatGPT - 4

# %% [markdown]
# ## SC-1.1

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-4-1106-preview', 11, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['1']
# > One way to approach this problem is to use the concept of "maximizing the minimum value." This means that we want to allocate the goods in a way that ensures each person gets the highest value possible for the goods they receive.
# >
# > In this case, we can allocate Good A to Person 1, as they value it the most at 80. Then, we can allocate Good B to Person 2, as they value it the most at 60. Finally, we can allocate Good C to Person 1, as they value it at 20, which is higher than Person 2's value for it at 20 as well.
# >
# > This allocation ensures that each person receives the highest value good for them, which can be seen as a fair and efficient allocation in this context.

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-4-1106-preview', 11, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > There are several ways to approach this problem, and different criteria for fairness could lead to different allocations. One possible approach is to try to maximize the total value generated by the allocation.
# >
# > In this case, we can see that Person 1 values Good A the most, while Person 2 values Good B the most. Therefore, an allocation that gives Good A to Person 1 and Good B to Person 2 would generate the most total value (80 + 60 = 140). Good C could be left unallocated in this scenario as neither person values it highly.
# >
# > Another approach to fairness could be to try to balance the allocations as much as possible. In this case, an allocation that gives Good A to Person 1, Good B to Person 2, and Good C to neither person would achieve a more balanced outcome.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-4-1106-preview', 11, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > There are multiple ways to approach this problem to determine a fair allocation. One way to do so is to use the concept of maximin share, which aims to maximize the minimum value that each individual receives.
# >
# > In this scenario, the fair allocation could be:
# > - Person 1 receives Good A (value of 80)
# > - Person 2 receives Good B (value of 60)
# > - Good C is not allocated to either person (value of 0)
# >
# > This allocation ensures that each person receives the good with the highest value to them, maximizing their individual gains. It also ensures that no individual receives a lower value good when a higher value good is available.
# >
# > Another approach could be to allocate the goods based on a weighted sum of values, taking into account both individuals' preferences.
# >
# > In this case, the fair allocation could be:
# > - Person 1 receives 2/3 of Good A (value of 53.33) and 1/3 of Good C (value of 6.67)
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-4-1106-preview', 11, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > There are different methods to determine a fair allocation of goods, such as the utilitarian approach, the egalitarian approach, or the need-based approach. In this case, we can use the utilitarian approach, aiming to maximize the total value obtained from the allocation.
# >
# > After considering the values of each person for the goods, the fairest allocation, according to the utilitarian approach, would be to allocate Good A to Person 1 and Good B to Person 2, and not allocate Good C to anyone. This allocation would result in a total value of 80 (Good A for Person 1) + 60 (Good B for Person 2) = 140.
# >
# > This allocation maximizes the total value obtained from the allocation, as it gives each good to the person who values it the most. It also takes into consideration that the goods are indivisible and cannot be divided between the two individuals.

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-4-1106-preview', 11, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > One way to approach this problem is to allocate the goods in a way that maximizes the total value generated. In this case, one possible fair allocation could be:
# >
# > Person 1 receives Good A (valued at 80)
# > Person 2 receives Good B (valued at 60)
# > No one receives Good C
# >
# > This allocation maximizes the total value generated, as each good is given to the person who values it the most. However, there are many other possible fair allocations, depending on the criteria used to define fairness. For example, another fair allocation could be:
# >
# > Person 1 receives Good A (valued at 80)
# > Person 2 receives Good C (valued at 20)
# > No one receives Good B
# >
# > Ultimately, the fairest allocation will depend on the specific circumstances and the values of the individuals involved.

# %% [markdown]
# ## SC-1.2

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-4-1106-preview', 12, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > There are various ways to determine the fairest allocation of the goods. One approach could be to maximize the total value received by both individuals, while another approach could be to ensure that each individual receives a fair share of the goods based on their values.
# >
# > One possible fair allocation could be as follows:
# > - Person 1 receives Good A with a value of 80.
# > - Person 2 receives Good B with a value of 60.
# > - Good C is not allocated to either person as it has the lowest combined value.
# >
# > This allocation ensures that each person receives a good with the highest value according to their preferences, and no goods are wasted. However, other allocations could also be considered fair depending on the criteria used to determine fairness.

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-4-1106-preview', 12, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['None']
# Good C: ['2']
# > There are different criteria that can be used to determine a fair allocation of goods in this scenario. One approach could be to allocate the goods in a way that maximizes the total value generated.
# >
# > In this case, one possible allocation could be:
# > - Person 1 receives Good A (value 80)
# > - Person 2 receives Good B (value 60)
# > - Good C is not allocated
# >
# > This allocation maximizes the total value generated, as it gives the highest value goods to each person. Another approach could be to allocate the goods in a way that minimizes envy, i.e. the difference between an individual's value for the goods they receive and the value of the goods the other person receives.
# >
# > In this case, one possible allocation could be:
# > - Person 1 receives Good A (value 80)
# > - Person 2 receives Good C (value 20)
# > - Good B is not allocated
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-4-1106-preview', 12, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['None']
# Good C: ['2']
# > One way to approach this problem is to use the concept of maximum total value. In this case, we can allocate the goods in a way that maximizes the total value obtained by both individuals.
# >
# > One possible fair allocation could be:
# > - Person 1 receives Good A (value 80)
# > - Person 2 receives Good B (value 60)
# > - Good C is not allocated
# >
# > This allocation would result in a total value of 140 (80 + 60) which is the maximum total value that can be achieved given the preferences of the individuals.
# >
# > Another possible fair allocation could be:
# > - Person 1 receives Good A (value 80)
# > - Person 2 receives Good C (value 20)
# > - Good B is not allocated
# >
# > This allocation would result in a total value of 100, which is also the maximum total value that can be achieved given the preferences of the individuals.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-4-1106-preview', 12, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['1']
# Good C: ['2']
# > One possible approach to determining the fairest allocation is to use the concept of maximizing the total value or utility. In this case, we can assign the goods in a way that maximizes the total value for both individuals.
# >
# > First, let's consider assigning Good A to Person 1 and Good B to Person 2. This would give a total value of 80 (Person 1) + 60 (Person 2) = 140. However, Person 1's value for Good B is only 5, which is lower than Person 2's value for Good A (20). Therefore, this allocation may not be the most fair.
# >
# > Next, let's consider assigning Good A to Person 2 and Good B to Person 1. This would give a total value of 20 (Person 2) + 5 (Person 1) = 25. This allocation also does not seem fair as it does not maximize the total value for both individuals.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-4-1106-preview', 12, 'word')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 5, and for Good C is 15.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that you consider to be the fairest - there are no 'correct' or 'incorrect' answers.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > There are several possible approaches to allocating the goods in a fair manner. One common approach is called the "utilitarian" approach, which aims to maximize the total value generated by the allocation. In this case, the utilitarian approach would suggest allocating Good A to Person 1 and Goods B and C to Person 2, as this would result in a total value of 80 (from Person 1's value for Good A) + 80 (from Person 2's value for Good B) + 20 (from Person 2's value for Good C) = 180.
# >
# > Another approach is the "egalitarian" approach, which aims to minimize the differences in value between the individuals. In this case, the egalitarian approach might suggest allocating one good to each person, as this would result in the smallest difference in value between the two individuals.
# >
# ...

# %% [markdown]
# ## SC-1.1 + EQ instruct

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-4-1106-preview', 11, 'word', instruction='EQ')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that ensures each individuals has the same total value for the good(s) they respectively receive.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['1']
# > One way to approach this problem is to use the technique of proportional allocation. This means that each person will receive a portion of the goods that is proportional to their overall value for the goods.
# >
# > First, let's calculate the total value of each good for each person:
# > - Person 1: Total value = 80 (Good A) + 0 (Good B) + 20 (Good C) = 100
# > - Person 2: Total value = 20 (Good A) + 60 (Good B) + 20 (Good C) = 100
# >
# > Since the total value for each person is the same, we can allocate the goods in a way that ensures each person ends up with a total value of 100.
# >
# > One possible fair allocation could be:
# > - Person 1 receives Good A (value of 80) and Good C (value of 20), totaling 100.
# > - Person 2 receives Good B (value of 60), totaling 60.
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-4-1106-preview', 11, 'word', instruction='EQ')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that ensures each individuals has the same total value for the good(s) they respectively receive.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > One way to approach this problem is to use the method of sealed bids. Each person submits their bid for each good privately, and then the goods are allocated based on the highest total bid for each person.
# >
# > Let's calculate the total value for each person based on their bids:
# >
# > Person 1:
# > Total value for Good A = 80
# > Total value for Good B = 0
# > Total value for Good C = 20
# > Total value for all goods = 80 + 0 + 20 = 100
# >
# > Person 2:
# > Total value for Good A = 20
# > Total value for Good B = 60
# > Total value for Good C = 20
# > Total value for all goods = 20 + 60 + 20 = 100
# >
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-4-1106-preview', 11, 'word', instruction='EQ')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that ensures each individuals has the same total value for the good(s) they respectively receive.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['1']
# > To determine a fair allocation of the goods, we can use the concept of the "max-min fairness" solution. In this approach, we aim to maximize the minimum value that each individual receives.
# >
# > First, let's consider the values of each good for each person:
# > Person 1:
# > - Good A: 80
# > - Good B: 0
# > - Good C: 20
# >
# > Person 2:
# > - Good A: 20
# > - Good B: 60
# > - Good C: 20
# >
# > Now, let's find the maximum value for each good and allocate it to the person who values it the most.
# > For Good A, Person 1 values it more (80) than Person 2 (20), so we allocate Good A to Person 1.
# > For Good B, Person 2 values it more (60) than Person 1 (0), so we allocate Good B to Person 2.
# > For Good C, both Person 1 and Person 2 value it equally (20), so we can allocate it to either person. For simplicity, let's allocate it to Person 1.
# >
# > The allocation is as follows:
# ...

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-4-1106-preview', 11, 'word', instruction='EQ')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that ensures each individuals has the same total value for the good(s) they respectively receive.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['None']
# Good C: ['1']
# > To find a fair allocation, we can use the method of "envy-free" allocation, where each individual receives goods such that they do not envy the goods received by the other individual.
# >
# > One possible fair allocation is as follows:
# >
# > Person 1 receives Good A and Good C, with a total value of 80 (for Good A) + 20 (for Good C) = 100.
# > Person 2 receives Good B, with a total value of 60.
# >
# > In this allocation, each person receives goods with a total value of 100, ensuring that they have the same total value for the goods they receive. Additionally, this allocation is envy-free, as neither person would prefer to have the goods received by the other person.

# %%
df_dict = get_single_response('', 'chatgpt', 'gpt-4-1106-preview', 11, 'word', instruction='EQ')
# Out:
# word
# Consider a problem where goods need to be allocated among different individuals. Imagine that the individuals involved, i.e. Person 1, and Person 2, approach you and ask you to determine a fair allocation of 3 goods, namely Good A, Good B, and Good C. The goods to be allocated are indivisible, that is, you have to give the good as a whole to one person or you can decide to not alocate it at all, i.e., you throw it away.
# Person 1's value for Good A is 80, for Good B is 0, and for Good C is 20.
# Person 2's value for Good A is 20, for Good B is 60, and for Good C is 20.
#  Your task is to determine the allocation that ensures each individuals has the same total value for the good(s) they respectively receive.

# %%
for key in df_dict:
    if key != 'Text':
        print(f"{key}: {df_dict[key]}")
to_markdown(df_dict['Text'])
# Out:
# Good A: ['1']
# Good B: ['2']
# Good C: ['None']
# > To determine a fair allocation of the goods, we can use the concept of maximum value division. This means that we allocate each good to the person who values it the most. If there is a tie, we can consider alternative methods such as random allocation.
# >
# > Looking at the values provided by Person 1 and Person 2, we can determine the following allocation:
# >
# > - Good A should be allocated to Person 1, as they value it at 80 which is higher than Person 2's value of 20.
# > - Good B should be allocated to Person 2, as they value it at 60 which is higher than Person 1's value of 0.
# > - Good C can be allocated to either person as they both value it at 20.
# >
# > With this allocation, Person 1 receives Good A and Person 2 receives Good B, ensuring that each individual has the same total value for the goods they receive. Good C can be allocated to either person or not allocated at all.
